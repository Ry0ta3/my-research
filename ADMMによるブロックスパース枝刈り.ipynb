# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.utils.prune as prune
import torchvision.models as models
from torch.onnx import export

import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torch.nn.utils import parameters_to_vector
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.optim.lr_scheduler import CosineAnnealingLR

# %%
# 乱数を一定にする
seed = 777  # 好きな数字でOK
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# onnxファイルを作成する関数
def model_to_onnx(model, output_file, input_shape = (1, 3, 224, 224)):
  model.eval()
  input_tensor = torch.randn(input_shape).to('cpu')
  input_names = ['input']
  output_names = ['output']
  torch.onnx.export(model, input_tensor, output_file, verbose = False, input_names = input_names, output_names = output_names)
  return output_file

# %%
# モデル読み込み
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# 訓練データセット作成
transform = transforms.Compose([transforms.Resize(224),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])   # 正規化したほうがいいらしい

trainset = torchvision.datasets.CIFAR10(root = "./data", train = True, download = True, transform = transform)
trainloader = DataLoader(trainset, batch_size = 400, shuffle = True)

# %%
def project_l1_ball(tensor_x: np.ndarray, radius: float) -> np.ndarray:
    """
    テンソル `tensor_x` を、中心が原点のL1ノルム半径 `radius` の超球（L1ボール）の表面または内部に射影する。
    これは、制約条件 ||z||_1 <= radius を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    アルゴリズムは、"Projection onto the L1-ball" として知られる効率的な手法に基づいている。
    """
    # ステップ 1: 入力テンソルのL1ノルムを計算し、そもそも射影が必要かを確認
    # もしL1ノルムが既に半径以下なら、テンソルは制約を満たしており、何もしなくてよい。
    if np.sum(np.abs(tensor_x)) <= radius:
        return tensor_x

    # ステップ 3: 符号情報を無視し、絶対値のテンソルを作成
    # 射影アルゴリズムは、正の象限（すべての要素が非負）で動作し、最後に元の符号を復元する。
    u_tensor = np.abs(tensor_x)

    # ステップ 4: 絶対値テンソル `u_tensor` を降順にソートする。
    # このソートが、効率的なアルゴリズムの鍵となる。
    u_sorted = np.sort(u_tensor, axis=None)[::-1]
    n_features = len(u_sorted)

    # ステップ 5: ソートされたベクトルの累積和を計算する。
    # sv[i-1] は、u の中で最も大きい i 個の要素の和を表す。
    sv = np.cumsum(u_sorted)

    # ステップ 6: 射影の閾値 `theta` を見つけるための条件を満たす `rho` を探す。
    # ここがアルゴリズムの核心部分。
    # 数学的な導出により、射影後のベクトルは `y = sign(v) * max(abs(v) - theta, 0)` という形になることが分かっている。
    # この `y` のL1ノルムが `radius` に等しくなるような `theta` を見つけたい。
    # そのための条件が `u_sorted[i-1] > (sv[i-1] - radius) / i` であり、
    # この条件を満たす最大のインデックスが `rho` となる。
    
    # i = 1, 2, ..., n_features を生成
    arange_i = np.arange(1, n_features + 1)
    
    # 条件を満たすインデックスの候補を探す
    rho_candidates = np.where(u_sorted > (sv - radius) / arange_i)[0]
    
    # 候補の中から最大のインデックスをrhoとして採用する（0-basedから1-basedに変換するため+1）
    # 候補がない場合は、すべての要素が同じだけシフトされるケース
    rho = rho_candidates[-1] + 1 if len(rho_candidates) > 0 else n_features

    # ステップ 7: 決定した `rho` を使って、最終的なシフト量 `theta` を計算する。
    # thetaは、各要素から（絶対値の形で）引き算される値。
    theta = (sv[rho - 1] - radius) / rho

    # ステップ 8: ソフトしきい値処理（soft-thresholding）を実行して、射影を完了させる。
    # 1. 各要素の絶対値から `theta` を引く。
    # 2. 結果が負になった場合は0にする（`np.maximum(..., 0)`）。
    # 3. 元の符号 `sign(v)` を掛け合わせて、正しい象限に戻す。
    projected_tensor_x = np.sign(tensor_x) * np.maximum(np.abs(tensor_x) - theta, 0)

    # ステップ 9: 返す。
    return projected_tensor_x

def hard_threshold(tensor_x: np.ndarray, K0: int) -> np.ndarray:
    """
    テンソル `tensor_x` に対してハードしきい値処理を適用する。
    これは、制約条件 ||z||_0 <= K0 を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    簡単に言うと、テンソルの要素のうち、絶対値が大きい方から `K0` 個だけを残し、
    それ以外をすべて厳密に0にする。
    """
    # ステップ 1: そもそも処理が必要かを確認
    # もし残したい非ゼロ要素の数 `K0` が、テンソルの全要素数以上なら、
    # どの要素も0にする必要はないので、そのまま返す。
    if K0 >= tensor_x.size:
        return tensor_x
    
    # ステップ 3: 0にすべき要素を決定するための「しきい値」を見つける。
    # しきい値は、ベクトル `v` の絶対値を小さい順にソートしたとき、
    # 後ろから `K0` 番目（つまり、絶対値が `K0` 番目に大きい要素）の値となる。
    # 例: v=[10, -2, 5, -8], K0=2 の場合、abs(v)=[10, 2, 5, 8]。
    #    ソートすると [2, 5, 8, 10]。後ろから2番目は `8`。これがしきい値となる。
    # 同じ値の要素があった場合は非ゼロの要素がK0
    threshold = np.sort(np.abs(tensor_x), axis=None)[-(K0+1)]

    # ステップ 4: しきい値に基づいて、値を0にする。
    # 絶対値がこのしきい値より「小さい」すべての要素を0で上書きする。
    # 例: abs(v) < 8 となるのは `2` と `5`。対応する元の要素 `-2` と `5` が0になる。
    tensor_x[np.abs(tensor_x) <= threshold] = 0

    return tensor_x

# %%
def D_op_4d(tensor: np.ndarray) -> np.ndarray:
    """
    4階数テンソル (out_ch, in_ch, h, w) の4方向の差分を計算し、
    5階数テンソル (out_ch, in_ch, h, w, 4) として返す。
    """
    # dim=0 (出力チャネル方向)
    diff_dim0 = np.roll(tensor, -1, axis=0) - tensor
    # dim=1 (入力チャネル方向)
    diff_dim1 = np.roll(tensor, -1, axis=1) - tensor
    # dim=2 (縦方向)
    diff_dim2 = np.roll(tensor, -1, axis=2) - tensor
    # dim=3 (横方向)
    diff_dim3 = np.roll(tensor, -1, axis=3) - tensor
    
    # 最後の軸に4つの差分をスタックする
    return np.stack([diff_dim0, diff_dim1, diff_dim2, diff_dim3], axis=-1)

# 転置差分がどんな演算なのかいまいちわかってない
def DT_op_4d(stacked_tensor: np.ndarray) -> np.ndarray:
    """
    D_op_4dの転置演算。5階数テンソルを受け取り、4階数テンソルを返す。
    """
    # 各差分を取り出す
    d0 = stacked_tensor[..., 0]
    d1 = stacked_tensor[..., 1]
    d2 = stacked_tensor[..., 2]
    d3 = stacked_tensor[..., 3]

    # 各々の転置差分を計算し、合計する (D^T = -D_backward)
    term0 = np.roll(d0, 1, axis=0) - d0
    term1 = np.roll(d1, 1, axis=1) - d1
    term2 = np.roll(d2, 1, axis=2) - d2
    term3 = np.roll(d3, 1, axis=3) - d3
    
    return term0 + term1 + term2 + term3

# %%
# lambda式つかうと多分うまくいかない（謎）
'''
def solve_admm(
    w: np.ndarray, 
    D_op, 
    DT_op, 
    K1: float, 
    K0_ratio: float, 
    rho: float = 1.0, 
    n_iter: int = 50
):
    x  = w.copy()
    y = D_op(x)
    z = x.copy()
    u1 = np.zeros_like(y)
    u2 = np.zeros_like(z)
    K0 = int(K0_ratio * w.size)

    print(f"Starting ADMM...")
    print(f"Tensor shape: {w.shape}, K1={K1}, K0={K0} ({K0_ratio*100:.1f}%)")

    def matvec(p_flat: np.ndarray) -> np.ndarray:
        """
        p = p_flat.reshape(w.shape)
        DTD_p = DT_op(D_op(p))
        result = rho * DTD_p + rho * p + p # vの定義と合わせる
        return result.flatten()
        """
    
        # ★★★ ここからが修正部分 ★★★

        # 1. cgから渡されたp_flatのデータ型を確認し、強制的にfloat64に変換する
        p_flat_float64 = p_flat.astype(np.float64, copy=False)
        # copy=Falseは、もし元々float64なら不要なコピーを避けるための最適化

        # 2. float64に変換されたベクトルを使って計算を進める
        p = p_flat_float64.reshape(w.shape)
        DTD_p = DT_op(D_op(p))
        
        # 3. 計算結果も必ずfloat64になるようにする
        result = rho * DTD_p + rho * p + p
        
        # 念のため、返す前にもdtypeを確認
        return result.flatten().astype(np.float64, copy=False)
        
        # ★★★ 修正ここまで ★★★

    # メインループ
    for i in range(n_iter):
        # 1. x の更新 (CG法で解く)
        v = w + rho * DT_op(y - u1) + rho * (z - u2)

        # ★★★ ここにデバッグ用のprint文を追加 ★★★
        print(f"\n--- Iteration {i+1} ---")
        print(f"Dtypes before CG: v={v.dtype}, x={x.dtype}")
        if v.dtype != np.float64 or x.dtype != np.float64:
            print("!!! WARNING: Dtype is not float64. Converting... !!!")
            v = v.astype(np.float64)
            x = x.astype(np.float64)
        # ★★★ デバッグここまで ★★★
        
        x_flat, _ = cg(lambda p: matvec(p), v.flatten(), x0=x.flatten())   # tol=1e-5つけるとエラー
        x = x_flat.reshape(w.shape)

        # 2. y の更新
        v_proj1 = D_op(x) + u1
        y = project_l1_ball(v_proj1, K1)

        # 3. z の更新
        v_proj2 = x + u2
        z = hard_threshold(v_proj2, K0)

        # 4. 双対変数 u1, u2 の更新
        u1 = u1 + D_op(x) - y
        u2 = u2 + x - z
        
        if (i + 1) % 10 == 0:
            recon_error = np.linalg.norm(x - w) / np.linalg.norm(w)
            print(f"Iteration {i+1}/{n_iter}, Reconstruction Error: {recon_error:.4f}")

    print("ADMM finished.")
    return x
'''
# Out:
# '\ndef solve_admm(\n    w: np.ndarray, \n    D_op, \n    DT_op, \n    K1: float, \n    K0_ratio: float, \n    rho: float = 1.0, \n    n_iter: int = 50\n):\n    x  = w.copy()\n    y = D_op(x)\n    z = x.copy()\n    u1 = np.zeros_like(y)\n    u2 = np.zeros_like(z)\n    K0 = int(K0_ratio * w.size)\n\n    print(f"Starting ADMM...")\n    print(f"Tensor shape: {w.shape}, K1={K1}, K0={K0} ({K0_ratio*100:.1f}%)")\n\n    def matvec(p_flat: np.ndarray) -> np.ndarray:\n        """\n        p = p_flat.reshape(w.shape)\n        DTD_p = DT_op(D_op(p))\n        result = rho * DTD_p + rho * p + p # vの定義と合わせる\n        return result.flatten()\n        """\n    \n        # ★★★ ここからが修正部分 ★★★\n\n        # 1. cgから渡されたp_flatのデータ型を確認し、強制的にfloat64に変換する\n        p_flat_float64 = p_flat.astype(np.float64, copy=False)\n        # copy=Falseは、もし元々float64なら不要なコピーを避けるための最適化\n\n        # 2. float64に変換されたベクトルを使って計算を進める\n        p = p_flat_float64.reshape(w.shape)\n        DTD_p = DT_op(D_op(p))\n        \n        # 3. 計算結果も必ずfloat64になるようにする\n        result = rho * DTD_p + rho * p + p\n        \n        # 念のため、返す前にもdtypeを確認\n        return result.flatten().astype(np.float64, copy=False)\n        \n        # ★★★ 修正ここまで ★★★\n\n    # メインループ\n    for i in range(n_iter):\n        # 1. x の更新 (CG法で解く)\n        v = w + rho * DT_op(y - u1) + rho * (z - u2)\n\n        # ★★★ ここにデバッグ用のprint文を追加 ★★★\n        print(f"\n--- Iteration {i+1} ---")\n        print(f"Dtypes before CG: v={v.dtype}, x={x.dtype}")\n        if v.dtype != np.float64 or x.dtype != np.float64:\n            print("!!! WARNING: Dtype is not float64. Converting... !!!")\n            v = v.astype(np.float64)\n            x = x.astype(np.float64)\n        # ★★★ デバッグここまで ★★★\n        \n        x_flat, _ = cg(lambda p: matvec(p), v.flatten(), x0=x.flatten())   # tol=1e-5つけるとエラー\n        x = x_flat.reshape(w.shape)\n\n        # 2. y の更新\n        v_proj1 = D_op(x) + u1\n        y = project_l1_ball(v_proj1, K1)\n\n        # 3. z の更新\n        v_proj2 = x + u2\n        z = hard_threshold(v_proj2, K0)\n\n        # 4. 双対変数 u1, u2 の更新\n        u1 = u1 + D_op(x) - y\n        u2 = u2 + x - z\n        \n        if (i + 1) % 10 == 0:\n            recon_error = np.linalg.norm(x - w) / np.linalg.norm(w)\n            print(f"Iteration {i+1}/{n_iter}, Reconstruction Error: {recon_error:.4f}")\n\n    print("ADMM finished.")\n    return x\n'

# %%
from scipy.sparse.linalg import cg, LinearOperator # LinearOperatorをインポート

def solve_admm(
    w: np.ndarray, 
    D_op, 
    DT_op, 
    K1: float, 
    K0_ratio: float, 
    rho: float, 
    gamma: float,
    n_iter: int,
):
    # --- 初期化 ---
    # 全ての変数を float64 で厳密に初期化
    x  = w.copy().astype(np.float64)
    y = D_op(x).astype(np.float64)
    z = x.copy().astype(np.float64)
    u1 = np.zeros_like(y, dtype=np.float64)
    u2 = np.zeros_like(z, dtype=np.float64)
    K0 = int(K0_ratio * w.size)
    
    # テンソルの総要素数を計算 (LinearOperatorのshape定義のため)
    n_elements = w.size

    print(f"Tensor shape: {w.shape}, K1={K1}, K0={K0} ({K0_ratio*100:.1f}%)")

    # ★★★ ここからが大幅な変更点 ★★★

    # 1. matvec関数を定義 (入力と出力が1次元ベクトルであることを明示)
    def matvec_for_lo(p_flat: np.ndarray) -> np.ndarray:
        # 内部で型変換は行わず、入力の型を信頼する
        p = p_flat.reshape(w.shape)
        DTD_p = DT_op(D_op(p))
        result = rho * DTD_p + gamma * p + p
        return result.flatten()

    # 2. LinearOperatorを明示的に作成
    # これにより、shapeとdtypeをcg関数に正確に伝える
    A = LinearOperator(
        shape=(n_elements, n_elements), # 作用素は (N, N) の正方行列として振る舞う
        matvec=matvec_for_lo,
        dtype=np.float64               # 扱うデータ型は float64 であることを明記
    )

    # ★★★ 変更ここまで ★★★


    # --- ADMM反復ループ ---
    for i in range(n_iter):
        # 1. x の更新
        # v は float64 であることを確認済み
        v = w + rho * DT_op(y - u1) + gamma * (z - u2)
        
        # LinearOperatorオブジェクト A を直接cgに渡す
        x_flat, _ = cg(A, v.flatten(), x0=x.flatten())
        x = x_flat.reshape(w.shape)

        # 2. y の更新
        v_proj1 = D_op(x) + u1
        y = project_l1_ball(v_proj1, K1)

        # 3. z の更新
        v_proj2 = x + u2
        z = hard_threshold(v_proj2, K0)

        # 4. 双対変数 u1, u2 の更新
        u1 = u1 + D_op(x) - y
        u2 = u2 + x - z
        
        if i % 5 == 0:
            recon_error = np.linalg.norm(x - w) / np.linalg.norm(w)
            print(f"Iteration {i+1}/{n_iter}, Reconstruction Error: {recon_error:.4f}")

    return x

# %%
def Omega(delta):
    """
    4階テンソルdeltaの各次元に沿った差分を計算し、
    その絶対値の総和を返す。
    """
    h = 1.0  # Dのパラメータ

    # 4つの次元それぞれに対して差分（勾配）を計算

    # dim=0 (出力チャネル方向の差分)
    diff_dim0 = delta[1:, :, :, :] - delta[:-1, :, :, :]

    # dim=1 (入力チャネル方向の差分)
    diff_dim1 = delta[:, 1:, :, :] - delta[:, :-1, :, :]

    # dim=2 (縦方向の差分)
    # 1行目から最後までと、0行目から最後の一つ手前までの差
    diff_dim2 = delta[:, :, 1:, :] - delta[:, :, :-1, :]

    # dim=3 (横方向の差分)
    # 1列目から最後までと、0列目から最後の一つ手前までの差
    diff_dim3 = delta[:, :, :, 1:] - delta[:, :, :, :-1]

    # 全ての差分の絶対値の総和を計算
    # これがD@deltaに相当する操作のL1ノルムになる
    constrain = torch.sum(torch.abs(diff_dim0)) + torch.sum(torch.abs(diff_dim1)) + torch.sum(torch.abs(diff_dim2)) + torch.sum(torch.abs(diff_dim3))

    return constrain / h

# %%
# 各層のTVを見てみる
layer_tvs = {}
layer_relative_tvs = {}
conv_layer_names = []

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        w_tensor = module.weight.detach().clone().to(device)
        tv = Omega(w_tensor).item()
        ave_tv = tv/(w_tensor).numel()
        relative_tv = tv / torch.sum(torch.abs(w_tensor)).item()
        layer_tvs[name] = tv
        layer_relative_tvs[name] = relative_tv
        conv_layer_names.append(name)
        print(f"{name}：TV={tv:.4f}     ave_TV={ave_tv:.4f}     relative_TV={relative_tv:.4f}")
# Out:
# conv1：TV=2785.1948     ave_TV=0.2960     relative_TV=3.8864
# layer1.0.conv1：TV=5368.6899     ave_TV=0.1456     relative_TV=4.6001
# layer1.0.conv2：TV=5110.8359     ave_TV=0.1386     relative_TV=4.3279
# layer1.1.conv1：TV=5665.4883     ave_TV=0.1537     relative_TV=4.4829
# layer1.1.conv2：TV=5081.4331     ave_TV=0.1378     relative_TV=4.3692
# layer2.0.conv1：TV=9606.8564     ave_TV=0.1303     relative_TV=4.4254
# layer2.0.conv2：TV=15700.7480     ave_TV=0.1065     relative_TV=4.4383
# layer2.0.downsample.0：TV=1077.2024     ave_TV=0.1315     relative_TV=2.9591
# layer2.1.conv1：TV=16048.6338     ave_TV=0.1088     relative_TV=4.4778
# layer2.1.conv2：TV=14007.5215     ave_TV=0.0950     relative_TV=4.2592
# layer3.0.conv1：TV=24442.1191     ave_TV=0.0829     relative_TV=3.9467
# layer3.0.conv2：TV=45506.3359     ave_TV=0.0772     relative_TV=4.1868
# layer3.0.downsample.0：TV=2261.6729     ave_TV=0.0690     relative_TV=2.8949
# layer3.1.conv1：TV=41485.1523     ave_TV=0.0703     relative_TV=4.2055
# layer3.1.conv2：TV=37498.1641     ave_TV=0.0636     relative_TV=4.0776
# layer4.0.conv1：TV=70836.3359     ave_TV=0.0600     relative_TV=3.9260
# layer4.0.conv2：TV=134329.4375     ave_TV=0.0569     relative_TV=4.2296
# layer4.0.downsample.0：TV=9025.8906     ave_TV=0.0689     relative_TV=2.8755
# layer4.1.conv1：TV=129517.4609     ave_TV=0.0549     relative_TV=3.8883
# layer4.1.conv2：TV=81123.4766     ave_TV=0.0344     relative_TV=3.3774

# %%
import json

# JSONファイルから辞書を読み込む
with open('90cut_data.json', 'r') as f:
    zero_ratings = json.load(f)

with open('90cut_TV.json', 'r') as f:
    target_TVs = json.load(f)

print(zero_ratings)
# Out:
# {'conv1': 0.45471938775510207, 'layer1.0.conv1': 0.6550564236111112, 'layer1.0.conv2': 0.6227756076388888, 'layer1.1.conv1': 0.6005859375, 'layer1.1.conv2': 0.6202528211805556, 'layer2.0.conv1': 0.6569552951388888, 'layer2.0.conv2': 0.73858642578125, 'layer2.0.downsample.0': 0.53125, 'layer2.1.conv1': 0.7287868923611112, 'layer2.1.conv2': 0.7545912000868056, 'layer3.0.conv1': 0.7836710611979166, 'layer3.0.conv2': 0.8301255967881944, 'layer3.0.downsample.0': 0.7366943359375, 'layer3.1.conv1': 0.8630913628472222, 'layer3.1.conv2': 0.8824259440104166, 'layer4.0.conv1': 0.8904622395833334, 'layer4.0.conv2': 0.9279958936903212, 'layer4.0.downsample.0': 0.7266311645507812, 'layer4.1.conv1': 0.9163699679904513, 'layer4.1.conv2': 0.9756698608398438}

# %%
final_weights_to_assign = {}

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        print(f"\n--- レイヤー '{name}' の処理を開始 ---")

        # wを4階テンソルのまま取得
        # .detach().clone()で勾配情報を切り離し、安全なコピーを作成し、numpyに変換、scipyのcg法に合うようにfloat64に
        w_numpy = module.weight.detach().clone().to('cpu').numpy().astype(np.float64)

        # --- パラメータ設定と実行 ---
        K1_val = target_TVs[name]*0.9       # Total Variationの上限
        K0_ratio_val = 1 - zero_ratings[name]   # 10%を非ゼロにする (目標のスパース率90%)
        rho_val = 0.01        # block性ペナルティパラメータ
        gamma_val = 15.0   # sparse性ペナルティパラメータ
        iterations = 300   # 繰り返し回数

        # ADMMソルバーを実行
        x_final = solve_admm(
            w=w_numpy,
            D_op=D_op_4d,        
            DT_op=DT_op_4d,      
            K1=K1_val,
            K0_ratio=K0_ratio_val,
            rho=rho_val,
            gamma=gamma_val,
            n_iter=iterations
        )
        with torch.no_grad():
            module.weight.copy_(torch.tensor(x_final))

        # 閾値で0に近い値を完全な0にする
        x_final[np.abs(x_final) <= 1e-4] = 0

        # 結果の簡単な確認
        print("\n結果:")
        #print(x_final)
        print(f"元の重みテンソルの非ゼロの要素数: {np.sum(w_numpy != 0)}")
        print(f"ADMM後の重みテンソルの非ゼロの要素数: {np.sum(x_final != 0)} (目標数{int(K0_ratio_val * w_numpy.size)})")
        print(f"||Dx||_1: {np.sum(np.abs(D_op_4d(x_final))):.4f} (制約は{K1_val}以下)")
# Out:
# --- レイヤー 'conv1' の処理を開始 ---
# Tensor shape: (64, 3, 7, 7), K1=2435.7392578125, K0=5129 (54.5%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.0750
# Iteration 11/300, Reconstruction Error: 0.0777
# Iteration 16/300, Reconstruction Error: 0.0844
# Iteration 21/300, Reconstruction Error: 0.0951
# Iteration 26/300, Reconstruction Error: 0.1084
# Iteration 31/300, Reconstruction Error: 0.1224
# Iteration 36/300, Reconstruction Error: 0.1356
# Iteration 41/300, Reconstruction Error: 0.1474
# Iteration 46/300, Reconstruction Error: 0.1572
# Iteration 51/300, Reconstruction Error: 0.1651
# Iteration 56/300, Reconstruction Error: 0.1711
# Iteration 61/300, Reconstruction Error: 0.1754
# Iteration 66/300, Reconstruction Error: 0.1781
# Iteration 71/300, Reconstruction Error: 0.1799
# Iteration 76/300, Reconstruction Error: 0.1807
# Iteration 81/300, Reconstruction Error: 0.1808
# Iteration 86/300, Reconstruction Error: 0.1805
# Iteration 91/300, Reconstruction Error: 0.1800
# Iteration 96/300, Reconstruction Error: 0.1793
# Iteration 101/300, Reconstruction Error: 0.1786
# Iteration 106/300, Reconstruction Error: 0.1778
# Iteration 111/300, Reconstruction Error: 0.1772
# Iteration 116/300, Reconstruction Error: 0.1766
# Iteration 121/300, Reconstruction Error: 0.1761
# Iteration 126/300, Reconstruction Error: 0.1756
# Iteration 131/300, Reconstruction Error: 0.1753
# Iteration 136/300, Reconstruction Error: 0.1750
# Iteration 141/300, Reconstruction Error: 0.1749
# Iteration 146/300, Reconstruction Error: 0.1747
# Iteration 151/300, Reconstruction Error: 0.1747
# Iteration 156/300, Reconstruction Error: 0.1746
# Iteration 161/300, Reconstruction Error: 0.1746
# Iteration 166/300, Reconstruction Error: 0.1746
# Iteration 171/300, Reconstruction Error: 0.1747
# Iteration 176/300, Reconstruction Error: 0.1747
# Iteration 181/300, Reconstruction Error: 0.1748
# Iteration 186/300, Reconstruction Error: 0.1748
# Iteration 191/300, Reconstruction Error: 0.1749
# Iteration 196/300, Reconstruction Error: 0.1749
# Iteration 201/300, Reconstruction Error: 0.1750
# Iteration 206/300, Reconstruction Error: 0.1750
# Iteration 211/300, Reconstruction Error: 0.1750
# Iteration 216/300, Reconstruction Error: 0.1751
# Iteration 221/300, Reconstruction Error: 0.1751
# Iteration 226/300, Reconstruction Error: 0.1751
# Iteration 231/300, Reconstruction Error: 0.1751
# Iteration 236/300, Reconstruction Error: 0.1751
# Iteration 241/300, Reconstruction Error: 0.1751
# Iteration 246/300, Reconstruction Error: 0.1752
# Iteration 251/300, Reconstruction Error: 0.1752
# Iteration 256/300, Reconstruction Error: 0.1752
# Iteration 261/300, Reconstruction Error: 0.1752
# Iteration 266/300, Reconstruction Error: 0.1752
# Iteration 271/300, Reconstruction Error: 0.1752
# Iteration 276/300, Reconstruction Error: 0.1752
# Iteration 281/300, Reconstruction Error: 0.1752
# Iteration 286/300, Reconstruction Error: 0.1752
# Iteration 291/300, Reconstruction Error: 0.1752
# Iteration 296/300, Reconstruction Error: 0.1752
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 9408
# ADMM後の重みテンソルの非ゼロの要素数: 5129 (目標数5129)
# ||Dx||_1: 2436.2149 (制約は2435.7392578125以下)
#
# --- レイヤー 'layer1.0.conv1' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=4192.696142578126, K0=12715 (34.5%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.2219
# Iteration 11/300, Reconstruction Error: 0.2244
# Iteration 16/300, Reconstruction Error: 0.2307
# Iteration 21/300, Reconstruction Error: 0.2408
# Iteration 26/300, Reconstruction Error: 0.2533
# Iteration 31/300, Reconstruction Error: 0.2662
# Iteration 36/300, Reconstruction Error: 0.2780
# Iteration 41/300, Reconstruction Error: 0.2876
# Iteration 46/300, Reconstruction Error: 0.2945
# Iteration 51/300, Reconstruction Error: 0.2989
# Iteration 56/300, Reconstruction Error: 0.3009
# Iteration 61/300, Reconstruction Error: 0.3011
# Iteration 66/300, Reconstruction Error: 0.3000
# Iteration 71/300, Reconstruction Error: 0.2981
# Iteration 76/300, Reconstruction Error: 0.2958
# Iteration 81/300, Reconstruction Error: 0.2934
# Iteration 86/300, Reconstruction Error: 0.2912
# Iteration 91/300, Reconstruction Error: 0.2892
# Iteration 96/300, Reconstruction Error: 0.2876
# Iteration 101/300, Reconstruction Error: 0.2864
# Iteration 106/300, Reconstruction Error: 0.2856
# Iteration 111/300, Reconstruction Error: 0.2851
# Iteration 116/300, Reconstruction Error: 0.2849
# Iteration 121/300, Reconstruction Error: 0.2848
# Iteration 126/300, Reconstruction Error: 0.2850
# Iteration 131/300, Reconstruction Error: 0.2852
# Iteration 136/300, Reconstruction Error: 0.2855
# Iteration 141/300, Reconstruction Error: 0.2858
# Iteration 146/300, Reconstruction Error: 0.2861
# Iteration 151/300, Reconstruction Error: 0.2863
# Iteration 156/300, Reconstruction Error: 0.2865
# Iteration 161/300, Reconstruction Error: 0.2867
# Iteration 166/300, Reconstruction Error: 0.2868
# Iteration 171/300, Reconstruction Error: 0.2869
# Iteration 176/300, Reconstruction Error: 0.2869
# Iteration 181/300, Reconstruction Error: 0.2869
# Iteration 186/300, Reconstruction Error: 0.2869
# Iteration 191/300, Reconstruction Error: 0.2869
# Iteration 196/300, Reconstruction Error: 0.2868
# Iteration 201/300, Reconstruction Error: 0.2868
# Iteration 206/300, Reconstruction Error: 0.2868
# Iteration 211/300, Reconstruction Error: 0.2867
# Iteration 216/300, Reconstruction Error: 0.2867
# Iteration 221/300, Reconstruction Error: 0.2867
# Iteration 226/300, Reconstruction Error: 0.2867
# Iteration 231/300, Reconstruction Error: 0.2867
# Iteration 236/300, Reconstruction Error: 0.2867
# Iteration 241/300, Reconstruction Error: 0.2867
# Iteration 246/300, Reconstruction Error: 0.2867
# Iteration 251/300, Reconstruction Error: 0.2867
# Iteration 256/300, Reconstruction Error: 0.2867
# Iteration 261/300, Reconstruction Error: 0.2867
# Iteration 266/300, Reconstruction Error: 0.2867
# Iteration 271/300, Reconstruction Error: 0.2867
# Iteration 276/300, Reconstruction Error: 0.2867
# Iteration 281/300, Reconstruction Error: 0.2867
# Iteration 286/300, Reconstruction Error: 0.2867
# Iteration 291/300, Reconstruction Error: 0.2867
# Iteration 296/300, Reconstruction Error: 0.2867
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 12715 (目標数12715)
# ||Dx||_1: 4192.8111 (制約は4192.696142578126以下)
#
# --- レイヤー 'layer1.0.conv2' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=3895.0000488281253, K0=13906 (37.7%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.2860
# Iteration 11/300, Reconstruction Error: 0.2884
# Iteration 16/300, Reconstruction Error: 0.2944
# Iteration 21/300, Reconstruction Error: 0.3040
# Iteration 26/300, Reconstruction Error: 0.3159
# Iteration 31/300, Reconstruction Error: 0.3285
# Iteration 36/300, Reconstruction Error: 0.3402
# Iteration 41/300, Reconstruction Error: 0.3498
# Iteration 46/300, Reconstruction Error: 0.3569
# Iteration 51/300, Reconstruction Error: 0.3614
# Iteration 56/300, Reconstruction Error: 0.3636
# Iteration 61/300, Reconstruction Error: 0.3640
# Iteration 66/300, Reconstruction Error: 0.3631
# Iteration 71/300, Reconstruction Error: 0.3613
# Iteration 76/300, Reconstruction Error: 0.3591
# Iteration 81/300, Reconstruction Error: 0.3567
# Iteration 86/300, Reconstruction Error: 0.3545
# Iteration 91/300, Reconstruction Error: 0.3526
# Iteration 96/300, Reconstruction Error: 0.3510
# Iteration 101/300, Reconstruction Error: 0.3497
# Iteration 106/300, Reconstruction Error: 0.3489
# Iteration 111/300, Reconstruction Error: 0.3483
# Iteration 116/300, Reconstruction Error: 0.3480
# Iteration 121/300, Reconstruction Error: 0.3480
# Iteration 126/300, Reconstruction Error: 0.3481
# Iteration 131/300, Reconstruction Error: 0.3483
# Iteration 136/300, Reconstruction Error: 0.3485
# Iteration 141/300, Reconstruction Error: 0.3488
# Iteration 146/300, Reconstruction Error: 0.3491
# Iteration 151/300, Reconstruction Error: 0.3493
# Iteration 156/300, Reconstruction Error: 0.3496
# Iteration 161/300, Reconstruction Error: 0.3497
# Iteration 166/300, Reconstruction Error: 0.3498
# Iteration 171/300, Reconstruction Error: 0.3499
# Iteration 176/300, Reconstruction Error: 0.3500
# Iteration 181/300, Reconstruction Error: 0.3500
# Iteration 186/300, Reconstruction Error: 0.3500
# Iteration 191/300, Reconstruction Error: 0.3499
# Iteration 196/300, Reconstruction Error: 0.3499
# Iteration 201/300, Reconstruction Error: 0.3499
# Iteration 206/300, Reconstruction Error: 0.3499
# Iteration 211/300, Reconstruction Error: 0.3498
# Iteration 216/300, Reconstruction Error: 0.3498
# Iteration 221/300, Reconstruction Error: 0.3498
# Iteration 226/300, Reconstruction Error: 0.3498
# Iteration 231/300, Reconstruction Error: 0.3498
# Iteration 236/300, Reconstruction Error: 0.3497
# Iteration 241/300, Reconstruction Error: 0.3497
# Iteration 246/300, Reconstruction Error: 0.3497
# Iteration 251/300, Reconstruction Error: 0.3497
# Iteration 256/300, Reconstruction Error: 0.3497
# Iteration 261/300, Reconstruction Error: 0.3497
# Iteration 266/300, Reconstruction Error: 0.3498
# Iteration 271/300, Reconstruction Error: 0.3498
# Iteration 276/300, Reconstruction Error: 0.3498
# Iteration 281/300, Reconstruction Error: 0.3498
# Iteration 286/300, Reconstruction Error: 0.3498
# Iteration 291/300, Reconstruction Error: 0.3498
# Iteration 296/300, Reconstruction Error: 0.3498
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 13906 (目標数13906)
# ||Dx||_1: 3895.0821 (制約は3895.0000488281253以下)
#
# --- レイヤー 'layer1.1.conv1' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=4417.782275390625, K0=14724 (39.9%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.2514
# Iteration 11/300, Reconstruction Error: 0.2543
# Iteration 16/300, Reconstruction Error: 0.2615
# Iteration 21/300, Reconstruction Error: 0.2729
# Iteration 26/300, Reconstruction Error: 0.2868
# Iteration 31/300, Reconstruction Error: 0.3012
# Iteration 36/300, Reconstruction Error: 0.3142
# Iteration 41/300, Reconstruction Error: 0.3246
# Iteration 46/300, Reconstruction Error: 0.3320
# Iteration 51/300, Reconstruction Error: 0.3364
# Iteration 56/300, Reconstruction Error: 0.3383
# Iteration 61/300, Reconstruction Error: 0.3381
# Iteration 66/300, Reconstruction Error: 0.3366
# Iteration 71/300, Reconstruction Error: 0.3343
# Iteration 76/300, Reconstruction Error: 0.3315
# Iteration 81/300, Reconstruction Error: 0.3288
# Iteration 86/300, Reconstruction Error: 0.3263
# Iteration 91/300, Reconstruction Error: 0.3242
# Iteration 96/300, Reconstruction Error: 0.3225
# Iteration 101/300, Reconstruction Error: 0.3213
# Iteration 106/300, Reconstruction Error: 0.3204
# Iteration 111/300, Reconstruction Error: 0.3200
# Iteration 116/300, Reconstruction Error: 0.3198
# Iteration 121/300, Reconstruction Error: 0.3199
# Iteration 126/300, Reconstruction Error: 0.3201
# Iteration 131/300, Reconstruction Error: 0.3204
# Iteration 136/300, Reconstruction Error: 0.3208
# Iteration 141/300, Reconstruction Error: 0.3211
# Iteration 146/300, Reconstruction Error: 0.3214
# Iteration 151/300, Reconstruction Error: 0.3217
# Iteration 156/300, Reconstruction Error: 0.3219
# Iteration 161/300, Reconstruction Error: 0.3221
# Iteration 166/300, Reconstruction Error: 0.3222
# Iteration 171/300, Reconstruction Error: 0.3222
# Iteration 176/300, Reconstruction Error: 0.3223
# Iteration 181/300, Reconstruction Error: 0.3222
# Iteration 186/300, Reconstruction Error: 0.3222
# Iteration 191/300, Reconstruction Error: 0.3222
# Iteration 196/300, Reconstruction Error: 0.3221
# Iteration 201/300, Reconstruction Error: 0.3221
# Iteration 206/300, Reconstruction Error: 0.3220
# Iteration 211/300, Reconstruction Error: 0.3220
# Iteration 216/300, Reconstruction Error: 0.3220
# Iteration 221/300, Reconstruction Error: 0.3220
# Iteration 226/300, Reconstruction Error: 0.3220
# Iteration 231/300, Reconstruction Error: 0.3220
# Iteration 236/300, Reconstruction Error: 0.3220
# Iteration 241/300, Reconstruction Error: 0.3220
# Iteration 246/300, Reconstruction Error: 0.3220
# Iteration 251/300, Reconstruction Error: 0.3220
# Iteration 256/300, Reconstruction Error: 0.3220
# Iteration 261/300, Reconstruction Error: 0.3220
# Iteration 266/300, Reconstruction Error: 0.3220
# Iteration 271/300, Reconstruction Error: 0.3220
# Iteration 276/300, Reconstruction Error: 0.3220
# Iteration 281/300, Reconstruction Error: 0.3220
# Iteration 286/300, Reconstruction Error: 0.3220
# Iteration 291/300, Reconstruction Error: 0.3220
# Iteration 296/300, Reconstruction Error: 0.3220
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 14724 (目標数14724)
# ||Dx||_1: 4417.8491 (制約は4417.782275390625以下)
#
# --- レイヤー 'layer1.1.conv2' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=3854.8362304687503, K0=13999 (38.0%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.2941
# Iteration 11/300, Reconstruction Error: 0.2969
# Iteration 16/300, Reconstruction Error: 0.3038
# Iteration 21/300, Reconstruction Error: 0.3148
# Iteration 26/300, Reconstruction Error: 0.3284
# Iteration 31/300, Reconstruction Error: 0.3424
# Iteration 36/300, Reconstruction Error: 0.3551
# Iteration 41/300, Reconstruction Error: 0.3654
# Iteration 46/300, Reconstruction Error: 0.3727
# Iteration 51/300, Reconstruction Error: 0.3771
# Iteration 56/300, Reconstruction Error: 0.3789
# Iteration 61/300, Reconstruction Error: 0.3788
# Iteration 66/300, Reconstruction Error: 0.3772
# Iteration 71/300, Reconstruction Error: 0.3749
# Iteration 76/300, Reconstruction Error: 0.3722
# Iteration 81/300, Reconstruction Error: 0.3695
# Iteration 86/300, Reconstruction Error: 0.3670
# Iteration 91/300, Reconstruction Error: 0.3649
# Iteration 96/300, Reconstruction Error: 0.3632
# Iteration 101/300, Reconstruction Error: 0.3620
# Iteration 106/300, Reconstruction Error: 0.3612
# Iteration 111/300, Reconstruction Error: 0.3607
# Iteration 116/300, Reconstruction Error: 0.3606
# Iteration 121/300, Reconstruction Error: 0.3607
# Iteration 126/300, Reconstruction Error: 0.3609
# Iteration 131/300, Reconstruction Error: 0.3612
# Iteration 136/300, Reconstruction Error: 0.3615
# Iteration 141/300, Reconstruction Error: 0.3619
# Iteration 146/300, Reconstruction Error: 0.3622
# Iteration 151/300, Reconstruction Error: 0.3624
# Iteration 156/300, Reconstruction Error: 0.3627
# Iteration 161/300, Reconstruction Error: 0.3628
# Iteration 166/300, Reconstruction Error: 0.3629
# Iteration 171/300, Reconstruction Error: 0.3630
# Iteration 176/300, Reconstruction Error: 0.3630
# Iteration 181/300, Reconstruction Error: 0.3630
# Iteration 186/300, Reconstruction Error: 0.3630
# Iteration 191/300, Reconstruction Error: 0.3629
# Iteration 196/300, Reconstruction Error: 0.3629
# Iteration 201/300, Reconstruction Error: 0.3628
# Iteration 206/300, Reconstruction Error: 0.3628
# Iteration 211/300, Reconstruction Error: 0.3628
# Iteration 216/300, Reconstruction Error: 0.3627
# Iteration 221/300, Reconstruction Error: 0.3627
# Iteration 226/300, Reconstruction Error: 0.3627
# Iteration 231/300, Reconstruction Error: 0.3627
# Iteration 236/300, Reconstruction Error: 0.3627
# Iteration 241/300, Reconstruction Error: 0.3627
# Iteration 246/300, Reconstruction Error: 0.3627
# Iteration 251/300, Reconstruction Error: 0.3627
# Iteration 256/300, Reconstruction Error: 0.3627
# Iteration 261/300, Reconstruction Error: 0.3627
# Iteration 266/300, Reconstruction Error: 0.3627
# Iteration 271/300, Reconstruction Error: 0.3627
# Iteration 276/300, Reconstruction Error: 0.3627
# Iteration 281/300, Reconstruction Error: 0.3627
# Iteration 286/300, Reconstruction Error: 0.3627
# Iteration 291/300, Reconstruction Error: 0.3627
# Iteration 296/300, Reconstruction Error: 0.3627
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 13999 (目標数13999)
# ||Dx||_1: 3854.8607 (制約は3854.8362304687503以下)
#
# --- レイヤー 'layer2.0.conv1' の処理を開始 ---
# Tensor shape: (128, 64, 3, 3), K1=7030.79560546875, K0=25292 (34.3%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.3143
# Iteration 11/300, Reconstruction Error: 0.3171
# Iteration 16/300, Reconstruction Error: 0.3240
# Iteration 21/300, Reconstruction Error: 0.3348
# Iteration 26/300, Reconstruction Error: 0.3481
# Iteration 31/300, Reconstruction Error: 0.3618
# Iteration 36/300, Reconstruction Error: 0.3742
# Iteration 41/300, Reconstruction Error: 0.3840
# Iteration 46/300, Reconstruction Error: 0.3908
# Iteration 51/300, Reconstruction Error: 0.3947
# Iteration 56/300, Reconstruction Error: 0.3961
# Iteration 61/300, Reconstruction Error: 0.3956
# Iteration 66/300, Reconstruction Error: 0.3938
# Iteration 71/300, Reconstruction Error: 0.3913
# Iteration 76/300, Reconstruction Error: 0.3885
# Iteration 81/300, Reconstruction Error: 0.3857
# Iteration 86/300, Reconstruction Error: 0.3833
# Iteration 91/300, Reconstruction Error: 0.3813
# Iteration 96/300, Reconstruction Error: 0.3797
# Iteration 101/300, Reconstruction Error: 0.3786
# Iteration 106/300, Reconstruction Error: 0.3779
# Iteration 111/300, Reconstruction Error: 0.3776
# Iteration 116/300, Reconstruction Error: 0.3775
# Iteration 121/300, Reconstruction Error: 0.3776
# Iteration 126/300, Reconstruction Error: 0.3779
# Iteration 131/300, Reconstruction Error: 0.3783
# Iteration 136/300, Reconstruction Error: 0.3786
# Iteration 141/300, Reconstruction Error: 0.3790
# Iteration 146/300, Reconstruction Error: 0.3793
# Iteration 151/300, Reconstruction Error: 0.3795
# Iteration 156/300, Reconstruction Error: 0.3797
# Iteration 161/300, Reconstruction Error: 0.3799
# Iteration 166/300, Reconstruction Error: 0.3799
# Iteration 171/300, Reconstruction Error: 0.3800
# Iteration 176/300, Reconstruction Error: 0.3800
# Iteration 181/300, Reconstruction Error: 0.3800
# Iteration 186/300, Reconstruction Error: 0.3799
# Iteration 191/300, Reconstruction Error: 0.3799
# Iteration 196/300, Reconstruction Error: 0.3798
# Iteration 201/300, Reconstruction Error: 0.3798
# Iteration 206/300, Reconstruction Error: 0.3797
# Iteration 211/300, Reconstruction Error: 0.3797
# Iteration 216/300, Reconstruction Error: 0.3797
# Iteration 221/300, Reconstruction Error: 0.3797
# Iteration 226/300, Reconstruction Error: 0.3797
# Iteration 231/300, Reconstruction Error: 0.3797
# Iteration 236/300, Reconstruction Error: 0.3797
# Iteration 241/300, Reconstruction Error: 0.3797
# Iteration 246/300, Reconstruction Error: 0.3797
# Iteration 251/300, Reconstruction Error: 0.3797
# Iteration 256/300, Reconstruction Error: 0.3797
# Iteration 261/300, Reconstruction Error: 0.3797
# Iteration 266/300, Reconstruction Error: 0.3797
# Iteration 271/300, Reconstruction Error: 0.3797
# Iteration 276/300, Reconstruction Error: 0.3797
# Iteration 281/300, Reconstruction Error: 0.3797
# Iteration 286/300, Reconstruction Error: 0.3797
# Iteration 291/300, Reconstruction Error: 0.3797
# Iteration 296/300, Reconstruction Error: 0.3797
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 73728
# ADMM後の重みテンソルの非ゼロの要素数: 25292 (目標数25292)
# ||Dx||_1: 7030.7992 (制約は7030.79560546875以下)
#
# --- レイヤー 'layer2.0.conv2' の処理を開始 ---
# Tensor shape: (128, 128, 3, 3), K1=10262.705273437501, K0=38547 (26.1%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.3977
# Iteration 11/300, Reconstruction Error: 0.3993
# Iteration 16/300, Reconstruction Error: 0.4031
# Iteration 21/300, Reconstruction Error: 0.4091
# Iteration 26/300, Reconstruction Error: 0.4166
# Iteration 31/300, Reconstruction Error: 0.4245
# Iteration 36/300, Reconstruction Error: 0.4317
# Iteration 41/300, Reconstruction Error: 0.4376
# Iteration 46/300, Reconstruction Error: 0.4418
# Iteration 51/300, Reconstruction Error: 0.4443
# Iteration 56/300, Reconstruction Error: 0.4452
# Iteration 61/300, Reconstruction Error: 0.4450
# Iteration 66/300, Reconstruction Error: 0.4441
# Iteration 71/300, Reconstruction Error: 0.4426
# Iteration 76/300, Reconstruction Error: 0.4409
# Iteration 81/300, Reconstruction Error: 0.4393
# Iteration 86/300, Reconstruction Error: 0.4378
# Iteration 91/300, Reconstruction Error: 0.4366
# Iteration 96/300, Reconstruction Error: 0.4356
# Iteration 101/300, Reconstruction Error: 0.4349
# Iteration 106/300, Reconstruction Error: 0.4345
# Iteration 111/300, Reconstruction Error: 0.4342
# Iteration 116/300, Reconstruction Error: 0.4342
# Iteration 121/300, Reconstruction Error: 0.4342
# Iteration 126/300, Reconstruction Error: 0.4344
# Iteration 131/300, Reconstruction Error: 0.4345
# Iteration 136/300, Reconstruction Error: 0.4347
# Iteration 141/300, Reconstruction Error: 0.4350
# Iteration 146/300, Reconstruction Error: 0.4351
# Iteration 151/300, Reconstruction Error: 0.4353
# Iteration 156/300, Reconstruction Error: 0.4354
# Iteration 161/300, Reconstruction Error: 0.4355
# Iteration 166/300, Reconstruction Error: 0.4356
# Iteration 171/300, Reconstruction Error: 0.4356
# Iteration 176/300, Reconstruction Error: 0.4356
# Iteration 181/300, Reconstruction Error: 0.4356
# Iteration 186/300, Reconstruction Error: 0.4356
# Iteration 191/300, Reconstruction Error: 0.4355
# Iteration 196/300, Reconstruction Error: 0.4355
# Iteration 201/300, Reconstruction Error: 0.4355
# Iteration 206/300, Reconstruction Error: 0.4355
# Iteration 211/300, Reconstruction Error: 0.4354
# Iteration 216/300, Reconstruction Error: 0.4354
# Iteration 221/300, Reconstruction Error: 0.4354
# Iteration 226/300, Reconstruction Error: 0.4354
# Iteration 231/300, Reconstruction Error: 0.4354
# Iteration 236/300, Reconstruction Error: 0.4354
# Iteration 241/300, Reconstruction Error: 0.4354
# Iteration 246/300, Reconstruction Error: 0.4354
# Iteration 251/300, Reconstruction Error: 0.4354
# Iteration 256/300, Reconstruction Error: 0.4354
# Iteration 261/300, Reconstruction Error: 0.4354
# Iteration 266/300, Reconstruction Error: 0.4354
# Iteration 271/300, Reconstruction Error: 0.4354
# Iteration 276/300, Reconstruction Error: 0.4354
# Iteration 281/300, Reconstruction Error: 0.4354
# Iteration 286/300, Reconstruction Error: 0.4354
# Iteration 291/300, Reconstruction Error: 0.4354
# Iteration 296/300, Reconstruction Error: 0.4354
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 147456
# ADMM後の重みテンソルの非ゼロの要素数: 38547 (目標数38547)
# ||Dx||_1: 10262.8597 (制約は10262.705273437501以下)
#
# --- レイヤー 'layer2.0.downsample.0' の処理を開始 ---
# Tensor shape: (128, 64, 1, 1), K1=893.0490600585938, K0=3840 (46.9%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.1730
# Iteration 11/300, Reconstruction Error: 0.1733
# Iteration 16/300, Reconstruction Error: 0.1740
# Iteration 21/300, Reconstruction Error: 0.1753
# Iteration 26/300, Reconstruction Error: 0.1772
# Iteration 31/300, Reconstruction Error: 0.1794
# Iteration 36/300, Reconstruction Error: 0.1818
# Iteration 41/300, Reconstruction Error: 0.1843
# Iteration 46/300, Reconstruction Error: 0.1866
# Iteration 51/300, Reconstruction Error: 0.1887
# Iteration 56/300, Reconstruction Error: 0.1905
# Iteration 61/300, Reconstruction Error: 0.1919
# Iteration 66/300, Reconstruction Error: 0.1930
# Iteration 71/300, Reconstruction Error: 0.1938
# Iteration 76/300, Reconstruction Error: 0.1944
# Iteration 81/300, Reconstruction Error: 0.1947
# Iteration 86/300, Reconstruction Error: 0.1949
# Iteration 91/300, Reconstruction Error: 0.1949
# Iteration 96/300, Reconstruction Error: 0.1948
# Iteration 101/300, Reconstruction Error: 0.1946
# Iteration 106/300, Reconstruction Error: 0.1945
# Iteration 111/300, Reconstruction Error: 0.1942
# Iteration 116/300, Reconstruction Error: 0.1940
# Iteration 121/300, Reconstruction Error: 0.1938
# Iteration 126/300, Reconstruction Error: 0.1937
# Iteration 131/300, Reconstruction Error: 0.1935
# Iteration 136/300, Reconstruction Error: 0.1934
# Iteration 141/300, Reconstruction Error: 0.1933
# Iteration 146/300, Reconstruction Error: 0.1932
# Iteration 151/300, Reconstruction Error: 0.1931
# Iteration 156/300, Reconstruction Error: 0.1931
# Iteration 161/300, Reconstruction Error: 0.1930
# Iteration 166/300, Reconstruction Error: 0.1930
# Iteration 171/300, Reconstruction Error: 0.1930
# Iteration 176/300, Reconstruction Error: 0.1930
# Iteration 181/300, Reconstruction Error: 0.1930
# Iteration 186/300, Reconstruction Error: 0.1930
# Iteration 191/300, Reconstruction Error: 0.1930
# Iteration 196/300, Reconstruction Error: 0.1930
# Iteration 201/300, Reconstruction Error: 0.1930
# Iteration 206/300, Reconstruction Error: 0.1930
# Iteration 211/300, Reconstruction Error: 0.1930
# Iteration 216/300, Reconstruction Error: 0.1930
# Iteration 221/300, Reconstruction Error: 0.1930
# Iteration 226/300, Reconstruction Error: 0.1930
# Iteration 231/300, Reconstruction Error: 0.1930
# Iteration 236/300, Reconstruction Error: 0.1930
# Iteration 241/300, Reconstruction Error: 0.1930
# Iteration 246/300, Reconstruction Error: 0.1930
# Iteration 251/300, Reconstruction Error: 0.1931
# Iteration 256/300, Reconstruction Error: 0.1931
# Iteration 261/300, Reconstruction Error: 0.1931
# Iteration 266/300, Reconstruction Error: 0.1931
# Iteration 271/300, Reconstruction Error: 0.1931
# Iteration 276/300, Reconstruction Error: 0.1931
# Iteration 281/300, Reconstruction Error: 0.1931
# Iteration 286/300, Reconstruction Error: 0.1931
# Iteration 291/300, Reconstruction Error: 0.1931
# Iteration 296/300, Reconstruction Error: 0.1931
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 8192
# ADMM後の重みテンソルの非ゼロの要素数: 3840 (目標数3840)
# ||Dx||_1: 893.0014 (制約は893.0490600585938以下)
#
# --- レイヤー 'layer2.1.conv1' の処理を開始 ---
# Tensor shape: (128, 128, 3, 3), K1=10595.213085937501, K0=39991 (27.1%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.3937
# Iteration 11/300, Reconstruction Error: 0.3958
# Iteration 16/300, Reconstruction Error: 0.4010
# Iteration 21/300, Reconstruction Error: 0.4091
# Iteration 26/300, Reconstruction Error: 0.4190
# Iteration 31/300, Reconstruction Error: 0.4293
# Iteration 36/300, Reconstruction Error: 0.4386
# Iteration 41/300, Reconstruction Error: 0.4458
# Iteration 46/300, Reconstruction Error: 0.4507
# Iteration 51/300, Reconstruction Error: 0.4534
# Iteration 56/300, Reconstruction Error: 0.4541
# Iteration 61/300, Reconstruction Error: 0.4534
# Iteration 66/300, Reconstruction Error: 0.4518
# Iteration 71/300, Reconstruction Error: 0.4496
# Iteration 76/300, Reconstruction Error: 0.4474
# Iteration 81/300, Reconstruction Error: 0.4452
# Iteration 86/300, Reconstruction Error: 0.4433
# Iteration 91/300, Reconstruction Error: 0.4418
# Iteration 96/300, Reconstruction Error: 0.4407
# Iteration 101/300, Reconstruction Error: 0.4400
# Iteration 106/300, Reconstruction Error: 0.4395
# Iteration 111/300, Reconstruction Error: 0.4393
# Iteration 116/300, Reconstruction Error: 0.4394
# Iteration 121/300, Reconstruction Error: 0.4395
# Iteration 126/300, Reconstruction Error: 0.4398
# Iteration 131/300, Reconstruction Error: 0.4401
# Iteration 136/300, Reconstruction Error: 0.4404
# Iteration 141/300, Reconstruction Error: 0.4407
# Iteration 146/300, Reconstruction Error: 0.4409
# Iteration 151/300, Reconstruction Error: 0.4411
# Iteration 156/300, Reconstruction Error: 0.4412
# Iteration 161/300, Reconstruction Error: 0.4413
# Iteration 166/300, Reconstruction Error: 0.4413
# Iteration 171/300, Reconstruction Error: 0.4413
# Iteration 176/300, Reconstruction Error: 0.4413
# Iteration 181/300, Reconstruction Error: 0.4413
# Iteration 186/300, Reconstruction Error: 0.4413
# Iteration 191/300, Reconstruction Error: 0.4412
# Iteration 196/300, Reconstruction Error: 0.4412
# Iteration 201/300, Reconstruction Error: 0.4411
# Iteration 206/300, Reconstruction Error: 0.4411
# Iteration 211/300, Reconstruction Error: 0.4411
# Iteration 216/300, Reconstruction Error: 0.4411
# Iteration 221/300, Reconstruction Error: 0.4411
# Iteration 226/300, Reconstruction Error: 0.4411
# Iteration 231/300, Reconstruction Error: 0.4411
# Iteration 236/300, Reconstruction Error: 0.4411
# Iteration 241/300, Reconstruction Error: 0.4411
# Iteration 246/300, Reconstruction Error: 0.4411
# Iteration 251/300, Reconstruction Error: 0.4411
# Iteration 256/300, Reconstruction Error: 0.4411
# Iteration 261/300, Reconstruction Error: 0.4411
# Iteration 266/300, Reconstruction Error: 0.4411
# Iteration 271/300, Reconstruction Error: 0.4411
# Iteration 276/300, Reconstruction Error: 0.4411
# Iteration 281/300, Reconstruction Error: 0.4411
# Iteration 286/300, Reconstruction Error: 0.4411
# Iteration 291/300, Reconstruction Error: 0.4411
# Iteration 296/300, Reconstruction Error: 0.4411
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 147456
# ADMM後の重みテンソルの非ゼロの要素数: 39991 (目標数39991)
# ||Dx||_1: 10595.1731 (制約は10595.213085937501以下)
#
# --- レイヤー 'layer2.1.conv2' の処理を開始 ---
# Tensor shape: (128, 128, 3, 3), K1=8684.54033203125, K0=36187 (24.5%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.4554
# Iteration 11/300, Reconstruction Error: 0.4571
# Iteration 16/300, Reconstruction Error: 0.4612
# Iteration 21/300, Reconstruction Error: 0.4678
# Iteration 26/300, Reconstruction Error: 0.4759
# Iteration 31/300, Reconstruction Error: 0.4844
# Iteration 36/300, Reconstruction Error: 0.4922
# Iteration 41/300, Reconstruction Error: 0.4985
# Iteration 46/300, Reconstruction Error: 0.5029
# Iteration 51/300, Reconstruction Error: 0.5055
# Iteration 56/300, Reconstruction Error: 0.5065
# Iteration 61/300, Reconstruction Error: 0.5062
# Iteration 66/300, Reconstruction Error: 0.5051
# Iteration 71/300, Reconstruction Error: 0.5034
# Iteration 76/300, Reconstruction Error: 0.5016
# Iteration 81/300, Reconstruction Error: 0.4999
# Iteration 86/300, Reconstruction Error: 0.4983
# Iteration 91/300, Reconstruction Error: 0.4970
# Iteration 96/300, Reconstruction Error: 0.4959
# Iteration 101/300, Reconstruction Error: 0.4952
# Iteration 106/300, Reconstruction Error: 0.4947
# Iteration 111/300, Reconstruction Error: 0.4945
# Iteration 116/300, Reconstruction Error: 0.4944
# Iteration 121/300, Reconstruction Error: 0.4945
# Iteration 126/300, Reconstruction Error: 0.4947
# Iteration 131/300, Reconstruction Error: 0.4949
# Iteration 136/300, Reconstruction Error: 0.4951
# Iteration 141/300, Reconstruction Error: 0.4953
# Iteration 146/300, Reconstruction Error: 0.4955
# Iteration 151/300, Reconstruction Error: 0.4957
# Iteration 156/300, Reconstruction Error: 0.4958
# Iteration 161/300, Reconstruction Error: 0.4959
# Iteration 166/300, Reconstruction Error: 0.4960
# Iteration 171/300, Reconstruction Error: 0.4960
# Iteration 176/300, Reconstruction Error: 0.4960
# Iteration 181/300, Reconstruction Error: 0.4960
# Iteration 186/300, Reconstruction Error: 0.4960
# Iteration 191/300, Reconstruction Error: 0.4959
# Iteration 196/300, Reconstruction Error: 0.4959
# Iteration 201/300, Reconstruction Error: 0.4959
# Iteration 206/300, Reconstruction Error: 0.4959
# Iteration 211/300, Reconstruction Error: 0.4958
# Iteration 216/300, Reconstruction Error: 0.4958
# Iteration 221/300, Reconstruction Error: 0.4958
# Iteration 226/300, Reconstruction Error: 0.4958
# Iteration 231/300, Reconstruction Error: 0.4958
# Iteration 236/300, Reconstruction Error: 0.4958
# Iteration 241/300, Reconstruction Error: 0.4958
# Iteration 246/300, Reconstruction Error: 0.4958
# Iteration 251/300, Reconstruction Error: 0.4958
# Iteration 256/300, Reconstruction Error: 0.4958
# Iteration 261/300, Reconstruction Error: 0.4958
# Iteration 266/300, Reconstruction Error: 0.4958
# Iteration 271/300, Reconstruction Error: 0.4958
# Iteration 276/300, Reconstruction Error: 0.4958
# Iteration 281/300, Reconstruction Error: 0.4958
# Iteration 286/300, Reconstruction Error: 0.4958
# Iteration 291/300, Reconstruction Error: 0.4958
# Iteration 296/300, Reconstruction Error: 0.4958
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 147456
# ADMM後の重みテンソルの非ゼロの要素数: 36187 (目標数36187)
# ||Dx||_1: 8684.6075 (制約は8684.54033203125以下)
#
# --- レイヤー 'layer3.0.conv1' の処理を開始 ---
# Tensor shape: (256, 128, 3, 3), K1=14299.4654296875, K0=63798 (21.6%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.4692
# Iteration 11/300, Reconstruction Error: 0.4704
# Iteration 16/300, Reconstruction Error: 0.4733
# Iteration 21/300, Reconstruction Error: 0.4779
# Iteration 26/300, Reconstruction Error: 0.4837
# Iteration 31/300, Reconstruction Error: 0.4899
# Iteration 36/300, Reconstruction Error: 0.4959
# Iteration 41/300, Reconstruction Error: 0.5010
# Iteration 46/300, Reconstruction Error: 0.5049
# Iteration 51/300, Reconstruction Error: 0.5076
# Iteration 56/300, Reconstruction Error: 0.5090
# Iteration 61/300, Reconstruction Error: 0.5094
# Iteration 66/300, Reconstruction Error: 0.5091
# Iteration 71/300, Reconstruction Error: 0.5083
# Iteration 76/300, Reconstruction Error: 0.5073
# Iteration 81/300, Reconstruction Error: 0.5061
# Iteration 86/300, Reconstruction Error: 0.5049
# Iteration 91/300, Reconstruction Error: 0.5039
# Iteration 96/300, Reconstruction Error: 0.5030
# Iteration 101/300, Reconstruction Error: 0.5023
# Iteration 106/300, Reconstruction Error: 0.5018
# Iteration 111/300, Reconstruction Error: 0.5014
# Iteration 116/300, Reconstruction Error: 0.5012
# Iteration 121/300, Reconstruction Error: 0.5011
# Iteration 126/300, Reconstruction Error: 0.5011
# Iteration 131/300, Reconstruction Error: 0.5012
# Iteration 136/300, Reconstruction Error: 0.5013
# Iteration 141/300, Reconstruction Error: 0.5014
# Iteration 146/300, Reconstruction Error: 0.5015
# Iteration 151/300, Reconstruction Error: 0.5017
# Iteration 156/300, Reconstruction Error: 0.5018
# Iteration 161/300, Reconstruction Error: 0.5019
# Iteration 166/300, Reconstruction Error: 0.5020
# Iteration 171/300, Reconstruction Error: 0.5020
# Iteration 176/300, Reconstruction Error: 0.5020
# Iteration 181/300, Reconstruction Error: 0.5021
# Iteration 186/300, Reconstruction Error: 0.5021
# Iteration 191/300, Reconstruction Error: 0.5021
# Iteration 196/300, Reconstruction Error: 0.5021
# Iteration 201/300, Reconstruction Error: 0.5020
# Iteration 206/300, Reconstruction Error: 0.5020
# Iteration 211/300, Reconstruction Error: 0.5020
# Iteration 216/300, Reconstruction Error: 0.5020
# Iteration 221/300, Reconstruction Error: 0.5020
# Iteration 226/300, Reconstruction Error: 0.5020
# Iteration 231/300, Reconstruction Error: 0.5020
# Iteration 236/300, Reconstruction Error: 0.5020
# Iteration 241/300, Reconstruction Error: 0.5020
# Iteration 246/300, Reconstruction Error: 0.5020
# Iteration 251/300, Reconstruction Error: 0.5020
# Iteration 256/300, Reconstruction Error: 0.5020
# Iteration 261/300, Reconstruction Error: 0.5020
# Iteration 266/300, Reconstruction Error: 0.5020
# Iteration 271/300, Reconstruction Error: 0.5020
# Iteration 276/300, Reconstruction Error: 0.5020
# Iteration 281/300, Reconstruction Error: 0.5020
# Iteration 286/300, Reconstruction Error: 0.5020
# Iteration 291/300, Reconstruction Error: 0.5020
# Iteration 296/300, Reconstruction Error: 0.5020
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 294912
# ADMM後の重みテンソルの非ゼロの要素数: 63798 (目標数63798)
# ||Dx||_1: 14299.9521 (制約は14299.4654296875以下)
#
# --- レイヤー 'layer3.0.conv2' の処理を開始 ---
# Tensor shape: (256, 256, 3, 3), K1=23188.751367187502, K0=100196 (17.0%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.5456
# Iteration 11/300, Reconstruction Error: 0.5468
# Iteration 16/300, Reconstruction Error: 0.5496
# Iteration 21/300, Reconstruction Error: 0.5540
# Iteration 26/300, Reconstruction Error: 0.5594
# Iteration 31/300, Reconstruction Error: 0.5651
# Iteration 36/300, Reconstruction Error: 0.5703
# Iteration 41/300, Reconstruction Error: 0.5745
# Iteration 46/300, Reconstruction Error: 0.5774
# Iteration 51/300, Reconstruction Error: 0.5791
# Iteration 56/300, Reconstruction Error: 0.5797
# Iteration 61/300, Reconstruction Error: 0.5795
# Iteration 66/300, Reconstruction Error: 0.5787
# Iteration 71/300, Reconstruction Error: 0.5776
# Iteration 76/300, Reconstruction Error: 0.5764
# Iteration 81/300, Reconstruction Error: 0.5752
# Iteration 86/300, Reconstruction Error: 0.5741
# Iteration 91/300, Reconstruction Error: 0.5732
# Iteration 96/300, Reconstruction Error: 0.5725
# Iteration 101/300, Reconstruction Error: 0.5720
# Iteration 106/300, Reconstruction Error: 0.5717
# Iteration 111/300, Reconstruction Error: 0.5716
# Iteration 116/300, Reconstruction Error: 0.5715
# Iteration 121/300, Reconstruction Error: 0.5716
# Iteration 126/300, Reconstruction Error: 0.5717
# Iteration 131/300, Reconstruction Error: 0.5718
# Iteration 136/300, Reconstruction Error: 0.5720
# Iteration 141/300, Reconstruction Error: 0.5721
# Iteration 146/300, Reconstruction Error: 0.5723
# Iteration 151/300, Reconstruction Error: 0.5724
# Iteration 156/300, Reconstruction Error: 0.5725
# Iteration 161/300, Reconstruction Error: 0.5725
# Iteration 166/300, Reconstruction Error: 0.5726
# Iteration 171/300, Reconstruction Error: 0.5726
# Iteration 176/300, Reconstruction Error: 0.5726
# Iteration 181/300, Reconstruction Error: 0.5726
# Iteration 186/300, Reconstruction Error: 0.5726
# Iteration 191/300, Reconstruction Error: 0.5726
# Iteration 196/300, Reconstruction Error: 0.5725
# Iteration 201/300, Reconstruction Error: 0.5725
# Iteration 206/300, Reconstruction Error: 0.5725
# Iteration 211/300, Reconstruction Error: 0.5725
# Iteration 216/300, Reconstruction Error: 0.5725
# Iteration 221/300, Reconstruction Error: 0.5725
# Iteration 226/300, Reconstruction Error: 0.5725
# Iteration 231/300, Reconstruction Error: 0.5725
# Iteration 236/300, Reconstruction Error: 0.5725
# Iteration 241/300, Reconstruction Error: 0.5725
# Iteration 246/300, Reconstruction Error: 0.5725
# Iteration 251/300, Reconstruction Error: 0.5725
# Iteration 256/300, Reconstruction Error: 0.5725
# Iteration 261/300, Reconstruction Error: 0.5725
# Iteration 266/300, Reconstruction Error: 0.5725
# Iteration 271/300, Reconstruction Error: 0.5725
# Iteration 276/300, Reconstruction Error: 0.5725
# Iteration 281/300, Reconstruction Error: 0.5725
# Iteration 286/300, Reconstruction Error: 0.5725
# Iteration 291/300, Reconstruction Error: 0.5725
# Iteration 296/300, Reconstruction Error: 0.5725
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 589824
# ADMM後の重みテンソルの非ゼロの要素数: 100196 (目標数100196)
# ||Dx||_1: 23188.9289 (制約は23188.751367187502以下)
#
# --- レイヤー 'layer3.0.downsample.0' の処理を開始 ---
# Tensor shape: (256, 128, 1, 1), K1=1457.6010864257812, K0=8628 (26.3%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.4121
# Iteration 11/300, Reconstruction Error: 0.4122
# Iteration 16/300, Reconstruction Error: 0.4126
# Iteration 21/300, Reconstruction Error: 0.4133
# Iteration 26/300, Reconstruction Error: 0.4141
# Iteration 31/300, Reconstruction Error: 0.4152
# Iteration 36/300, Reconstruction Error: 0.4163
# Iteration 41/300, Reconstruction Error: 0.4174
# Iteration 46/300, Reconstruction Error: 0.4184
# Iteration 51/300, Reconstruction Error: 0.4193
# Iteration 56/300, Reconstruction Error: 0.4201
# Iteration 61/300, Reconstruction Error: 0.4207
# Iteration 66/300, Reconstruction Error: 0.4212
# Iteration 71/300, Reconstruction Error: 0.4215
# Iteration 76/300, Reconstruction Error: 0.4217
# Iteration 81/300, Reconstruction Error: 0.4218
# Iteration 86/300, Reconstruction Error: 0.4218
# Iteration 91/300, Reconstruction Error: 0.4217
# Iteration 96/300, Reconstruction Error: 0.4217
# Iteration 101/300, Reconstruction Error: 0.4216
# Iteration 106/300, Reconstruction Error: 0.4215
# Iteration 111/300, Reconstruction Error: 0.4213
# Iteration 116/300, Reconstruction Error: 0.4212
# Iteration 121/300, Reconstruction Error: 0.4211
# Iteration 126/300, Reconstruction Error: 0.4211
# Iteration 131/300, Reconstruction Error: 0.4210
# Iteration 136/300, Reconstruction Error: 0.4209
# Iteration 141/300, Reconstruction Error: 0.4209
# Iteration 146/300, Reconstruction Error: 0.4208
# Iteration 151/300, Reconstruction Error: 0.4208
# Iteration 156/300, Reconstruction Error: 0.4208
# Iteration 161/300, Reconstruction Error: 0.4208
# Iteration 166/300, Reconstruction Error: 0.4208
# Iteration 171/300, Reconstruction Error: 0.4208
# Iteration 176/300, Reconstruction Error: 0.4208
# Iteration 181/300, Reconstruction Error: 0.4208
# Iteration 186/300, Reconstruction Error: 0.4208
# Iteration 191/300, Reconstruction Error: 0.4208
# Iteration 196/300, Reconstruction Error: 0.4208
# Iteration 201/300, Reconstruction Error: 0.4208
# Iteration 206/300, Reconstruction Error: 0.4208
# Iteration 211/300, Reconstruction Error: 0.4208
# Iteration 216/300, Reconstruction Error: 0.4208
# Iteration 221/300, Reconstruction Error: 0.4208
# Iteration 226/300, Reconstruction Error: 0.4208
# Iteration 231/300, Reconstruction Error: 0.4208
# Iteration 236/300, Reconstruction Error: 0.4208
# Iteration 241/300, Reconstruction Error: 0.4208
# Iteration 246/300, Reconstruction Error: 0.4208
# Iteration 251/300, Reconstruction Error: 0.4208
# Iteration 256/300, Reconstruction Error: 0.4208
# Iteration 261/300, Reconstruction Error: 0.4208
# Iteration 266/300, Reconstruction Error: 0.4208
# Iteration 271/300, Reconstruction Error: 0.4208
# Iteration 276/300, Reconstruction Error: 0.4208
# Iteration 281/300, Reconstruction Error: 0.4208
# Iteration 286/300, Reconstruction Error: 0.4208
# Iteration 291/300, Reconstruction Error: 0.4208
# Iteration 296/300, Reconstruction Error: 0.4208
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 32768
# ADMM後の重みテンソルの非ゼロの要素数: 8628 (目標数8628)
# ||Dx||_1: 1457.5565 (制約は1457.6010864257812以下)
#
# --- レイヤー 'layer3.1.conv1' の処理を開始 ---
# Tensor shape: (256, 256, 3, 3), K1=18336.807421875, K0=80752 (13.7%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.6073
# Iteration 11/300, Reconstruction Error: 0.6086
# Iteration 16/300, Reconstruction Error: 0.6116
# Iteration 21/300, Reconstruction Error: 0.6162
# Iteration 26/300, Reconstruction Error: 0.6219
# Iteration 31/300, Reconstruction Error: 0.6277
# Iteration 36/300, Reconstruction Error: 0.6329
# Iteration 41/300, Reconstruction Error: 0.6369
# Iteration 46/300, Reconstruction Error: 0.6396
# Iteration 51/300, Reconstruction Error: 0.6409
# Iteration 56/300, Reconstruction Error: 0.6411
# Iteration 61/300, Reconstruction Error: 0.6406
# Iteration 66/300, Reconstruction Error: 0.6395
# Iteration 71/300, Reconstruction Error: 0.6381
# Iteration 76/300, Reconstruction Error: 0.6368
# Iteration 81/300, Reconstruction Error: 0.6355
# Iteration 86/300, Reconstruction Error: 0.6345
# Iteration 91/300, Reconstruction Error: 0.6336
# Iteration 96/300, Reconstruction Error: 0.6330
# Iteration 101/300, Reconstruction Error: 0.6326
# Iteration 106/300, Reconstruction Error: 0.6324
# Iteration 111/300, Reconstruction Error: 0.6324
# Iteration 116/300, Reconstruction Error: 0.6324
# Iteration 121/300, Reconstruction Error: 0.6325
# Iteration 126/300, Reconstruction Error: 0.6327
# Iteration 131/300, Reconstruction Error: 0.6329
# Iteration 136/300, Reconstruction Error: 0.6331
# Iteration 141/300, Reconstruction Error: 0.6332
# Iteration 146/300, Reconstruction Error: 0.6334
# Iteration 151/300, Reconstruction Error: 0.6335
# Iteration 156/300, Reconstruction Error: 0.6335
# Iteration 161/300, Reconstruction Error: 0.6336
# Iteration 166/300, Reconstruction Error: 0.6336
# Iteration 171/300, Reconstruction Error: 0.6336
# Iteration 176/300, Reconstruction Error: 0.6336
# Iteration 181/300, Reconstruction Error: 0.6335
# Iteration 186/300, Reconstruction Error: 0.6335
# Iteration 191/300, Reconstruction Error: 0.6335
# Iteration 196/300, Reconstruction Error: 0.6335
# Iteration 201/300, Reconstruction Error: 0.6334
# Iteration 206/300, Reconstruction Error: 0.6334
# Iteration 211/300, Reconstruction Error: 0.6334
# Iteration 216/300, Reconstruction Error: 0.6334
# Iteration 221/300, Reconstruction Error: 0.6334
# Iteration 226/300, Reconstruction Error: 0.6334
# Iteration 231/300, Reconstruction Error: 0.6334
# Iteration 236/300, Reconstruction Error: 0.6334
# Iteration 241/300, Reconstruction Error: 0.6334
# Iteration 246/300, Reconstruction Error: 0.6334
# Iteration 251/300, Reconstruction Error: 0.6334
# Iteration 256/300, Reconstruction Error: 0.6334
# Iteration 261/300, Reconstruction Error: 0.6334
# Iteration 266/300, Reconstruction Error: 0.6334
# Iteration 271/300, Reconstruction Error: 0.6334
# Iteration 276/300, Reconstruction Error: 0.6334
# Iteration 281/300, Reconstruction Error: 0.6334
# Iteration 286/300, Reconstruction Error: 0.6334
# Iteration 291/300, Reconstruction Error: 0.6334
# Iteration 296/300, Reconstruction Error: 0.6334
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 589824
# ADMM後の重みテンソルの非ゼロの要素数: 80752 (目標数80752)
# ||Dx||_1: 18336.7033 (制約は18336.807421875以下)
#
# --- レイヤー 'layer3.1.conv2' の処理を開始 ---
# Tensor shape: (256, 256, 3, 3), K1=15043.805859375001, K0=69348 (11.8%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.6483
# Iteration 11/300, Reconstruction Error: 0.6494
# Iteration 16/300, Reconstruction Error: 0.6520
# Iteration 21/300, Reconstruction Error: 0.6559
# Iteration 26/300, Reconstruction Error: 0.6607
# Iteration 31/300, Reconstruction Error: 0.6656
# Iteration 36/300, Reconstruction Error: 0.6701
# Iteration 41/300, Reconstruction Error: 0.6736
# Iteration 46/300, Reconstruction Error: 0.6759
# Iteration 51/300, Reconstruction Error: 0.6772
# Iteration 56/300, Reconstruction Error: 0.6775
# Iteration 61/300, Reconstruction Error: 0.6771
# Iteration 66/300, Reconstruction Error: 0.6762
# Iteration 71/300, Reconstruction Error: 0.6752
# Iteration 76/300, Reconstruction Error: 0.6740
# Iteration 81/300, Reconstruction Error: 0.6730
# Iteration 86/300, Reconstruction Error: 0.6720
# Iteration 91/300, Reconstruction Error: 0.6713
# Iteration 96/300, Reconstruction Error: 0.6708
# Iteration 101/300, Reconstruction Error: 0.6704
# Iteration 106/300, Reconstruction Error: 0.6702
# Iteration 111/300, Reconstruction Error: 0.6701
# Iteration 116/300, Reconstruction Error: 0.6701
# Iteration 121/300, Reconstruction Error: 0.6702
# Iteration 126/300, Reconstruction Error: 0.6703
# Iteration 131/300, Reconstruction Error: 0.6705
# Iteration 136/300, Reconstruction Error: 0.6706
# Iteration 141/300, Reconstruction Error: 0.6707
# Iteration 146/300, Reconstruction Error: 0.6709
# Iteration 151/300, Reconstruction Error: 0.6710
# Iteration 156/300, Reconstruction Error: 0.6710
# Iteration 161/300, Reconstruction Error: 0.6711
# Iteration 166/300, Reconstruction Error: 0.6711
# Iteration 171/300, Reconstruction Error: 0.6711
# Iteration 176/300, Reconstruction Error: 0.6711
# Iteration 181/300, Reconstruction Error: 0.6711
# Iteration 186/300, Reconstruction Error: 0.6710
# Iteration 191/300, Reconstruction Error: 0.6710
# Iteration 196/300, Reconstruction Error: 0.6710
# Iteration 201/300, Reconstruction Error: 0.6710
# Iteration 206/300, Reconstruction Error: 0.6710
# Iteration 211/300, Reconstruction Error: 0.6710
# Iteration 216/300, Reconstruction Error: 0.6710
# Iteration 221/300, Reconstruction Error: 0.6709
# Iteration 226/300, Reconstruction Error: 0.6709
# Iteration 231/300, Reconstruction Error: 0.6709
# Iteration 236/300, Reconstruction Error: 0.6709
# Iteration 241/300, Reconstruction Error: 0.6709
# Iteration 246/300, Reconstruction Error: 0.6709
# Iteration 251/300, Reconstruction Error: 0.6710
# Iteration 256/300, Reconstruction Error: 0.6710
# Iteration 261/300, Reconstruction Error: 0.6710
# Iteration 266/300, Reconstruction Error: 0.6710
# Iteration 271/300, Reconstruction Error: 0.6710
# Iteration 276/300, Reconstruction Error: 0.6710
# Iteration 281/300, Reconstruction Error: 0.6710
# Iteration 286/300, Reconstruction Error: 0.6710
# Iteration 291/300, Reconstruction Error: 0.6710
# Iteration 296/300, Reconstruction Error: 0.6710
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 589824
# ADMM後の重みテンソルの非ゼロの要素数: 69348 (目標数69348)
# ||Dx||_1: 15043.8236 (制約は15043.805859375001以下)
#
# --- レイヤー 'layer4.0.conv1' の処理を開始 ---
# Tensor shape: (512, 256, 3, 3), K1=26372.309765625, K0=129215 (11.0%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.6818
# Iteration 11/300, Reconstruction Error: 0.6827
# Iteration 16/300, Reconstruction Error: 0.6848
# Iteration 21/300, Reconstruction Error: 0.6880
# Iteration 26/300, Reconstruction Error: 0.6920
# Iteration 31/300, Reconstruction Error: 0.6961
# Iteration 36/300, Reconstruction Error: 0.6999
# Iteration 41/300, Reconstruction Error: 0.7029
# Iteration 46/300, Reconstruction Error: 0.7051
# Iteration 51/300, Reconstruction Error: 0.7063
# Iteration 56/300, Reconstruction Error: 0.7067
# Iteration 61/300, Reconstruction Error: 0.7065
# Iteration 66/300, Reconstruction Error: 0.7059
# Iteration 71/300, Reconstruction Error: 0.7051
# Iteration 76/300, Reconstruction Error: 0.7042
# Iteration 81/300, Reconstruction Error: 0.7033
# Iteration 86/300, Reconstruction Error: 0.7025
# Iteration 91/300, Reconstruction Error: 0.7019
# Iteration 96/300, Reconstruction Error: 0.7014
# Iteration 101/300, Reconstruction Error: 0.7010
# Iteration 106/300, Reconstruction Error: 0.7008
# Iteration 111/300, Reconstruction Error: 0.7007
# Iteration 116/300, Reconstruction Error: 0.7006
# Iteration 121/300, Reconstruction Error: 0.7007
# Iteration 126/300, Reconstruction Error: 0.7008
# Iteration 131/300, Reconstruction Error: 0.7009
# Iteration 136/300, Reconstruction Error: 0.7010
# Iteration 141/300, Reconstruction Error: 0.7011
# Iteration 146/300, Reconstruction Error: 0.7012
# Iteration 151/300, Reconstruction Error: 0.7013
# Iteration 156/300, Reconstruction Error: 0.7013
# Iteration 161/300, Reconstruction Error: 0.7014
# Iteration 166/300, Reconstruction Error: 0.7014
# Iteration 171/300, Reconstruction Error: 0.7014
# Iteration 176/300, Reconstruction Error: 0.7014
# Iteration 181/300, Reconstruction Error: 0.7014
# Iteration 186/300, Reconstruction Error: 0.7014
# Iteration 191/300, Reconstruction Error: 0.7014
# Iteration 196/300, Reconstruction Error: 0.7014
# Iteration 201/300, Reconstruction Error: 0.7014
# Iteration 206/300, Reconstruction Error: 0.7013
# Iteration 211/300, Reconstruction Error: 0.7013
# Iteration 216/300, Reconstruction Error: 0.7013
# Iteration 221/300, Reconstruction Error: 0.7013
# Iteration 226/300, Reconstruction Error: 0.7013
# Iteration 231/300, Reconstruction Error: 0.7013
# Iteration 236/300, Reconstruction Error: 0.7013
# Iteration 241/300, Reconstruction Error: 0.7013
# Iteration 246/300, Reconstruction Error: 0.7013
# Iteration 251/300, Reconstruction Error: 0.7013
# Iteration 256/300, Reconstruction Error: 0.7013
# Iteration 261/300, Reconstruction Error: 0.7013
# Iteration 266/300, Reconstruction Error: 0.7013
# Iteration 271/300, Reconstruction Error: 0.7013
# Iteration 276/300, Reconstruction Error: 0.7013
# Iteration 281/300, Reconstruction Error: 0.7013
# Iteration 286/300, Reconstruction Error: 0.7013
# Iteration 291/300, Reconstruction Error: 0.7013
# Iteration 296/300, Reconstruction Error: 0.7013
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 1179648
# ADMM後の重みテンソルの非ゼロの要素数: 129215 (目標数129215)
# ||Dx||_1: 26372.5164 (制約は26372.309765625以下)
#
# --- レイヤー 'layer4.0.conv2' の処理を開始 ---
# Tensor shape: (512, 512, 3, 3), K1=38261.6859375, K0=169878 (7.2%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.7624
# Iteration 11/300, Reconstruction Error: 0.7631
# Iteration 16/300, Reconstruction Error: 0.7646
# Iteration 21/300, Reconstruction Error: 0.7668
# Iteration 26/300, Reconstruction Error: 0.7693
# Iteration 31/300, Reconstruction Error: 0.7718
# Iteration 36/300, Reconstruction Error: 0.7740
# Iteration 41/300, Reconstruction Error: 0.7756
# Iteration 46/300, Reconstruction Error: 0.7765
# Iteration 51/300, Reconstruction Error: 0.7769
# Iteration 56/300, Reconstruction Error: 0.7768
# Iteration 61/300, Reconstruction Error: 0.7764
# Iteration 66/300, Reconstruction Error: 0.7758
# Iteration 71/300, Reconstruction Error: 0.7751
# Iteration 76/300, Reconstruction Error: 0.7745
# Iteration 81/300, Reconstruction Error: 0.7740
# Iteration 86/300, Reconstruction Error: 0.7735
# Iteration 91/300, Reconstruction Error: 0.7732
# Iteration 96/300, Reconstruction Error: 0.7730
# Iteration 101/300, Reconstruction Error: 0.7729
# Iteration 106/300, Reconstruction Error: 0.7728
# Iteration 111/300, Reconstruction Error: 0.7729
# Iteration 116/300, Reconstruction Error: 0.7729
# Iteration 121/300, Reconstruction Error: 0.7730
# Iteration 126/300, Reconstruction Error: 0.7731
# Iteration 131/300, Reconstruction Error: 0.7732
# Iteration 136/300, Reconstruction Error: 0.7732
# Iteration 141/300, Reconstruction Error: 0.7733
# Iteration 146/300, Reconstruction Error: 0.7734
# Iteration 151/300, Reconstruction Error: 0.7734
# Iteration 156/300, Reconstruction Error: 0.7734
# Iteration 161/300, Reconstruction Error: 0.7734
# Iteration 166/300, Reconstruction Error: 0.7734
# Iteration 171/300, Reconstruction Error: 0.7734
# Iteration 176/300, Reconstruction Error: 0.7734
# Iteration 181/300, Reconstruction Error: 0.7734
# Iteration 186/300, Reconstruction Error: 0.7734
# Iteration 191/300, Reconstruction Error: 0.7734
# Iteration 196/300, Reconstruction Error: 0.7733
# Iteration 201/300, Reconstruction Error: 0.7733
# Iteration 206/300, Reconstruction Error: 0.7733
# Iteration 211/300, Reconstruction Error: 0.7733
# Iteration 216/300, Reconstruction Error: 0.7733
# Iteration 221/300, Reconstruction Error: 0.7733
# Iteration 226/300, Reconstruction Error: 0.7733
# Iteration 231/300, Reconstruction Error: 0.7733
# Iteration 236/300, Reconstruction Error: 0.7733
# Iteration 241/300, Reconstruction Error: 0.7733
# Iteration 246/300, Reconstruction Error: 0.7733
# Iteration 251/300, Reconstruction Error: 0.7733
# Iteration 256/300, Reconstruction Error: 0.7733
# Iteration 261/300, Reconstruction Error: 0.7733
# Iteration 266/300, Reconstruction Error: 0.7733
# Iteration 271/300, Reconstruction Error: 0.7733
# Iteration 276/300, Reconstruction Error: 0.7733
# Iteration 281/300, Reconstruction Error: 0.7733
# Iteration 286/300, Reconstruction Error: 0.7733
# Iteration 291/300, Reconstruction Error: 0.7733
# Iteration 296/300, Reconstruction Error: 0.7733
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 2359296
# ADMM後の重みテンソルの非ゼロの要素数: 169878 (目標数169878)
# ||Dx||_1: 38260.5908 (制約は38261.6859375以下)
#
# --- レイヤー 'layer4.0.downsample.0' の処理を開始 ---
# Tensor shape: (512, 256, 1, 1), K1=5838.152783203125, K0=35831 (27.3%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.4138
# Iteration 11/300, Reconstruction Error: 0.4140
# Iteration 16/300, Reconstruction Error: 0.4143
# Iteration 21/300, Reconstruction Error: 0.4149
# Iteration 26/300, Reconstruction Error: 0.4158
# Iteration 31/300, Reconstruction Error: 0.4167
# Iteration 36/300, Reconstruction Error: 0.4178
# Iteration 41/300, Reconstruction Error: 0.4188
# Iteration 46/300, Reconstruction Error: 0.4198
# Iteration 51/300, Reconstruction Error: 0.4206
# Iteration 56/300, Reconstruction Error: 0.4214
# Iteration 61/300, Reconstruction Error: 0.4219
# Iteration 66/300, Reconstruction Error: 0.4224
# Iteration 71/300, Reconstruction Error: 0.4227
# Iteration 76/300, Reconstruction Error: 0.4228
# Iteration 81/300, Reconstruction Error: 0.4229
# Iteration 86/300, Reconstruction Error: 0.4230
# Iteration 91/300, Reconstruction Error: 0.4229
# Iteration 96/300, Reconstruction Error: 0.4229
# Iteration 101/300, Reconstruction Error: 0.4228
# Iteration 106/300, Reconstruction Error: 0.4227
# Iteration 111/300, Reconstruction Error: 0.4226
# Iteration 116/300, Reconstruction Error: 0.4225
# Iteration 121/300, Reconstruction Error: 0.4224
# Iteration 126/300, Reconstruction Error: 0.4223
# Iteration 131/300, Reconstruction Error: 0.4222
# Iteration 136/300, Reconstruction Error: 0.4222
# Iteration 141/300, Reconstruction Error: 0.4221
# Iteration 146/300, Reconstruction Error: 0.4221
# Iteration 151/300, Reconstruction Error: 0.4221
# Iteration 156/300, Reconstruction Error: 0.4220
# Iteration 161/300, Reconstruction Error: 0.4220
# Iteration 166/300, Reconstruction Error: 0.4220
# Iteration 171/300, Reconstruction Error: 0.4220
# Iteration 176/300, Reconstruction Error: 0.4220
# Iteration 181/300, Reconstruction Error: 0.4220
# Iteration 186/300, Reconstruction Error: 0.4220
# Iteration 191/300, Reconstruction Error: 0.4220
# Iteration 196/300, Reconstruction Error: 0.4220
# Iteration 201/300, Reconstruction Error: 0.4220
# Iteration 206/300, Reconstruction Error: 0.4220
# Iteration 211/300, Reconstruction Error: 0.4221
# Iteration 216/300, Reconstruction Error: 0.4221
# Iteration 221/300, Reconstruction Error: 0.4221
# Iteration 226/300, Reconstruction Error: 0.4221
# Iteration 231/300, Reconstruction Error: 0.4221
# Iteration 236/300, Reconstruction Error: 0.4221
# Iteration 241/300, Reconstruction Error: 0.4221
# Iteration 246/300, Reconstruction Error: 0.4221
# Iteration 251/300, Reconstruction Error: 0.4221
# Iteration 256/300, Reconstruction Error: 0.4221
# Iteration 261/300, Reconstruction Error: 0.4221
# Iteration 266/300, Reconstruction Error: 0.4221
# Iteration 271/300, Reconstruction Error: 0.4221
# Iteration 276/300, Reconstruction Error: 0.4221
# Iteration 281/300, Reconstruction Error: 0.4221
# Iteration 286/300, Reconstruction Error: 0.4221
# Iteration 291/300, Reconstruction Error: 0.4221
# Iteration 296/300, Reconstruction Error: 0.4221
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 131072
# ADMM後の重みテンソルの非ゼロの要素数: 35831 (目標数35831)
# ||Dx||_1: 5837.7766 (制約は5838.152783203125以下)
#
# --- レイヤー 'layer4.1.conv1' の処理を開始 ---
# Tensor shape: (512, 512, 3, 3), K1=39879.2109375, K0=197308 (8.4%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.7551
# Iteration 11/300, Reconstruction Error: 0.7558
# Iteration 16/300, Reconstruction Error: 0.7571
# Iteration 21/300, Reconstruction Error: 0.7592
# Iteration 26/300, Reconstruction Error: 0.7616
# Iteration 31/300, Reconstruction Error: 0.7642
# Iteration 36/300, Reconstruction Error: 0.7664
# Iteration 41/300, Reconstruction Error: 0.7682
# Iteration 46/300, Reconstruction Error: 0.7694
# Iteration 51/300, Reconstruction Error: 0.7701
# Iteration 56/300, Reconstruction Error: 0.7703
# Iteration 61/300, Reconstruction Error: 0.7701
# Iteration 66/300, Reconstruction Error: 0.7697
# Iteration 71/300, Reconstruction Error: 0.7691
# Iteration 76/300, Reconstruction Error: 0.7685
# Iteration 81/300, Reconstruction Error: 0.7680
# Iteration 86/300, Reconstruction Error: 0.7675
# Iteration 91/300, Reconstruction Error: 0.7672
# Iteration 96/300, Reconstruction Error: 0.7669
# Iteration 101/300, Reconstruction Error: 0.7667
# Iteration 106/300, Reconstruction Error: 0.7665
# Iteration 111/300, Reconstruction Error: 0.7665
# Iteration 116/300, Reconstruction Error: 0.7665
# Iteration 121/300, Reconstruction Error: 0.7665
# Iteration 126/300, Reconstruction Error: 0.7666
# Iteration 131/300, Reconstruction Error: 0.7667
# Iteration 136/300, Reconstruction Error: 0.7667
# Iteration 141/300, Reconstruction Error: 0.7668
# Iteration 146/300, Reconstruction Error: 0.7669
# Iteration 151/300, Reconstruction Error: 0.7669
# Iteration 156/300, Reconstruction Error: 0.7669
# Iteration 161/300, Reconstruction Error: 0.7670
# Iteration 166/300, Reconstruction Error: 0.7670
# Iteration 171/300, Reconstruction Error: 0.7670
# Iteration 176/300, Reconstruction Error: 0.7670
# Iteration 181/300, Reconstruction Error: 0.7670
# Iteration 186/300, Reconstruction Error: 0.7670
# Iteration 191/300, Reconstruction Error: 0.7670
# Iteration 196/300, Reconstruction Error: 0.7669
# Iteration 201/300, Reconstruction Error: 0.7669
# Iteration 206/300, Reconstruction Error: 0.7669
# Iteration 211/300, Reconstruction Error: 0.7669
# Iteration 216/300, Reconstruction Error: 0.7669
# Iteration 221/300, Reconstruction Error: 0.7669
# Iteration 226/300, Reconstruction Error: 0.7669
# Iteration 231/300, Reconstruction Error: 0.7669
# Iteration 236/300, Reconstruction Error: 0.7669
# Iteration 241/300, Reconstruction Error: 0.7669
# Iteration 246/300, Reconstruction Error: 0.7669
# Iteration 251/300, Reconstruction Error: 0.7669
# Iteration 256/300, Reconstruction Error: 0.7669
# Iteration 261/300, Reconstruction Error: 0.7669
# Iteration 266/300, Reconstruction Error: 0.7669
# Iteration 271/300, Reconstruction Error: 0.7669
# Iteration 276/300, Reconstruction Error: 0.7669
# Iteration 281/300, Reconstruction Error: 0.7669
# Iteration 286/300, Reconstruction Error: 0.7669
# Iteration 291/300, Reconstruction Error: 0.7669
# Iteration 296/300, Reconstruction Error: 0.7669
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 2359296
# ADMM後の重みテンソルの非ゼロの要素数: 197308 (目標数197308)
# ||Dx||_1: 39879.1902 (制約は39879.2109375以下)
#
# --- レイヤー 'layer4.1.conv2' の処理を開始 ---
# Tensor shape: (512, 512, 3, 3), K1=10035.70927734375, K0=57402 (2.4%)
# Iteration 1/300, Reconstruction Error: 0.0000
# Iteration 6/300, Reconstruction Error: 0.8730
# Iteration 11/300, Reconstruction Error: 0.8732
# Iteration 16/300, Reconstruction Error: 0.8735
# Iteration 21/300, Reconstruction Error: 0.8740
# Iteration 26/300, Reconstruction Error: 0.8746
# Iteration 31/300, Reconstruction Error: 0.8752
# Iteration 36/300, Reconstruction Error: 0.8759
# Iteration 41/300, Reconstruction Error: 0.8764
# Iteration 46/300, Reconstruction Error: 0.8768
# Iteration 51/300, Reconstruction Error: 0.8771
# Iteration 56/300, Reconstruction Error: 0.8773
# Iteration 61/300, Reconstruction Error: 0.8773
# Iteration 66/300, Reconstruction Error: 0.8773
# Iteration 71/300, Reconstruction Error: 0.8773
# Iteration 76/300, Reconstruction Error: 0.8772
# Iteration 81/300, Reconstruction Error: 0.8771
# Iteration 86/300, Reconstruction Error: 0.8770
# Iteration 91/300, Reconstruction Error: 0.8769
# Iteration 96/300, Reconstruction Error: 0.8768
# Iteration 101/300, Reconstruction Error: 0.8767
# Iteration 106/300, Reconstruction Error: 0.8766
# Iteration 111/300, Reconstruction Error: 0.8766
# Iteration 116/300, Reconstruction Error: 0.8765
# Iteration 121/300, Reconstruction Error: 0.8765
# Iteration 126/300, Reconstruction Error: 0.8765
# Iteration 131/300, Reconstruction Error: 0.8765
# Iteration 136/300, Reconstruction Error: 0.8765
# Iteration 141/300, Reconstruction Error: 0.8765
# Iteration 146/300, Reconstruction Error: 0.8765
# Iteration 151/300, Reconstruction Error: 0.8766
# Iteration 156/300, Reconstruction Error: 0.8766
# Iteration 161/300, Reconstruction Error: 0.8766
# Iteration 166/300, Reconstruction Error: 0.8766
# Iteration 171/300, Reconstruction Error: 0.8766
# Iteration 176/300, Reconstruction Error: 0.8766
# Iteration 181/300, Reconstruction Error: 0.8766
# Iteration 186/300, Reconstruction Error: 0.8766
# Iteration 191/300, Reconstruction Error: 0.8766
# Iteration 196/300, Reconstruction Error: 0.8766
# Iteration 201/300, Reconstruction Error: 0.8766
# Iteration 206/300, Reconstruction Error: 0.8766
# Iteration 211/300, Reconstruction Error: 0.8766
# Iteration 216/300, Reconstruction Error: 0.8766
# Iteration 221/300, Reconstruction Error: 0.8766
# Iteration 226/300, Reconstruction Error: 0.8766
# Iteration 231/300, Reconstruction Error: 0.8766
# Iteration 236/300, Reconstruction Error: 0.8766
# Iteration 241/300, Reconstruction Error: 0.8766
# Iteration 246/300, Reconstruction Error: 0.8766
# Iteration 251/300, Reconstruction Error: 0.8766
# Iteration 256/300, Reconstruction Error: 0.8766
# Iteration 261/300, Reconstruction Error: 0.8766
# Iteration 266/300, Reconstruction Error: 0.8766
# Iteration 271/300, Reconstruction Error: 0.8766
# Iteration 276/300, Reconstruction Error: 0.8766
# Iteration 281/300, Reconstruction Error: 0.8766
# Iteration 286/300, Reconstruction Error: 0.8766
# Iteration 291/300, Reconstruction Error: 0.8766
# Iteration 296/300, Reconstruction Error: 0.8766
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 2359296
# ADMM後の重みテンソルの非ゼロの要素数: 57402 (目標数57402)
# ||Dx||_1: 10036.2016 (制約は10035.70927734375以下)

# %%
zero_percentage_list = []

for i in range(10):
    # 更新後の重みの値を見る
    threshold = 10**-i

    print(f"閾値 {threshold} を使って、永続的なプルーニングマスクを適用します。")

    # 2. マスクを適用したいパラメータをリストアップ
    #    ここでは、全ての畳み込み層の'weight'を対象にします。
    parameters_to_prune = [
        (module, "weight")
        for module in model.modules()
        if isinstance(module, torch.nn.Conv2d)
    ]

    # 3. 各レイヤーに対して、現在の重みを基にカスタムマスクを作成し、適用する
    for module, name in parameters_to_prune:
        # 現在の重みを取得
        weights = getattr(module, name).detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        mask = (torch.abs(weights) > threshold).float().to(weights.device)
        
        # カスタムマスクを適用
        prune.CustomFromMask.apply(module, name, mask=mask)

    with torch.no_grad():
        all_conv_params = 0
        all_conv_zeros = 0
        for module, name in parameters_to_prune:
            weight_after_pruning = module.weight
            num_zeros = (weight_after_pruning == 0).sum().item()
            total_params = weight_after_pruning.numel()
            sparsity = 100. * num_zeros / total_params

            # 全体で何％枝刈りされたか考える
            all_conv_params += total_params
            all_conv_zeros += num_zeros

            print(f"{name}の重みのゼロの数: {num_zeros} / {total_params} ({sparsity:.4f}%)")

        all_conv_sparsity = 100. * all_conv_zeros / all_conv_params
        print(f"全畳み込み層の0率：{all_conv_sparsity:.4f}%")
        zero_percentage_list.append(all_conv_sparsity)

        for module, name in parameters_to_prune:
            # 1. 元の重み('weight_orig')を退避
            original_weights = module.weight_orig.clone()

            # 2. prune.removeでフックとマスクを削除
            prune.remove(module, 'weight')

            # 3. 退避した元の重みで上書き
            module.weight.data.copy_(original_weights)

plt.plot(zero_percentage_list)
plt.xticks(range(10))
plt.yticks(np.arange(40, 101, 5))
plt.grid()
plt.xlabel('(1e-x)')
plt.ylabel('zero_percent')
plt.show()

# 0マスクをつける閾値は1e-4か1e-5くらいがよさそう
# Out:
# 閾値 1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9408 / 9408 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 73728 / 73728 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 8192 / 8192 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 294912 / 294912 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 32768 / 32768 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 1179648 / 1179648 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 131072 / 131072 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# 全畳み込み層の0率：100.0000%
# 閾値 0.1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 7512 / 9408 (79.8469%)
# weightの重みのゼロの数: 35441 / 36864 (96.1399%)
# weightの重みのゼロの数: 35902 / 36864 (97.3904%)
# weightの重みのゼロの数: 35700 / 36864 (96.8424%)
# weightの重みのゼロの数: 36043 / 36864 (97.7729%)
# weightの重みのゼロの数: 72295 / 73728 (98.0564%)
# weightの重みのゼロの数: 145791 / 147456 (98.8708%)
# weightの重みのゼロの数: 7551 / 8192 (92.1753%)
# weightの重みのゼロの数: 145933 / 147456 (98.9671%)
# weightの重みのゼロの数: 146805 / 147456 (99.5585%)
# weightの重みのゼロの数: 293229 / 294912 (99.4293%)
# weightの重みのゼロの数: 588221 / 589824 (99.7282%)
# weightの重みのゼロの数: 32405 / 32768 (98.8922%)
# weightの重みのゼロの数: 588974 / 589824 (99.8559%)
# weightの重みのゼロの数: 589352 / 589824 (99.9200%)
# weightの重みのゼロの数: 1179125 / 1179648 (99.9557%)
# weightの重みのゼロの数: 2358832 / 2359296 (99.9803%)
# weightの重みのゼロの数: 129798 / 131072 (99.0280%)
# weightの重みのゼロの数: 2359035 / 2359296 (99.9889%)
# weightの重みのゼロの数: 2359029 / 2359296 (99.9887%)
# 全畳み込み層の0率：99.8214%
# 閾値 0.01 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4395 / 9408 (46.7156%)
# weightの重みのゼロの数: 24221 / 36864 (65.7037%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22185 / 36864 (60.1807%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0021%
# 閾値 0.001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0000%
# 閾値 0.0001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0000%
# 閾値 1e-05 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4274 / 9408 (45.4294%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0000%
# 閾値 1e-06 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4268 / 9408 (45.3656%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4327 / 8192 (52.8198%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：89.9997%
# 閾値 1e-07 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4260 / 9408 (45.2806%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 40441 / 147456 (27.4258%)
# weightの重みのゼロの数: 1206 / 8192 (14.7217%)
# weightの重みのゼロの数: 101639 / 147456 (68.9284%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 482095 / 589824 (81.7354%)
# weightの重みのゼロの数: 10218 / 32768 (31.1829%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2058408 / 2359296 (87.2467%)
# weightの重みのゼロの数: 39591 / 131072 (30.2055%)
# weightの重みのゼロの数: 2158579 / 2359296 (91.4925%)
# weightの重みのゼロの数: 2301856 / 2359296 (97.5654%)
# 全畳み込み層の0率：87.4119%
# 閾値 1e-08 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4251 / 9408 (45.1849%)
# weightの重みのゼロの数: 21240 / 36864 (57.6172%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 8078 / 147456 (5.4782%)
# weightの重みのゼロの数: 281 / 8192 (3.4302%)
# weightの重みのゼロの数: 23036 / 147456 (15.6223%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 170795 / 589824 (28.9569%)
# weightの重みのゼロの数: 9320 / 32768 (28.4424%)
# weightの重みのゼロの数: 257012 / 589824 (43.5744%)
# weightの重みのゼロの数: 460946 / 589824 (78.1498%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 1041461 / 2359296 (44.1429%)
# weightの重みのゼロの数: 21467 / 131072 (16.3780%)
# weightの重みのゼロの数: 1215070 / 2359296 (51.5014%)
# weightの重みのゼロの数: 2037221 / 2359296 (86.3487%)
# 全畳み込み層の0率：60.7096%
# 閾値 1e-09 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 2906 / 9408 (30.8886%)
# weightの重みのゼロの数: 5786 / 36864 (15.6955%)
# weightの重みのゼロの数: 22782 / 36864 (61.8001%)
# weightの重みのゼロの数: 19030 / 36864 (51.6222%)
# weightの重みのゼロの数: 20014 / 36864 (54.2914%)
# weightの重みのゼロの数: 19159 / 73728 (25.9861%)
# weightの重みのゼロの数: 1023 / 147456 (0.6938%)
# weightの重みのゼロの数: 150 / 8192 (1.8311%)
# weightの重みのゼロの数: 2877 / 147456 (1.9511%)
# weightの重みのゼロの数: 111225 / 147456 (75.4293%)
# weightの重みのゼロの数: 216731 / 294912 (73.4901%)
# weightの重みのゼロの数: 27932 / 589824 (4.7356%)
# weightの重みのゼロの数: 2455 / 32768 (7.4921%)
# weightの重みのゼロの数: 228801 / 589824 (38.7914%)
# weightの重みのゼロの数: 180224 / 589824 (30.5556%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 308844 / 2359296 (13.0905%)
# weightの重みのゼロの数: 8065 / 131072 (6.1531%)
# weightの重みのゼロの数: 336772 / 2359296 (14.2743%)
# weightの重みのゼロの数: 1663700 / 2359296 (70.5168%)
# 全畳み込み層の0率：37.8700%

# %%
# maskをつくる
threshold = 1e-4   #1e-4が基準

masks = {}

for name, module in model.named_modules():
    if isinstance(module, torch.nn.Conv2d):
        # 現在の重みを取得
        weights = module.weight.detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        masks[name] = (torch.abs(weights) > threshold).float().to(weights.device)

# %%
# カスタムマスクを適用
# ブロックスパースアルゴリズム前の密モデルの重みに対してマスクをかける
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])

# %%
# ADMM後のモデルにマスクをかける
'''
for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])
'''
# Out:
# '\nfor name, module in model.named_modules(): \n    if name in masks:\n        prune.CustomFromMask.apply(module, "weight", mask=masks[name])\n'

# %%
# ゼロ比率を表示
all_conv_params = 0
all_conv_zeros = 0

for name, module in model.named_modules():
  if isinstance(module, torch.nn.Conv2d):
    print(f"{name} Zero-Ratio: {100.0 * float(torch.sum(module.weight == 0)) / float(module.weight.nelement()):.4f}%")
    weight_after_pruning = module.weight
    num_zeros = (weight_after_pruning == 0).sum().item()
    total_params = weight_after_pruning.numel()
    all_conv_params += total_params
    all_conv_zeros += num_zeros

sparsity = 100. * all_conv_zeros / all_conv_params if all_conv_params > 0 else 0
print(f"全畳み込み層の0率：{sparsity:.4f}%")
# Out:
# conv1 Zero-Ratio: 45.4826%
# layer1.0.conv1 Zero-Ratio: 65.5084%
# layer1.0.conv2 Zero-Ratio: 62.2776%
# layer1.1.conv1 Zero-Ratio: 60.0586%
# layer1.1.conv2 Zero-Ratio: 62.0253%
# layer2.0.conv1 Zero-Ratio: 65.6955%
# layer2.0.conv2 Zero-Ratio: 73.8586%
# layer2.0.downsample.0 Zero-Ratio: 53.1250%
# layer2.1.conv1 Zero-Ratio: 72.8794%
# layer2.1.conv2 Zero-Ratio: 75.4591%
# layer3.0.conv1 Zero-Ratio: 78.3671%
# layer3.0.conv2 Zero-Ratio: 83.0126%
# layer3.0.downsample.0 Zero-Ratio: 73.6694%
# layer3.1.conv1 Zero-Ratio: 86.3091%
# layer3.1.conv2 Zero-Ratio: 88.2426%
# layer4.0.conv1 Zero-Ratio: 89.0463%
# layer4.0.conv2 Zero-Ratio: 92.7996%
# layer4.0.downsample.0 Zero-Ratio: 72.6631%
# layer4.1.conv1 Zero-Ratio: 91.6370%
# layer4.1.conv2 Zero-Ratio: 97.5670%
# 全畳み込み層の0率：90.0000%

# %%
# 再訓練
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)   #lr = 0.001で損失0.02とか
num_epochs = 15
epoch_loss_list = []
# CosineAnnealingLRを定義
# T_max: 学習率が半周期で最小値になるまでのエポック数。通常、総エポック数を指定。
# eta_min: 最小学習率。
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=0)

for epoch in range(num_epochs):
  model.train()
  model = model.to(device)
  total_loss = 0.0
  num_train = 0
  for inputs, labels in trainloader:
    inputs, labels = inputs.to(device), labels.to(device)   # データ代入

    # 重み更新のための手順
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # 損失を記録
    total_loss += loss.item()*labels.size(0)
    num_train+=labels.size(0)

  # 出力と記録
  epoch_loss_list.append(total_loss/num_train)
  current_lr = optimizer.param_groups[0]['lr']
  print(f'Epoch[{epoch+1}/{num_epochs}], Loss: {epoch_loss_list[epoch]:.4f}, LR: {current_lr:.8f}')


  # 次のエポックへの準備
  if epoch >= 1:
    if np.abs(epoch_loss_list[epoch]-epoch_loss_list[epoch-1]) < 0.001:
      break
  scheduler.step()
# Out:
# Epoch[1/15], Loss: 0.2345, LR: 0.00100000
# Epoch[2/15], Loss: 0.0774, LR: 0.00098907
# Epoch[3/15], Loss: 0.0394, LR: 0.00095677
# Epoch[4/15], Loss: 0.0223, LR: 0.00090451
# Epoch[5/15], Loss: 0.0142, LR: 0.00083457
# Epoch[6/15], Loss: 0.0085, LR: 0.00075000
# Epoch[7/15], Loss: 0.0042, LR: 0.00065451
# Epoch[8/15], Loss: 0.0011, LR: 0.00055226
# Epoch[9/15], Loss: 0.0004, LR: 0.00044774

# %%
# 損失グラフ作成
plt.plot(epoch_loss_list)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# 永続化（マスクと重みを掛ける）
for module in model.modules():
  if isinstance(module, torch.nn.Conv2d):
    prune.remove(module, "weight")

# %%
# onnxファイルとptファイルの作成
model = model.to('cpu')
model_to_onnx(model, "ADMM_blocksparse_trained90.onnx")
torch.save(model.state_dict(), "ADMM_blocksparse_trained90.pt")
