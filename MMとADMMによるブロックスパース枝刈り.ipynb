# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.utils.prune as prune
import torchvision.models as models
from torch.onnx import export

import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torch.nn.utils import parameters_to_vector
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.optim.lr_scheduler import CosineAnnealingLR

# %%
# 乱数を一定にする
seed = 777  # 好きな数字でOK
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# onnxファイルを作成する関数
def model_to_onnx(model, output_file, input_shape = (1, 3, 224, 224)):
  model.eval()
  input_tensor = torch.randn(input_shape).to('cpu')
  input_names = ['input']
  output_names = ['output']
  torch.onnx.export(model, input_tensor, output_file, verbose = False, input_names = input_names, output_names = output_names)
  return output_file

# %%
# モデル読み込み
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# 訓練データセット作成
transform = transforms.Compose([transforms.Resize(224),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])   # 正規化したほうがいいらしい

trainset = torchvision.datasets.CIFAR10(root = "./data", train = True, download = True, transform = transform)
trainloader = DataLoader(trainset, batch_size = 400, shuffle = True)

# %%
def project_l1_ball(tensor_x: np.ndarray, radius: float) -> np.ndarray:
    """
    テンソル `tensor_x` を、中心が原点のL1ノルム半径 `radius` の超球（L1ボール）の表面または内部に射影する。
    これは、制約条件 ||z||_1 <= radius を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    アルゴリズムは、"Projection onto the L1-ball" として知られる効率的な手法に基づいている。
    """
    # ステップ 1: 入力テンソルのL1ノルムを計算し、そもそも射影が必要かを確認
    # もしL1ノルムが既に半径以下なら、テンソルは制約を満たしており、何もしなくてよい。
    if np.sum(np.abs(tensor_x)) <= radius:
        return tensor_x

    # ステップ 3: 符号情報を無視し、絶対値のテンソルを作成
    # 射影アルゴリズムは、正の象限（すべての要素が非負）で動作し、最後に元の符号を復元する。
    u_tensor = np.abs(tensor_x)

    # ステップ 4: 絶対値テンソル `u_tensor` を降順にソートする。
    # このソートが、効率的なアルゴリズムの鍵となる。
    u_sorted = np.sort(u_tensor, axis=None)[::-1]
    n_features = len(u_sorted)

    # ステップ 5: ソートされたベクトルの累積和を計算する。
    # sv[i-1] は、u の中で最も大きい i 個の要素の和を表す。
    sv = np.cumsum(u_sorted)

    # ステップ 6: 射影の閾値 `theta` を見つけるための条件を満たす `rho` を探す。
    # ここがアルゴリズムの核心部分。
    # 数学的な導出により、射影後のベクトルは `y = sign(v) * max(abs(v) - theta, 0)` という形になることが分かっている。
    # この `y` のL1ノルムが `radius` に等しくなるような `theta` を見つけたい。
    # そのための条件が `u_sorted[i-1] > (sv[i-1] - radius) / i` であり、
    # この条件を満たす最大のインデックスが `rho` となる。
    
    # i = 1, 2, ..., n_features を生成
    arange_i = np.arange(1, n_features + 1)
    
    # 条件を満たすインデックスの候補を探す
    rho_candidates = np.where(u_sorted > (sv - radius) / arange_i)[0]
    
    # 候補の中から最大のインデックスをrhoとして採用する（0-basedから1-basedに変換するため+1）
    # 候補がない場合は、すべての要素が同じだけシフトされるケース
    rho = rho_candidates[-1] + 1 if len(rho_candidates) > 0 else n_features

    # ステップ 7: 決定した `rho` を使って、最終的なシフト量 `theta` を計算する。
    # thetaは、各要素から（絶対値の形で）引き算される値。
    theta = (sv[rho - 1] - radius) / rho

    # ステップ 8: ソフトしきい値処理（soft-thresholding）を実行して、射影を完了させる。
    # 1. 各要素の絶対値から `theta` を引く。
    # 2. 結果が負になった場合は0にする（`np.maximum(..., 0)`）。
    # 3. 元の符号 `sign(v)` を掛け合わせて、正しい象限に戻す。
    projected_tensor_x = np.sign(tensor_x) * np.maximum(np.abs(tensor_x) - theta, 0)

    # ステップ 9: 返す。
    return projected_tensor_x

def hard_threshold(tensor_x: np.ndarray, K0: int) -> np.ndarray:
    """
    テンソル `tensor_x` に対してハードしきい値処理を適用する。
    これは、制約条件 ||z||_0 <= K0 を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    簡単に言うと、テンソルの要素のうち、絶対値が大きい方から `K0` 個だけを残し、
    それ以外をすべて厳密に0にする。
    """
    # ステップ 1: そもそも処理が必要かを確認
    # もし残したい非ゼロ要素の数 `K0` が、テンソルの全要素数以上なら、
    # どの要素も0にする必要はないので、そのまま返す。
    if K0 >= tensor_x.size:
        return tensor_x
    
    # ステップ 3: 0にすべき要素を決定するための「しきい値」を見つける。
    # しきい値は、ベクトル `v` の絶対値を小さい順にソートしたとき、
    # 後ろから `K0` 番目（つまり、絶対値が `K0` 番目に大きい要素）の値となる。
    # 例: v=[10, -2, 5, -8], K0=2 の場合、abs(v)=[10, 2, 5, 8]。
    #    ソートすると [2, 5, 8, 10]。後ろから2番目は `8`。これがしきい値となる。
    # 同じ値の要素があった場合は非ゼロの要素がK0
    threshold = np.sort(np.abs(tensor_x), axis=None)[-(K0+1)]

    # ステップ 4: しきい値に基づいて、値を0にする。
    # 絶対値がこのしきい値より「小さい」すべての要素を0で上書きする。
    # 例: abs(v) < 8 となるのは `2` と `5`。対応する元の要素 `-2` と `5` が0になる。
    tensor_x[np.abs(tensor_x) <= threshold] = 0

    return tensor_x

# %%
def D_op_4d(tensor: np.ndarray) -> np.ndarray:
    """
    4階数テンソル (out_ch, in_ch, h, w) の4方向の差分を計算し、
    5階数テンソル (out_ch, in_ch, h, w, 4) として返す。
    """
    # dim=0 (出力チャネル方向)
    diff_dim0 = np.roll(tensor, -1, axis=0) - tensor
    # dim=1 (入力チャネル方向)
    diff_dim1 = np.roll(tensor, -1, axis=1) - tensor
    # dim=2 (縦方向)
    diff_dim2 = np.roll(tensor, -1, axis=2) - tensor
    # dim=3 (横方向)
    diff_dim3 = np.roll(tensor, -1, axis=3) - tensor
    
    # 最後の軸に4つの差分をスタックする
    return np.stack([diff_dim0, diff_dim1, diff_dim2, diff_dim3], axis=-1)

# 転置差分がどんな演算なのかいまいちわかってない
def DT_op_4d(stacked_tensor: np.ndarray) -> np.ndarray:
    """
    D_op_4dの転置演算。5階数テンソルを受け取り、4階数テンソルを返す。
    """
    # 各差分を取り出す
    d0 = stacked_tensor[..., 0]
    d1 = stacked_tensor[..., 1]
    d2 = stacked_tensor[..., 2]
    d3 = stacked_tensor[..., 3]

    # 各々の転置差分を計算し、合計する (D^T = -D_backward)
    term0 = np.roll(d0, 1, axis=0) - d0
    term1 = np.roll(d1, 1, axis=1) - d1
    term2 = np.roll(d2, 1, axis=2) - d2
    term3 = np.roll(d3, 1, axis=3) - d3
    
    return term0 + term1 + term2 + term3

# %%
from scipy.sparse.linalg import cg, LinearOperator # LinearOperatorをインポート

def solve_admm(
    w: np.ndarray, 
    D_op, 
    DT_op, 
    K1: float, 
    K0_ratio: float, 
    rho: float, 
    gamma: float,
    n_iter: int,
    x: float,
    y: float,
    z: float,
    u1: float,
    u2: float,
):
    
    K0 = int(K0_ratio * w.size)
    
    # テンソルの総要素数を計算 (LinearOperatorのshape定義のため)
    n_elements = w.size

    print(f"Tensor shape: {w.shape}, K1={K1}, K0={K0} ({K0_ratio*100:.1f}%)")

    # ★★★ ここからが大幅な変更点 ★★★

    # 1. matvec関数を定義 (入力と出力が1次元ベクトルであることを明示)
    def matvec_for_lo(p_flat: np.ndarray) -> np.ndarray:
        # 内部で型変換は行わず、入力の型を信頼する
        p = p_flat.reshape(w.shape)
        DTD_p = DT_op(D_op(p))
        result = rho * DTD_p + gamma * p + p
        return result.flatten()

    # 2. LinearOperatorを明示的に作成
    # これにより、shapeとdtypeをcg関数に正確に伝える
    A = LinearOperator(
        shape=(n_elements, n_elements), # 作用素は (N, N) の正方行列として振る舞う
        matvec=matvec_for_lo,
        dtype=np.float64               # 扱うデータ型は float64 であることを明記
    )

    # ★★★ 変更ここまで ★★★


    # --- ADMM反復ループ ---
    for i in range(n_iter):
        # 1. x の更新
        # v は float64 であることを確認済み
        v = w + rho * DT_op(y - u1) + gamma * (z - u2)
        
        # LinearOperatorオブジェクト A を直接cgに渡す
        x_flat, _ = cg(A, v.flatten(), x0=x.flatten())
        x = x_flat.reshape(w.shape)

        # 2. y の更新
        v_proj1 = D_op(x) + u1
        y = project_l1_ball(v_proj1, K1)

        # 3. z の更新
        v_proj2 = x + u2
        z = hard_threshold(v_proj2, K0)

        # 4. 双対変数 u1, u2 の更新
        u1 = u1 + D_op(x) - y
        u2 = u2 + x - z

        if i % 5 == 0:
            if i != 0:
                if np.abs(recon_error - np.linalg.norm(x - w) / np.linalg.norm(w)) < 0.001:   # 前回（5回前）と1%未満しか変化がなければ、ループを終える
                    print(f"1%未満しか変化がないので、{i+1}回目で終了")
                    break
            recon_error = np.linalg.norm(x - w) / np.linalg.norm(w)
            print(f"Iteration {i+1}/{n_iter}, Reconstruction Error: {recon_error:.4f}")

    return x, y, z, u1, u2, K1

# %%
def Omega(delta):
    """
    4階テンソルdeltaの各次元に沿った差分を計算し、
    その絶対値の総和を返す。
    """
    h = 1.0  # Dのパラメータ

    # 4つの次元それぞれに対して差分（勾配）を計算

    # dim=0 (出力チャネル方向の差分)
    diff_dim0 = delta[1:, :, :, :] - delta[:-1, :, :, :]

    # dim=1 (入力チャネル方向の差分)
    diff_dim1 = delta[:, 1:, :, :] - delta[:, :-1, :, :]

    # dim=2 (縦方向の差分)
    # 1行目から最後までと、0行目から最後の一つ手前までの差
    diff_dim2 = delta[:, :, 1:, :] - delta[:, :, :-1, :]

    # dim=3 (横方向の差分)
    # 1列目から最後までと、0列目から最後の一つ手前までの差
    diff_dim3 = delta[:, :, :, 1:] - delta[:, :, :, :-1]

    # 全ての差分の絶対値の総和を計算
    # これがD@deltaに相当する操作のL1ノルムになる
    constrain = torch.sum(torch.abs(diff_dim0)) + torch.sum(torch.abs(diff_dim1)) + torch.sum(torch.abs(diff_dim2)) + torch.sum(torch.abs(diff_dim3))

    return constrain / h

# %%
# 各層のTVを見てみる
layer_tvs = {}
layer_relative_tvs = {}
conv_layer_names = []

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        w_tensor = module.weight.detach().clone().to(device)
        tv = Omega(w_tensor).item()
        ave_tv = tv/(w_tensor).numel()
        relative_tv = tv / torch.sum(torch.abs(w_tensor)).item()
        layer_tvs[name] = tv
        layer_relative_tvs[name] = relative_tv
        conv_layer_names.append(name)
        print(f"{name}：TV={tv:.4f}     ave_TV={ave_tv:.4f}     relative_TV={relative_tv:.4f}")
# Out:
# conv1：TV=2785.1948     ave_TV=0.2960     relative_TV=3.8864
# layer1.0.conv1：TV=5368.6899     ave_TV=0.1456     relative_TV=4.6001
# layer1.0.conv2：TV=5110.8359     ave_TV=0.1386     relative_TV=4.3279
# layer1.1.conv1：TV=5665.4883     ave_TV=0.1537     relative_TV=4.4829
# layer1.1.conv2：TV=5081.4331     ave_TV=0.1378     relative_TV=4.3692
# layer2.0.conv1：TV=9606.8564     ave_TV=0.1303     relative_TV=4.4254
# layer2.0.conv2：TV=15700.7480     ave_TV=0.1065     relative_TV=4.4383
# layer2.0.downsample.0：TV=1077.2024     ave_TV=0.1315     relative_TV=2.9591
# layer2.1.conv1：TV=16048.6338     ave_TV=0.1088     relative_TV=4.4778
# layer2.1.conv2：TV=14007.5215     ave_TV=0.0950     relative_TV=4.2592
# layer3.0.conv1：TV=24442.1191     ave_TV=0.0829     relative_TV=3.9467
# layer3.0.conv2：TV=45506.3359     ave_TV=0.0772     relative_TV=4.1868
# layer3.0.downsample.0：TV=2261.6729     ave_TV=0.0690     relative_TV=2.8949
# layer3.1.conv1：TV=41485.1523     ave_TV=0.0703     relative_TV=4.2055
# layer3.1.conv2：TV=37498.1641     ave_TV=0.0636     relative_TV=4.0776
# layer4.0.conv1：TV=70836.3359     ave_TV=0.0600     relative_TV=3.9260
# layer4.0.conv2：TV=134329.4375     ave_TV=0.0569     relative_TV=4.2296
# layer4.0.downsample.0：TV=9025.8906     ave_TV=0.0689     relative_TV=2.8755
# layer4.1.conv1：TV=129517.4688     ave_TV=0.0549     relative_TV=3.8883
# layer4.1.conv2：TV=81123.4766     ave_TV=0.0344     relative_TV=3.3774

# %%
import json

# JSONファイルから辞書を読み込む
with open('90cut_data.json', 'r') as f:
    zero_ratings = json.load(f)

with open('90cut_relativeTV.json', 'r') as f:
    layer_90cut_relative_tvs = json.load(f)

print(zero_ratings)
print(layer_90cut_relative_tvs)
# Out:
# {'conv1': 0.45471938775510207, 'layer1.0.conv1': 0.6550564236111112, 'layer1.0.conv2': 0.6227756076388888, 'layer1.1.conv1': 0.6005859375, 'layer1.1.conv2': 0.6202528211805556, 'layer2.0.conv1': 0.6569552951388888, 'layer2.0.conv2': 0.73858642578125, 'layer2.0.downsample.0': 0.53125, 'layer2.1.conv1': 0.7287868923611112, 'layer2.1.conv2': 0.7545912000868056, 'layer3.0.conv1': 0.7836710611979166, 'layer3.0.conv2': 0.8301255967881944, 'layer3.0.downsample.0': 0.7366943359375, 'layer3.1.conv1': 0.8630913628472222, 'layer3.1.conv2': 0.8824259440104166, 'layer4.0.conv1': 0.8904622395833334, 'layer4.0.conv2': 0.9279958936903212, 'layer4.0.downsample.0': 0.7266311645507812, 'layer4.1.conv1': 0.9163699679904513, 'layer4.1.conv2': 0.9756698608398438}
# {'conv1': 4.027483465904622, 'layer1.0.conv1': 5.187465703233075, 'layer1.0.conv2': 5.018088421462655, 'layer1.1.conv1': 5.1439845812105345, 'layer1.1.conv2': 5.073877961406653, 'layer2.0.conv1': 5.171453991691199, 'layer2.0.conv2': 5.445477096898191, 'layer2.0.downsample.0': 3.290322149753673, 'layer2.1.conv1': 5.457166442246035, 'layer2.1.conv2': 5.329104132585309, 'layer3.0.conv1': 4.953840272616876, 'layer3.0.conv2': 5.446103003405924, 'layer3.0.downsample.0': 3.529604452799148, 'layer3.1.conv1': 5.575070285575484, 'layer3.1.conv2': 5.511405656525587, 'layer4.0.conv1': 5.356365754800536, 'layer4.0.conv2': 6.169967069786414, 'layer4.0.downsample.0': 3.4884049950864453, 'layer4.1.conv1': 5.640184190467383, 'layer4.1.conv2': 4.877897042575949}

# %%
final_weights_to_assign = {}

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        print(f"\n--- レイヤー '{name}' の処理を開始 ---")

        # wを4階テンソルのまま取得
        # .detach().clone()で勾配情報を切り離し、安全なコピーを作成し、numpyに変換、scipyのcg法に合うようにfloat64に
        w_numpy = module.weight.detach().clone().to('cpu').numpy().astype(np.float64)

        # --- パラメータ設定と実行 ---
        K1_val = layer_90cut_relative_tvs[name]*0.9       # Relative Total Variationの上限
        K0_ratio_val = 1 - zero_ratings[name]   # 10%を非ゼロにする (目標のスパース率90%)
        rho_val = 0.1        # block性ペナルティパラメータ
        gamma_val = 15.0   # sparse性ペナルティパラメータ
        iterations = 70   # 繰り返し回数

        # --- 初期化 ---
        # 全ての変数を float64 で厳密に初期化
        x  = w_numpy.copy().astype(np.float64)
        y = D_op_4d(x).astype(np.float64)
        z = x.copy().astype(np.float64)
        u1 = np.zeros_like(y, dtype=np.float64)
        u2 = np.zeros_like(z, dtype=np.float64)

        for i in range(10):
            k1 = K1_val*np.sum(np.abs(x))
            admm_result = solve_admm(w_numpy, D_op_4d, DT_op_4d, k1, K0_ratio_val, rho_val, gamma_val, iterations, x, y, z, u1, u2)
            x_was=x
            x=admm_result[0]
            y=admm_result[1]
            z=admm_result[2]
            u1=admm_result[3]
            u2=admm_result[4]
            k1=admm_result[5]
            if i > 0:
                l1norm_change = np.linalg.norm(x-x_was) / np.linalg.norm(x)
                print(f'L1ノルムの変化 = {l1norm_change*100}%')
                if l1norm_change <= 0.01:   # 1%以下しか変化していなければ
                    print("xのL1ノルムは1%以下しか変化していないのでearly stopします。")
                    break
            if i == 49:
                print("外のループを規定回数（50回）回しました")
        x_final = x
            
        with torch.no_grad():
            module.weight.copy_(torch.tensor(x_final))

        # 閾値で0に近い値を完全な0にする
        x_final[np.abs(x_final) <= 1e-4] = 0

        # 結果の簡単な確認
        print("\n結果:")
        print(f"元の重みテンソルの非ゼロの要素数: {np.sum(w_numpy != 0)}")
        print(f"ADMM後の重みテンソルの非ゼロの要素数: {np.sum(x_final != 0)} (目標数{int(K0_ratio_val * w_numpy.size)})")
        print(f"||Dx||_1 / ||x||_1: {np.sum(np.abs(D_op_4d(x_final))) / np.sum(np.abs(x_final)):.4f} (制約は{K1_val}以下)")
# Out:
# --- レイヤー 'conv1' の処理を開始 ---
# Tensor shape: (64, 3, 7, 7), K1=2597.6572407586646, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.1512
# Iteration 21/30, Reconstruction Error: 0.1639
# Tensor shape: (64, 3, 7, 7), K1=2128.3677801392446, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.1322
# Iteration 11/30, Reconstruction Error: 0.2494
# Iteration 21/30, Reconstruction Error: 0.2785
# L1ノルムの変化 = 16.65650314375691%
# Tensor shape: (64, 3, 7, 7), K1=1778.8807220837768, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.2477
# Iteration 11/30, Reconstruction Error: 0.3366
# Iteration 21/30, Reconstruction Error: 0.3662
# L1ノルムの変化 = 14.59788245970381%
# Tensor shape: (64, 3, 7, 7), K1=1516.74604481992, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.3425
# Iteration 11/30, Reconstruction Error: 0.4114
# Iteration 21/30, Reconstruction Error: 0.4359
# L1ノルムの変化 = 13.223763119008188%
# Tensor shape: (64, 3, 7, 7), K1=1306.5426192976731, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.4184
# Iteration 11/30, Reconstruction Error: 0.4766
# Iteration 21/30, Reconstruction Error: 0.4971
# L1ノルムの変化 = 12.307116798883754%
# Tensor shape: (64, 3, 7, 7), K1=1133.3718973039527, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.4822
# Iteration 11/30, Reconstruction Error: 0.5326
# Iteration 21/30, Reconstruction Error: 0.5499
# L1ノルムの変化 = 11.653294914991175%
# Tensor shape: (64, 3, 7, 7), K1=991.1591307806232, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.5372
# Iteration 11/30, Reconstruction Error: 0.5809
# Iteration 21/30, Reconstruction Error: 0.5951
# L1ノルムの変化 = 10.776848852315911%
# Tensor shape: (64, 3, 7, 7), K1=874.9870948070306, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.5838
# Iteration 11/30, Reconstruction Error: 0.6212
# Iteration 21/30, Reconstruction Error: 0.6326
# L1ノルムの変化 = 10.047408758313367%
# Tensor shape: (64, 3, 7, 7), K1=775.2836056312033, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.6230
# Iteration 11/30, Reconstruction Error: 0.6569
# Iteration 21/30, Reconstruction Error: 0.6664
# L1ノルムの変化 = 9.852310963610497%
# Tensor shape: (64, 3, 7, 7), K1=689.8725613373626, K0=5129 (54.5%)
# Iteration 1/30, Reconstruction Error: 0.6579
# Iteration 11/30, Reconstruction Error: 0.6883
# Iteration 21/30, Reconstruction Error: 0.6961
# L1ノルムの変化 = 9.423652756002685%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 9408
# ADMM後の重みテンソルの非ゼロの要素数: 5319 (目標数5129)
# ||Dx||_1 / ||x||_1: 4.1770 (制約は3.6247351193141597以下)
#
# --- レイヤー 'layer1.0.conv1' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=5448.811795484811, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.2226
# Iteration 21/30, Reconstruction Error: 0.2216
# Tensor shape: (64, 64, 3, 3), K1=4176.822462411667, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.2215
# Iteration 11/30, Reconstruction Error: 0.3261
# Iteration 21/30, Reconstruction Error: 0.2928
# L1ノルムの変化 = 19.257926500520046%
# Tensor shape: (64, 64, 3, 3), K1=3385.7684849011926, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.2746
# Iteration 11/30, Reconstruction Error: 0.3994
# Iteration 21/30, Reconstruction Error: 0.3740
# L1ノルムの変化 = 18.231357097852154%
# Tensor shape: (64, 64, 3, 3), K1=2812.4874276765913, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.3566
# Iteration 11/30, Reconstruction Error: 0.4574
# Iteration 21/30, Reconstruction Error: 0.4462
# L1ノルムの変化 = 15.165434881689583%
# Tensor shape: (64, 64, 3, 3), K1=2380.3100728030336, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.4289
# Iteration 11/30, Reconstruction Error: 0.5078
# Iteration 21/30, Reconstruction Error: 0.5034
# L1ノルムの変化 = 13.267802424297983%
# Tensor shape: (64, 64, 3, 3), K1=2050.9753650679, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.4888
# Iteration 11/30, Reconstruction Error: 0.5515
# Iteration 21/30, Reconstruction Error: 0.5501
# L1ノルムの変化 = 11.843036453460016%
# Tensor shape: (64, 64, 3, 3), K1=1786.9364067944678, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.5380
# Iteration 11/30, Reconstruction Error: 0.5898
# Iteration 21/30, Reconstruction Error: 0.5899
# L1ノルムの変化 = 10.651698391097757%
# Tensor shape: (64, 64, 3, 3), K1=1567.535699797306, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.5797
# Iteration 11/30, Reconstruction Error: 0.6241
# Iteration 21/30, Reconstruction Error: 0.6245
# L1ノルムの変化 = 9.8364225660421%
# Tensor shape: (64, 64, 3, 3), K1=1383.383370572538, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.6157
# Iteration 11/30, Reconstruction Error: 0.6540
# Iteration 21/30, Reconstruction Error: 0.6546
# L1ノルムの変化 = 9.250519201420934%
# Tensor shape: (64, 64, 3, 3), K1=1227.3925687085318, K0=12715 (34.5%)
# Iteration 1/30, Reconstruction Error: 0.6470
# Iteration 11/30, Reconstruction Error: 0.6807
# Iteration 21/30, Reconstruction Error: 0.6812
# L1ノルムの変化 = 8.751472184519463%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 13172 (目標数12715)
# ||Dx||_1 / ||x||_1: 5.4848 (制約は4.668719132909768以下)
#
# --- レイヤー 'layer1.0.conv2' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=5333.284968825247, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.2858
# Iteration 21/30, Reconstruction Error: 0.2857
# Tensor shape: (64, 64, 3, 3), K1=3889.30855158143, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.2857
# Iteration 11/30, Reconstruction Error: 0.3883
# Iteration 21/30, Reconstruction Error: 0.3568
# L1ノルムの変化 = 22.19475248389143%
# Tensor shape: (64, 64, 3, 3), K1=3129.690031553473, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.3374
# Iteration 11/30, Reconstruction Error: 0.4648
# Iteration 21/30, Reconstruction Error: 0.4353
# L1ノルムの変化 = 21.649975888050534%
# Tensor shape: (64, 64, 3, 3), K1=2607.3617197801655, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.4173
# Iteration 11/30, Reconstruction Error: 0.5179
# Iteration 21/30, Reconstruction Error: 0.5031
# L1ノルムの変化 = 18.34786390323823%
# Tensor shape: (64, 64, 3, 3), K1=2233.8368546569113, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.4873
# Iteration 11/30, Reconstruction Error: 0.5628
# Iteration 21/30, Reconstruction Error: 0.5560
# L1ノルムの変化 = 15.137541117577358%
# Tensor shape: (64, 64, 3, 3), K1=1960.7668438580265, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.5423
# Iteration 11/30, Reconstruction Error: 0.5991
# Iteration 21/30, Reconstruction Error: 0.5960
# L1ノルムの変化 = 13.138298631345819%
# Tensor shape: (64, 64, 3, 3), K1=1760.6515479594998, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.5851
# Iteration 11/30, Reconstruction Error: 0.6279
# Iteration 21/30, Reconstruction Error: 0.6265
# L1ノルムの変化 = 11.361958992816039%
# Tensor shape: (64, 64, 3, 3), K1=1611.0108950670044, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.6179
# Iteration 11/30, Reconstruction Error: 0.6505
# Iteration 21/30, Reconstruction Error: 0.6499
# L1ノルムの変化 = 10.530207228777485%
# Tensor shape: (64, 64, 3, 3), K1=1499.7252292451399, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.6433
# Iteration 11/30, Reconstruction Error: 0.6681
# Iteration 21/30, Reconstruction Error: 0.6679
# L1ノルムの変化 = 9.348348384355695%
# Tensor shape: (64, 64, 3, 3), K1=1411.2847737569352, K0=13906 (37.7%)
# Iteration 1/30, Reconstruction Error: 0.6630
# Iteration 11/30, Reconstruction Error: 0.6826
# Iteration 21/30, Reconstruction Error: 0.6827
# L1ノルムの変化 = 8.527040629143691%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 14261 (目標数13906)
# ||Dx||_1 / ||x||_1: 4.8614 (制約は4.5162795793163895以下)
#
# --- レイヤー 'layer1.1.conv1' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=5850.80930309991, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.2522
# Iteration 21/30, Reconstruction Error: 0.2511
# Tensor shape: (64, 64, 3, 3), K1=4398.831832286357, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.2510
# Iteration 11/30, Reconstruction Error: 0.3668
# Iteration 21/30, Reconstruction Error: 0.3270
# L1ノルムの変化 = 22.079466594117125%
# Tensor shape: (64, 64, 3, 3), K1=3496.387894359759, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.3098
# Iteration 11/30, Reconstruction Error: 0.4471
# Iteration 21/30, Reconstruction Error: 0.4143
# L1ノルムの変化 = 20.91460126891131%
# Tensor shape: (64, 64, 3, 3), K1=2854.836214585549, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.3983
# Iteration 11/30, Reconstruction Error: 0.5082
# Iteration 21/30, Reconstruction Error: 0.4911
# L1ノルムの変化 = 17.583213514947804%
# Tensor shape: (64, 64, 3, 3), K1=2380.161116346208, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.4752
# Iteration 11/30, Reconstruction Error: 0.5595
# Iteration 21/30, Reconstruction Error: 0.5512
# L1ノルムの変化 = 15.252940475389357%
# Tensor shape: (64, 64, 3, 3), K1=2029.6906231497078, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.5373
# Iteration 11/30, Reconstruction Error: 0.6018
# Iteration 21/30, Reconstruction Error: 0.5977
# L1ノルムの変化 = 13.408046372095045%
# Tensor shape: (64, 64, 3, 3), K1=1762.0158369368169, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.5863
# Iteration 11/30, Reconstruction Error: 0.6372
# Iteration 21/30, Reconstruction Error: 0.6350
# L1ノルムの変化 = 12.141586412216698%
# Tensor shape: (64, 64, 3, 3), K1=1546.2262578990944, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.6261
# Iteration 11/30, Reconstruction Error: 0.6677
# Iteration 21/30, Reconstruction Error: 0.6666
# L1ノルムの変化 = 11.037769642918892%
# Tensor shape: (64, 64, 3, 3), K1=1373.1389233705604, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.6592
# Iteration 11/30, Reconstruction Error: 0.6932
# Iteration 21/30, Reconstruction Error: 0.6927
# L1ノルムの変化 = 9.85797608169199%
# Tensor shape: (64, 64, 3, 3), K1=1241.6372397666278, K0=14724 (39.9%)
# Iteration 1/30, Reconstruction Error: 0.6863
# Iteration 11/30, Reconstruction Error: 0.7127
# Iteration 21/30, Reconstruction Error: 0.7128
# L1ノルムの変化 = 8.429883946991499%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 15172 (目標数14724)
# ||Dx||_1 / ||x||_1: 5.2584 (制約は4.6295861230894815以下)
#
# --- レイヤー 'layer1.1.conv2' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=5310.8962732213795, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.2939
# Iteration 21/30, Reconstruction Error: 0.2937
# Tensor shape: (64, 64, 3, 3), K1=3847.516994899643, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.2937
# Iteration 11/30, Reconstruction Error: 0.4066
# Iteration 21/30, Reconstruction Error: 0.3674
# L1ノルムの変化 = 23.99941531229998%
# Tensor shape: (64, 64, 3, 3), K1=3042.853569186808, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.3509
# Iteration 11/30, Reconstruction Error: 0.4878
# Iteration 21/30, Reconstruction Error: 0.4524
# L1ノルムの変化 = 23.33671822354605%
# Tensor shape: (64, 64, 3, 3), K1=2492.964278803186, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.4369
# Iteration 11/30, Reconstruction Error: 0.5444
# Iteration 21/30, Reconstruction Error: 0.5256
# L1ノルムの変化 = 19.614059815375086%
# Tensor shape: (64, 64, 3, 3), K1=2100.4482625396304, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.5112
# Iteration 11/30, Reconstruction Error: 0.5912
# Iteration 21/30, Reconstruction Error: 0.5823
# L1ノルムの変化 = 16.42836488568039%
# Tensor shape: (64, 64, 3, 3), K1=1815.5414582577187, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.5694
# Iteration 11/30, Reconstruction Error: 0.6294
# Iteration 21/30, Reconstruction Error: 0.6246
# L1ノルムの変化 = 14.322942567297577%
# Tensor shape: (64, 64, 3, 3), K1=1607.179548122097, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.6142
# Iteration 11/30, Reconstruction Error: 0.6594
# Iteration 21/30, Reconstruction Error: 0.6568
# L1ノルムの変化 = 12.712127901548104%
# Tensor shape: (64, 64, 3, 3), K1=1448.4882247208525, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.6489
# Iteration 11/30, Reconstruction Error: 0.6842
# Iteration 21/30, Reconstruction Error: 0.6826
# L1ノルムの変化 = 11.46195140357827%
# Tensor shape: (64, 64, 3, 3), K1=1324.5576727810235, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.6763
# Iteration 11/30, Reconstruction Error: 0.7040
# Iteration 21/30, Reconstruction Error: 0.7033
# L1ノルムの変化 = 10.370229756008204%
# Tensor shape: (64, 64, 3, 3), K1=1225.505606054753, K0=13999 (38.0%)
# Iteration 1/30, Reconstruction Error: 0.6981
# Iteration 11/30, Reconstruction Error: 0.7207
# Iteration 21/30, Reconstruction Error: 0.7202
# L1ノルムの変化 = 9.435630174242153%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 14426 (目標数13999)
# ||Dx||_1 / ||x||_1: 5.0400 (制約は4.566490165265988以下)
#
# --- レイヤー 'layer2.0.conv1' の処理を開始 ---
# Tensor shape: (128, 64, 3, 3), K1=10103.88254699463, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.3140
# Iteration 21/30, Reconstruction Error: 0.3139
# Tensor shape: (128, 64, 3, 3), K1=7023.297901813586, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.3139
# Iteration 11/30, Reconstruction Error: 0.4234
# Iteration 21/30, Reconstruction Error: 0.3822
# L1ノルムの変化 = 24.448288744875548%
# Tensor shape: (128, 64, 3, 3), K1=5513.232314297935, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.3694
# Iteration 11/30, Reconstruction Error: 0.5042
# Iteration 21/30, Reconstruction Error: 0.4671
# L1ノルムの変化 = 24.153034906079142%
# Tensor shape: (128, 64, 3, 3), K1=4477.2837376766165, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.4546
# Iteration 11/30, Reconstruction Error: 0.5619
# Iteration 21/30, Reconstruction Error: 0.5418
# L1ノルムの変化 = 20.4092382300897%
# Tensor shape: (128, 64, 3, 3), K1=3736.7848851774647, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.5289
# Iteration 11/30, Reconstruction Error: 0.6100
# Iteration 21/30, Reconstruction Error: 0.5993
# L1ノルムの変化 = 17.20341259863723%
# Tensor shape: (128, 64, 3, 3), K1=3202.9719279680967, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.5873
# Iteration 11/30, Reconstruction Error: 0.6485
# Iteration 21/30, Reconstruction Error: 0.6423
# L1ノルムの変化 = 15.16647196659636%
# Tensor shape: (128, 64, 3, 3), K1=2808.309416313601, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.6327
# Iteration 11/30, Reconstruction Error: 0.6798
# Iteration 21/30, Reconstruction Error: 0.6757
# L1ノルムの変化 = 13.730828438162856%
# Tensor shape: (128, 64, 3, 3), K1=2504.7761959282625, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.6682
# Iteration 11/30, Reconstruction Error: 0.7053
# Iteration 21/30, Reconstruction Error: 0.7027
# L1ノルムの変化 = 12.588270386935527%
# Tensor shape: (128, 64, 3, 3), K1=2260.977252716931, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.6967
# Iteration 11/30, Reconstruction Error: 0.7268
# Iteration 21/30, Reconstruction Error: 0.7252
# L1ノルムの変化 = 11.264504367303264%
# Tensor shape: (128, 64, 3, 3), K1=2064.625524918512, K0=25292 (34.3%)
# Iteration 1/30, Reconstruction Error: 0.7201
# Iteration 11/30, Reconstruction Error: 0.7448
# Iteration 21/30, Reconstruction Error: 0.7437
# L1ノルムの変化 = 9.940727457379186%
# 外のループを規定回数（10回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 73728
# ADMM後の重みテンソルの非ゼロの要素数: 26116 (目標数25292)
# ||Dx||_1 / ||x||_1: 5.2384 (制約は4.654308592522079以下)
#
# --- レイヤー 'layer2.0.conv2' の処理を開始 ---
# Tensor shape: (128, 128, 3, 3), K1=17337.284550060594, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.0000
# Iteration 11/30, Reconstruction Error: 0.3975
# Iteration 21/30, Reconstruction Error: 0.3974
# Tensor shape: (128, 128, 3, 3), K1=10259.815107518834, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.3974
# Iteration 11/30, Reconstruction Error: 0.4619
# Iteration 21/30, Reconstruction Error: 0.4379
# L1ノルムの変化 = 20.29048036514569%
# Tensor shape: (128, 128, 3, 3), K1=8358.525027635202, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.4291
# Iteration 11/30, Reconstruction Error: 0.5232
# Iteration 21/30, Reconstruction Error: 0.4932
# L1ノルムの変化 = 19.706949119032892%
# Tensor shape: (128, 128, 3, 3), K1=6973.650783051856, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.4847
# Iteration 11/30, Reconstruction Error: 0.5659
# Iteration 21/30, Reconstruction Error: 0.5464
# L1ノルムの変化 = 18.541742244061677%
# Tensor shape: (128, 128, 3, 3), K1=5996.425320432519, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.5378
# Iteration 11/30, Reconstruction Error: 0.6004
# Iteration 21/30, Reconstruction Error: 0.5893
# L1ノルムの変化 = 15.894629438194844%
# Tensor shape: (128, 128, 3, 3), K1=5292.789248296541, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.5818
# Iteration 11/30, Reconstruction Error: 0.6289
# Iteration 21/30, Reconstruction Error: 0.6231
# L1ノルムの変化 = 12.891353468130637%
# Tensor shape: (128, 128, 3, 3), K1=4774.592700274073, K0=38547 (26.1%)
# Iteration 1/30, Reconstruction Error: 0.6162
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[142], line 28
#      26 for i in range(10):
#      27     k1 = K1_val*np.sum(np.abs(x))
# ---> 28     admm_result = solve_admm(w_numpy, D_op_4d, DT_op_4d, k1, K0_ratio_val, rho_val, gamma_val, iterations, x, y, z, u1, u2)
#      29     x_was=x
#      30     x=admm_result[0]
#
# Cell In[138], line 59, in solve_admm(w, D_op, DT_op, K1, K0_ratio, rho, gamma, n_iter, x, y, z, u1, u2)
#      57 # 2. y の更新
#      58 v_proj1 = D_op(x) + u1
# ---> 59 y = project_l1_ball(v_proj1, K1)
#      61 # 3. z の更新
#      62 v_proj2 = x + u2
#
# Cell In[136], line 18, in project_l1_ball(tensor_x, radius)
#      14 u_tensor = np.abs(tensor_x)
#      16 # ステップ 4: 絶対値テンソル `u_tensor` を降順にソートする。
#      17 # このソートが、効率的なアルゴリズムの鍵となる。
# ---> 18 u_sorted = np.sort(u_tensor, axis=None)[::-1]
#      19 n_features = len(u_sorted)
#      21 # ステップ 5: ソートされたベクトルの累積和を計算する。
#      22 # sv[i-1] は、u の中で最も大きい i 個の要素の和を表す。
#
# File <__array_function__ internals>:180, in sort(*args, **kwargs)
#
# File ~/.conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1004, in sort(a, axis, kind, order)
#    1002 else:
#    1003     a = asanyarray(a).copy(order="K")
# -> 1004 a.sort(axis=axis, kind=kind, order=order)
#    1005 return a
#
# KeyboardInterrupt:

# %%
zero_percentage_list = []

for i in range(10):
    # 更新後の重みの値を見る
    threshold = 10**-i

    print(f"閾値 {threshold} を使って、永続的なプルーニングマスクを適用します。")

    # 2. マスクを適用したいパラメータをリストアップ
    #    ここでは、全ての畳み込み層の'weight'を対象にします。
    parameters_to_prune = [
        (module, "weight")
        for module in model.modules()
        if isinstance(module, torch.nn.Conv2d)
    ]

    # 3. 各レイヤーに対して、現在の重みを基にカスタムマスクを作成し、適用する
    for module, name in parameters_to_prune:
        # 現在の重みを取得
        weights = getattr(module, name).detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        mask = (torch.abs(weights) > threshold).float().to(weights.device)
        
        # カスタムマスクを適用
        prune.CustomFromMask.apply(module, name, mask=mask)

    with torch.no_grad():
        all_conv_params = 0
        all_conv_zeros = 0
        for module, name in parameters_to_prune:
            weight_after_pruning = module.weight
            num_zeros = (weight_after_pruning == 0).sum().item()
            total_params = weight_after_pruning.numel()
            sparsity = 100. * num_zeros / total_params

            # 全体で何％枝刈りされたか考える
            all_conv_params += total_params
            all_conv_zeros += num_zeros

            print(f"{name}の重みのゼロの数: {num_zeros} / {total_params} ({sparsity:.4f}%)")

        all_conv_sparsity = 100. * all_conv_zeros / all_conv_params
        print(f"全畳み込み層の0率：{all_conv_sparsity:.4f}%")
        zero_percentage_list.append(all_conv_sparsity)

        for module, name in parameters_to_prune:
            # 1. 元の重み('weight_orig')を退避
            original_weights = module.weight_orig.clone()

            # 2. prune.removeでフックとマスクを削除
            prune.remove(module, 'weight')

            # 3. 退避した元の重みで上書き
            module.weight.data.copy_(original_weights)

plt.plot(zero_percentage_list)
plt.xticks(range(10))
plt.yticks(np.arange(40, 101, 5))
plt.grid()
plt.xlabel('(1e-x)')
plt.ylabel('zero_percent')
plt.show()

# 0マスクをつける閾値は1e-4か1e-5くらいがよさそう
# Out:
# 閾値 1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9408 / 9408 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 73728 / 73728 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 8192 / 8192 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 294912 / 294912 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 32768 / 32768 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 1179648 / 1179648 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 131072 / 131072 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# 全畳み込み層の0率：100.0000%
# 閾値 0.1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9406 / 9408 (99.9787%)
# weightの重みのゼロの数: 36829 / 36864 (99.9051%)
# weightの重みのゼロの数: 36681 / 36864 (99.5036%)
# weightの重みのゼロの数: 36711 / 36864 (99.5850%)
# weightの重みのゼロの数: 36708 / 36864 (99.5768%)
# weightの重みのゼロの数: 73571 / 73728 (99.7871%)
# weightの重みのゼロの数: 147124 / 147456 (99.7748%)
# weightの重みのゼロの数: 7824 / 8192 (95.5078%)
# weightの重みのゼロの数: 147214 / 147456 (99.8359%)
# weightの重みのゼロの数: 147341 / 147456 (99.9220%)
# weightの重みのゼロの数: 294055 / 294912 (99.7094%)
# weightの重みのゼロの数: 589115 / 589824 (99.8798%)
# weightの重みのゼロの数: 32577 / 32768 (99.4171%)
# weightの重みのゼロの数: 588472 / 589824 (99.7708%)
# weightの重みのゼロの数: 589071 / 589824 (99.8723%)
# weightの重みのゼロの数: 1178785 / 1179648 (99.9268%)
# weightの重みのゼロの数: 2358565 / 2359296 (99.9690%)
# weightの重みのゼロの数: 129544 / 131072 (98.8342%)
# weightの重みのゼロの数: 2358926 / 2359296 (99.9843%)
# weightの重みのゼロの数: 2358991 / 2359296 (99.9871%)
# 全畳み込み層の0率：99.9158%
# 閾値 0.01 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9396 / 9408 (99.8724%)
# weightの重みのゼロの数: 36740 / 36864 (99.6636%)
# weightの重みのゼロの数: 31160 / 36864 (84.5269%)
# weightの重みのゼロの数: 35774 / 36864 (97.0432%)
# weightの重みのゼロの数: 33166 / 36864 (89.9685%)
# weightの重みのゼロの数: 70856 / 73728 (96.1046%)
# weightの重みのゼロの数: 139729 / 147456 (94.7598%)
# weightの重みのゼロの数: 4826 / 8192 (58.9111%)
# weightの重みのゼロの数: 142881 / 147456 (96.8974%)
# weightの重みのゼロの数: 138414 / 147456 (93.8680%)
# weightの重みのゼロの数: 256730 / 294912 (87.0531%)
# weightの重みのゼロの数: 538853 / 589824 (91.3583%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：92.1579%
# 閾値 0.001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9396 / 9408 (99.8724%)
# weightの重みのゼロの数: 36614 / 36864 (99.3218%)
# weightの重みのゼロの数: 23416 / 36864 (63.5200%)
# weightの重みのゼロの数: 25245 / 36864 (68.4814%)
# weightの重みのゼロの数: 24199 / 36864 (65.6440%)
# weightの重みのゼロの数: 54675 / 73728 (74.1577%)
# weightの重みのゼロの数: 117512 / 147456 (79.6929%)
# weightの重みのゼロの数: 4357 / 8192 (53.1860%)
# weightの重みのゼロの数: 125010 / 147456 (84.7778%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.4914%
# 閾値 0.0001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 6561 / 9408 (69.7385%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 23022 / 36864 (62.4512%)
# weightの重みのゼロの数: 22202 / 36864 (60.2268%)
# weightの重みのゼロの数: 22933 / 36864 (62.2097%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0222%
# 閾値 1e-05 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231112 / 294912 (78.3664%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0000%
# 閾値 1e-06 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22949 / 36864 (62.2531%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22858 / 36864 (62.0063%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231057 / 294912 (78.3478%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24063 / 32768 (73.4344%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：89.9987%
# 閾値 1e-07 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 10610 / 36864 (28.7815%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 20102 / 36864 (54.5302%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231057 / 294912 (78.3478%)
# weightの重みのゼロの数: 446792 / 589824 (75.7501%)
# weightの重みのゼロの数: 21382 / 32768 (65.2527%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：89.4559%
# 閾値 1e-08 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 10374 / 36864 (28.1413%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 11283 / 36864 (30.6071%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 230949 / 294912 (78.3112%)
# weightの重みのゼロの数: 196792 / 589824 (33.3645%)
# weightの重みのゼロの数: 8937 / 32768 (27.2736%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：87.0237%
# 閾値 1e-09 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 2360 / 36864 (6.4019%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 5487 / 36864 (14.8844%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 230949 / 294912 (78.3112%)
# weightの重みのゼロの数: 60767 / 589824 (10.3026%)
# weightの重みのゼロの数: 7009 / 32768 (21.3898%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：85.6646%

# %%
# maskをつくる
threshold = 1e-4   #1e-4が基準

masks = {}

for name, module in model.named_modules():
    if isinstance(module, torch.nn.Conv2d):
        # 現在の重みを取得
        weights = module.weight.detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        masks[name] = (torch.abs(weights) > threshold).float().to(weights.device)

# %%
# カスタムマスクを適用
# ブロックスパースアルゴリズム前の密モデルの重みに対してマスクをかける
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])

# %%
# ADMM後のモデルにマスクをかける
'''
for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])
'''
# Out:
# '\nfor name, module in model.named_modules(): \n    if name in masks:\n        prune.CustomFromMask.apply(module, "weight", mask=masks[name])\n'

# %%
# ゼロ比率を表示
all_conv_params = 0
all_conv_zeros = 0

for name, module in model.named_modules():
  if isinstance(module, torch.nn.Conv2d):
    print(f"{name} Zero-Ratio: {100.0 * float(torch.sum(module.weight == 0)) / float(module.weight.nelement()):.4f}%")
    weight_after_pruning = module.weight
    num_zeros = (weight_after_pruning == 0).sum().item()
    total_params = weight_after_pruning.numel()
    all_conv_params += total_params
    all_conv_zeros += num_zeros

sparsity = 100. * all_conv_zeros / all_conv_params if all_conv_params > 0 else 0
print(f"全畳み込み層の0率：{sparsity:.4f}%")
# Out:
# conv1 Zero-Ratio: 45.4826%
# layer1.0.conv1 Zero-Ratio: 65.5084%
# layer1.0.conv2 Zero-Ratio: 62.2776%
# layer1.1.conv1 Zero-Ratio: 60.0586%
# layer1.1.conv2 Zero-Ratio: 62.0253%
# layer2.0.conv1 Zero-Ratio: 65.6955%
# layer2.0.conv2 Zero-Ratio: 73.8586%
# layer2.0.downsample.0 Zero-Ratio: 53.1250%
# layer2.1.conv1 Zero-Ratio: 72.8794%
# layer2.1.conv2 Zero-Ratio: 75.4591%
# layer3.0.conv1 Zero-Ratio: 78.3671%
# layer3.0.conv2 Zero-Ratio: 83.0126%
# layer3.0.downsample.0 Zero-Ratio: 73.6694%
# layer3.1.conv1 Zero-Ratio: 86.3091%
# layer3.1.conv2 Zero-Ratio: 88.2426%
# layer4.0.conv1 Zero-Ratio: 89.0463%
# layer4.0.conv2 Zero-Ratio: 92.7996%
# layer4.0.downsample.0 Zero-Ratio: 72.6631%
# layer4.1.conv1 Zero-Ratio: 91.6370%
# layer4.1.conv2 Zero-Ratio: 97.5670%
# 全畳み込み層の0率：90.0000%

# %%
# 再訓練
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)   #lr = 0.001で損失0.02とか
num_epochs = 15
epoch_loss_list = []
# CosineAnnealingLRを定義
# T_max: 学習率が半周期で最小値になるまでのエポック数。通常、総エポック数を指定。
# eta_min: 最小学習率。
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=0)

for epoch in range(num_epochs):
  model.train()
  model = model.to(device)
  total_loss = 0.0
  num_train = 0
  for inputs, labels in trainloader:
    inputs, labels = inputs.to(device), labels.to(device)   # データ代入

    # 重み更新のための手順
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # 損失を記録
    total_loss += loss.item()*labels.size(0)
    num_train+=labels.size(0)

  # 出力と記録
  epoch_loss_list.append(total_loss/num_train)
  current_lr = optimizer.param_groups[0]['lr']
  print(f'Epoch[{epoch+1}/{num_epochs}], Loss: {epoch_loss_list[epoch]:.4f}, LR: {current_lr:.8f}')


  # 次のエポックへの準備
  if epoch >= 1:
    if np.abs(epoch_loss_list[epoch]-epoch_loss_list[epoch-1]) < 0.001:
      break
  scheduler.step()
# Out:
# Epoch[1/15], Loss: 0.3555, LR: 0.00100000
# Epoch[2/15], Loss: 0.1224, LR: 0.00098907
# Epoch[3/15], Loss: 0.0577, LR: 0.00095677
# Epoch[4/15], Loss: 0.0297, LR: 0.00090451
# Epoch[5/15], Loss: 0.0148, LR: 0.00083457
# Epoch[6/15], Loss: 0.0075, LR: 0.00075000
# Epoch[7/15], Loss: 0.0021, LR: 0.00065451
# Epoch[8/15], Loss: 0.0007, LR: 0.00055226
# Epoch[9/15], Loss: 0.0004, LR: 0.00044774

# %%
# 損失グラフ作成
plt.plot(epoch_loss_list)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# 永続化（マスクと重みを掛ける）
for module in model.modules():
  if isinstance(module, torch.nn.Conv2d):
    prune.remove(module, "weight")

# %%
# onnxファイルとptファイルの作成
model = model.to('cpu')
model_to_onnx(model, "MM_ADMM_blocksparse_trained.onnx")
torch.save(model.state_dict(), "MM_ADMM_blocksparse_trained.pt")
