# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.utils.prune as prune
import torchvision.models as models
from torch.onnx import export

import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torch.nn.utils import parameters_to_vector
from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.optim.lr_scheduler import CosineAnnealingLR

# %%
# 乱数を一定にする
seed = 777  # 好きな数字でOK
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# onnxファイルを作成する関数
def model_to_onnx(model, output_file, input_shape = (1, 3, 224, 224)):
  model.eval()
  input_tensor = torch.randn(input_shape).to('cpu')
  input_names = ['input']
  output_names = ['output']
  torch.onnx.export(model, input_tensor, output_file, verbose = False, input_names = input_names, output_names = output_names)
  return output_file

# %%
# モデル読み込み
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# 訓練データセット作成
transform = transforms.Compose([transforms.Resize(224),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])   # 正規化したほうがいいらしい

trainset = torchvision.datasets.CIFAR10(root = "./data", train = True, download = True, transform = transform)
trainloader = DataLoader(trainset, batch_size = 400, shuffle = True)

# %%
def project_l1_ball(tensor_x: np.ndarray, radius: float) -> np.ndarray:
    """
    テンソル `tensor_x` を、中心が原点のL1ノルム半径 `radius` の超球（L1ボール）の表面または内部に射影する。
    これは、制約条件 ||z||_1 <= radius を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    アルゴリズムは、"Projection onto the L1-ball" として知られる効率的な手法に基づいている。
    """
    # ステップ 1: 入力テンソルのL1ノルムを計算し、そもそも射影が必要かを確認
    # もしL1ノルムが既に半径以下なら、テンソルは制約を満たしており、何もしなくてよい。
    if np.sum(np.abs(tensor_x)) <= radius:
        return tensor_x

    # ステップ 3: 符号情報を無視し、絶対値のテンソルを作成
    # 射影アルゴリズムは、正の象限（すべての要素が非負）で動作し、最後に元の符号を復元する。
    u_tensor = np.abs(tensor_x)

    # ステップ 4: 絶対値テンソル `u_tensor` を降順にソートする。
    # このソートが、効率的なアルゴリズムの鍵となる。
    u_sorted = np.sort(u_tensor, axis=None)[::-1]
    n_features = len(u_sorted)

    # ステップ 5: ソートされたベクトルの累積和を計算する。
    # sv[i-1] は、u の中で最も大きい i 個の要素の和を表す。
    sv = np.cumsum(u_sorted)

    # ステップ 6: 射影の閾値 `theta` を見つけるための条件を満たす `rho` を探す。
    # ここがアルゴリズムの核心部分。
    # 数学的な導出により、射影後のベクトルは `y = sign(v) * max(abs(v) - theta, 0)` という形になることが分かっている。
    # この `y` のL1ノルムが `radius` に等しくなるような `theta` を見つけたい。
    # そのための条件が `u_sorted[i-1] > (sv[i-1] - radius) / i` であり、
    # この条件を満たす最大のインデックスが `rho` となる。
    
    # i = 1, 2, ..., n_features を生成
    arange_i = np.arange(1, n_features + 1)
    
    # 条件を満たすインデックスの候補を探す
    rho_candidates = np.where(u_sorted > (sv - radius) / arange_i)[0]
    
    # 候補の中から最大のインデックスをrhoとして採用する（0-basedから1-basedに変換するため+1）
    # 候補がない場合は、すべての要素が同じだけシフトされるケース
    rho = rho_candidates[-1] + 1 if len(rho_candidates) > 0 else n_features

    # ステップ 7: 決定した `rho` を使って、最終的なシフト量 `theta` を計算する。
    # thetaは、各要素から（絶対値の形で）引き算される値。
    theta = (sv[rho - 1] - radius) / rho

    # ステップ 8: ソフトしきい値処理（soft-thresholding）を実行して、射影を完了させる。
    # 1. 各要素の絶対値から `theta` を引く。
    # 2. 結果が負になった場合は0にする（`np.maximum(..., 0)`）。
    # 3. 元の符号 `sign(v)` を掛け合わせて、正しい象限に戻す。
    projected_tensor_x = np.sign(tensor_x) * np.maximum(np.abs(tensor_x) - theta, 0)

    # ステップ 9: 返す。
    return projected_tensor_x

def hard_threshold(tensor_x: np.ndarray, K0: int) -> np.ndarray:
    """
    テンソル `tensor_x` に対してハードしきい値処理を適用する。
    これは、制約条件 ||z||_0 <= K0 を満たす、最も `tensor_x` に近い点 `z` を見つける操作。
    簡単に言うと、テンソルの要素のうち、絶対値が大きい方から `K0` 個だけを残し、
    それ以外をすべて厳密に0にする。
    """
    # ステップ 1: そもそも処理が必要かを確認
    # もし残したい非ゼロ要素の数 `K0` が、テンソルの全要素数以上なら、
    # どの要素も0にする必要はないので、そのまま返す。
    if K0 >= tensor_x.size:
        return tensor_x
    
    # ステップ 3: 0にすべき要素を決定するための「しきい値」を見つける。
    # しきい値は、ベクトル `v` の絶対値を小さい順にソートしたとき、
    # 後ろから `K0` 番目（つまり、絶対値が `K0` 番目に大きい要素）の値となる。
    # 例: v=[10, -2, 5, -8], K0=2 の場合、abs(v)=[10, 2, 5, 8]。
    #    ソートすると [2, 5, 8, 10]。後ろから2番目は `8`。これがしきい値となる。
    # 同じ値の要素があった場合は非ゼロの要素がK0
    threshold = np.sort(np.abs(tensor_x), axis=None)[-(K0+1)]

    # ステップ 4: しきい値に基づいて、値を0にする。
    # 絶対値がこのしきい値より「小さい」すべての要素を0で上書きする。
    # 例: abs(v) < 8 となるのは `2` と `5`。対応する元の要素 `-2` と `5` が0になる。
    tensor_x[np.abs(tensor_x) <= threshold] = 0

    return tensor_x

# %%
def D_op_4d(tensor: np.ndarray) -> np.ndarray:
    """
    4階数テンソル (out_ch, in_ch, h, w) の4方向の差分を計算し、
    5階数テンソル (out_ch, in_ch, h, w, 4) として返す。
    """
    # dim=0 (出力チャネル方向)
    diff_dim0 = np.roll(tensor, -1, axis=0) - tensor
    # dim=1 (入力チャネル方向)
    diff_dim1 = np.roll(tensor, -1, axis=1) - tensor
    # dim=2 (縦方向)
    diff_dim2 = np.roll(tensor, -1, axis=2) - tensor
    # dim=3 (横方向)
    diff_dim3 = np.roll(tensor, -1, axis=3) - tensor
    
    # 最後の軸に4つの差分をスタックする
    return np.stack([diff_dim0, diff_dim1, diff_dim2, diff_dim3], axis=-1)

# 転置差分がどんな演算なのかいまいちわかってない
def DT_op_4d(stacked_tensor: np.ndarray) -> np.ndarray:
    """
    D_op_4dの転置演算。5階数テンソルを受け取り、4階数テンソルを返す。
    """
    # 各差分を取り出す
    d0 = stacked_tensor[..., 0]
    d1 = stacked_tensor[..., 1]
    d2 = stacked_tensor[..., 2]
    d3 = stacked_tensor[..., 3]

    # 各々の転置差分を計算し、合計する (D^T = -D_backward)
    term0 = np.roll(d0, 1, axis=0) - d0
    term1 = np.roll(d1, 1, axis=1) - d1
    term2 = np.roll(d2, 1, axis=2) - d2
    term3 = np.roll(d3, 1, axis=3) - d3
    
    return term0 + term1 + term2 + term3

# %%
from scipy.sparse.linalg import cg, LinearOperator # LinearOperatorをインポート

def solve_admm(
    w: np.ndarray, 
    D_op, 
    DT_op, 
    K1: float, 
    K0_ratio: float, 
    rho: float, 
    gamma: float,
    n_iter: int,
    x: float,
    y: float,
    z: float,
    u1: float,
    u2: float,
):
    
    K0 = int(K0_ratio * w.size)
    
    # テンソルの総要素数を計算 (LinearOperatorのshape定義のため)
    n_elements = w.size

    print(f"Tensor shape: {w.shape}, K1={K1}, K0={K0} ({K0_ratio*100:.1f}%)")

    # ★★★ ここからが大幅な変更点 ★★★

    # 1. matvec関数を定義 (入力と出力が1次元ベクトルであることを明示)
    def matvec_for_lo(p_flat: np.ndarray) -> np.ndarray:
        # 内部で型変換は行わず、入力の型を信頼する
        p = p_flat.reshape(w.shape)
        DTD_p = DT_op(D_op(p))
        result = rho * DTD_p + gamma * p + p
        return result.flatten()

    # 2. LinearOperatorを明示的に作成
    # これにより、shapeとdtypeをcg関数に正確に伝える
    A = LinearOperator(
        shape=(n_elements, n_elements), # 作用素は (N, N) の正方行列として振る舞う
        matvec=matvec_for_lo,
        dtype=np.float64               # 扱うデータ型は float64 であることを明記
    )

    # ★★★ 変更ここまで ★★★


    # --- ADMM反復ループ ---
    for i in range(n_iter):
        # 1. x の更新
        # v は float64 であることを確認済み
        v = w + rho * DT_op(y - u1) + gamma * (z - u2)
        
        # LinearOperatorオブジェクト A を直接cgに渡す
        x_flat, _ = cg(A, v.flatten(), x0=x.flatten())
        x = x_flat.reshape(w.shape)

        # 2. y の更新
        v_proj1 = D_op(x) + u1
        y = project_l1_ball(v_proj1, K1)

        # 3. z の更新
        v_proj2 = x + u2
        z = hard_threshold(v_proj2, K0)

        # 4. 双対変数 u1, u2 の更新
        u1 = u1 + D_op(x) - y
        u2 = u2 + x - z

        recon_error = np.linalg.norm(x - w) / np.linalg.norm(w)

        if i != 0:
            if np.abs(recon_error - ex_recon_error) < 1e-4:   # 前回と0.01%未満しか変化がなければ、ループを終える
                print(f"0.01%未満しか変化がないので、{i+1}回目で終了。Reconstruction Error: {recon_error:.4f}")
                break
        
        if i % 5 == 0:
            print(f"Iteration {i+1}/{n_iter}, Reconstruction Error: {recon_error:.4f}")
        
        ex_recon_error = recon_error

    return x, y, z, u1, u2, K1

# %%
def Omega(delta):
    """
    4階テンソルdeltaの各次元に沿った差分を計算し、
    その絶対値の総和を返す。
    """
    h = 1.0  # Dのパラメータ

    # 4つの次元それぞれに対して差分（勾配）を計算

    # dim=0 (出力チャネル方向の差分)
    diff_dim0 = delta[1:, :, :, :] - delta[:-1, :, :, :]

    # dim=1 (入力チャネル方向の差分)
    diff_dim1 = delta[:, 1:, :, :] - delta[:, :-1, :, :]

    # dim=2 (縦方向の差分)
    # 1行目から最後までと、0行目から最後の一つ手前までの差
    diff_dim2 = delta[:, :, 1:, :] - delta[:, :, :-1, :]

    # dim=3 (横方向の差分)
    # 1列目から最後までと、0列目から最後の一つ手前までの差
    diff_dim3 = delta[:, :, :, 1:] - delta[:, :, :, :-1]

    # 全ての差分の絶対値の総和を計算
    # これがD@deltaに相当する操作のL1ノルムになる
    constrain = torch.sum(torch.abs(diff_dim0)) + torch.sum(torch.abs(diff_dim1)) + torch.sum(torch.abs(diff_dim2)) + torch.sum(torch.abs(diff_dim3))

    return constrain / h

# %%
# 各層のTVを見てみる
layer_tvs = {}
layer_relative_tvs = {}
conv_layer_names = []

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        w_tensor = module.weight.detach().clone().to(device)
        tv = Omega(w_tensor).item()
        ave_tv = tv/(w_tensor).numel()
        relative_tv = tv / torch.sum(torch.abs(w_tensor)).item()
        layer_tvs[name] = tv
        layer_relative_tvs[name] = relative_tv
        conv_layer_names.append(name)
        print(f"{name}：TV={tv:.4f}     ave_TV={ave_tv:.4f}     relative_TV={relative_tv:.4f}")
# Out:
# conv1：TV=2785.1948     ave_TV=0.2960     relative_TV=3.8864
# layer1.0.conv1：TV=5368.6899     ave_TV=0.1456     relative_TV=4.6001
# layer1.0.conv2：TV=5110.8359     ave_TV=0.1386     relative_TV=4.3279
# layer1.1.conv1：TV=5665.4883     ave_TV=0.1537     relative_TV=4.4829
# layer1.1.conv2：TV=5081.4331     ave_TV=0.1378     relative_TV=4.3692
# layer2.0.conv1：TV=9606.8564     ave_TV=0.1303     relative_TV=4.4254
# layer2.0.conv2：TV=15700.7480     ave_TV=0.1065     relative_TV=4.4383
# layer2.0.downsample.0：TV=1077.2024     ave_TV=0.1315     relative_TV=2.9591
# layer2.1.conv1：TV=16048.6338     ave_TV=0.1088     relative_TV=4.4778
# layer2.1.conv2：TV=14007.5215     ave_TV=0.0950     relative_TV=4.2592
# layer3.0.conv1：TV=24442.1191     ave_TV=0.0829     relative_TV=3.9467
# layer3.0.conv2：TV=45506.3359     ave_TV=0.0772     relative_TV=4.1868
# layer3.0.downsample.0：TV=2261.6729     ave_TV=0.0690     relative_TV=2.8949
# layer3.1.conv1：TV=41485.1523     ave_TV=0.0703     relative_TV=4.2055
# layer3.1.conv2：TV=37498.1641     ave_TV=0.0636     relative_TV=4.0776
# layer4.0.conv1：TV=70836.3359     ave_TV=0.0600     relative_TV=3.9260
# layer4.0.conv2：TV=134329.4375     ave_TV=0.0569     relative_TV=4.2296
# layer4.0.downsample.0：TV=9025.8906     ave_TV=0.0689     relative_TV=2.8755
# layer4.1.conv1：TV=129517.4688     ave_TV=0.0549     relative_TV=3.8883
# layer4.1.conv2：TV=81123.4766     ave_TV=0.0344     relative_TV=3.3774
# /home/rkaneko/.conda/lib/python3.10/site-packages/torch/cuda/__init__.py:789: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
import json

# JSONファイルから辞書を読み込む
with open('90cut_data.json', 'r') as f:
    zero_ratings = json.load(f)

with open('90cut_relativeTV.json', 'r') as f:
    layer_90cut_relative_tvs = json.load(f)

print(zero_ratings)
print(layer_90cut_relative_tvs)
# Out:
# {'conv1': 0.45471938775510207, 'layer1.0.conv1': 0.6550564236111112, 'layer1.0.conv2': 0.6227756076388888, 'layer1.1.conv1': 0.6005859375, 'layer1.1.conv2': 0.6202528211805556, 'layer2.0.conv1': 0.6569552951388888, 'layer2.0.conv2': 0.73858642578125, 'layer2.0.downsample.0': 0.53125, 'layer2.1.conv1': 0.7287868923611112, 'layer2.1.conv2': 0.7545912000868056, 'layer3.0.conv1': 0.7836710611979166, 'layer3.0.conv2': 0.8301255967881944, 'layer3.0.downsample.0': 0.7366943359375, 'layer3.1.conv1': 0.8630913628472222, 'layer3.1.conv2': 0.8824259440104166, 'layer4.0.conv1': 0.8904622395833334, 'layer4.0.conv2': 0.9279958936903212, 'layer4.0.downsample.0': 0.7266311645507812, 'layer4.1.conv1': 0.9163699679904513, 'layer4.1.conv2': 0.9756698608398438}
# {'conv1': 4.027483465904622, 'layer1.0.conv1': 5.187465703233075, 'layer1.0.conv2': 5.018088421462655, 'layer1.1.conv1': 5.1439845812105345, 'layer1.1.conv2': 5.073877961406653, 'layer2.0.conv1': 5.171453991691199, 'layer2.0.conv2': 5.445477096898191, 'layer2.0.downsample.0': 3.290322149753673, 'layer2.1.conv1': 5.457166442246035, 'layer2.1.conv2': 5.329104132585309, 'layer3.0.conv1': 4.953840272616876, 'layer3.0.conv2': 5.446103003405924, 'layer3.0.downsample.0': 3.529604452799148, 'layer3.1.conv1': 5.575070285575484, 'layer3.1.conv2': 5.511405656525587, 'layer4.0.conv1': 5.356365754800536, 'layer4.0.conv2': 6.169967069786414, 'layer4.0.downsample.0': 3.4884049950864453, 'layer4.1.conv1': 5.640184190467383, 'layer4.1.conv2': 4.877897042575949}

# %%
final_weights_to_assign = {}

for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        print(f"\n--- レイヤー '{name}' の処理を開始 ---")

        # wを4階テンソルのまま取得
        # .detach().clone()で勾配情報を切り離し、安全なコピーを作成し、numpyに変換、scipyのcg法に合うようにfloat64に
        w_numpy = module.weight.detach().clone().to('cpu').numpy().astype(np.float64)

        # --- パラメータ設定と実行 ---
        K1_val = layer_90cut_relative_tvs[name]*0.5       # Relative Total Variationの上限
        K0_ratio_val = 1 - zero_ratings[name]   # 10%を非ゼロにする (目標のスパース率90%)
        rho_val = 0.0001        # block性ペナルティパラメータ
        gamma_val = 1.0   # sparse性ペナルティパラメータ
        iterations = 200   # 繰り返し回数

        # --- 初期化 ---
        # 全ての変数を float64 で厳密に初期化
        x  = w_numpy.copy().astype(np.float64)
        y = D_op_4d(x).astype(np.float64)
        z = x.copy().astype(np.float64)
        u1 = np.zeros_like(y, dtype=np.float64)
        u2 = np.zeros_like(z, dtype=np.float64)

        for i in range(10):
            k1 = K1_val*np.sum(np.abs(x))
            admm_result = solve_admm(w_numpy, D_op_4d, DT_op_4d, k1, K0_ratio_val, rho_val, gamma_val, iterations, x, y, z, u1, u2)
            x_was=x
            x=admm_result[0]
            y=admm_result[1]
            z=admm_result[2]
            u1=admm_result[3]
            u2=admm_result[4]
            k1=admm_result[5]
            if i > 0:
                l2norm_change = np.linalg.norm(x-x_was) / np.linalg.norm(x)
                print(f'xのL2ノルムの変化 = {l2norm_change*100}%')
                if l2norm_change < 0.01:   # 1%未満しか変化していなければ
                    print("xのL2ノルムは1%以下しか変化していないのでearly stopします。")
                    break
            if i == 9:
                print("外のループを規定回数（20回）回しました")
        x_final = x
            
        with torch.no_grad():
            module.weight.copy_(torch.tensor(x_final))

        # 閾値で0に近い値を完全な0にする
        x_final[np.abs(x_final) <= 1e-4] = 0

        # 結果の簡単な確認
        print("\n結果:")
        print(f"元の重みテンソルの非ゼロの要素数: {np.sum(w_numpy != 0)}")
        print(f"ADMM後の重みテンソルの非ゼロの要素数: {np.sum(x_final != 0)} (目標数{int(K0_ratio_val * w_numpy.size)})")
        print(f"||Dx||_1 / ||x||_1: {np.sum(np.abs(D_op_4d(x_final))) / np.sum(np.abs(x_final)):.4f} (制約は{K1_val}以下)")
# Out:
# --- レイヤー 'conv1' の処理を開始 ---
# Tensor shape: (64, 3, 7, 7), K1=1443.1429115325914, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.0000
# Iteration 6/200, Reconstruction Error: 0.0746
# Iteration 11/200, Reconstruction Error: 0.0747
# Iteration 16/200, Reconstruction Error: 0.0747
# Iteration 21/200, Reconstruction Error: 0.0747
# Iteration 26/200, Reconstruction Error: 0.0748
# Iteration 31/200, Reconstruction Error: 0.0749
# Iteration 36/200, Reconstruction Error: 0.0750
# Iteration 41/200, Reconstruction Error: 0.0751
# Iteration 46/200, Reconstruction Error: 0.0752
# Iteration 51/200, Reconstruction Error: 0.0753
# Iteration 56/200, Reconstruction Error: 0.0755
# Iteration 61/200, Reconstruction Error: 0.0756
# Iteration 66/200, Reconstruction Error: 0.0758
# Iteration 71/200, Reconstruction Error: 0.0760
# Iteration 76/200, Reconstruction Error: 0.0761
# Iteration 81/200, Reconstruction Error: 0.0764
# Iteration 86/200, Reconstruction Error: 0.0766
# Iteration 91/200, Reconstruction Error: 0.0768
# Iteration 96/200, Reconstruction Error: 0.0771
# Iteration 101/200, Reconstruction Error: 0.0773
# Iteration 106/200, Reconstruction Error: 0.0776
# Iteration 111/200, Reconstruction Error: 0.0778
# Iteration 116/200, Reconstruction Error: 0.0781
# Iteration 121/200, Reconstruction Error: 0.0784
# Iteration 126/200, Reconstruction Error: 0.0787
# Iteration 131/200, Reconstruction Error: 0.0790
# Iteration 136/200, Reconstruction Error: 0.0793
# Iteration 141/200, Reconstruction Error: 0.0797
# Iteration 146/200, Reconstruction Error: 0.0800
# Iteration 151/200, Reconstruction Error: 0.0803
# Iteration 156/200, Reconstruction Error: 0.0807
# Iteration 161/200, Reconstruction Error: 0.0810
# Iteration 166/200, Reconstruction Error: 0.0814
# Iteration 171/200, Reconstruction Error: 0.0819
# Iteration 176/200, Reconstruction Error: 0.0822
# Iteration 181/200, Reconstruction Error: 0.0826
# Iteration 186/200, Reconstruction Error: 0.0830
# Iteration 191/200, Reconstruction Error: 0.0834
# Iteration 196/200, Reconstruction Error: 0.0839
# Tensor shape: (64, 3, 7, 7), K1=1297.6495758238134, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.0843
# Iteration 6/200, Reconstruction Error: 0.0848
# Iteration 11/200, Reconstruction Error: 0.0852
# Iteration 16/200, Reconstruction Error: 0.0857
# Iteration 21/200, Reconstruction Error: 0.0863
# Iteration 26/200, Reconstruction Error: 0.0868
# Iteration 31/200, Reconstruction Error: 0.0873
# Iteration 36/200, Reconstruction Error: 0.0879
# Iteration 41/200, Reconstruction Error: 0.0883
# Iteration 46/200, Reconstruction Error: 0.0889
# Iteration 51/200, Reconstruction Error: 0.0895
# Iteration 56/200, Reconstruction Error: 0.0900
# Iteration 61/200, Reconstruction Error: 0.0906
# Iteration 66/200, Reconstruction Error: 0.0912
# Iteration 71/200, Reconstruction Error: 0.0918
# Iteration 76/200, Reconstruction Error: 0.0923
# Iteration 81/200, Reconstruction Error: 0.0929
# Iteration 86/200, Reconstruction Error: 0.0934
# Iteration 91/200, Reconstruction Error: 0.0941
# Iteration 96/200, Reconstruction Error: 0.0947
# Iteration 101/200, Reconstruction Error: 0.0952
# Iteration 106/200, Reconstruction Error: 0.0959
# Iteration 111/200, Reconstruction Error: 0.0966
# Iteration 116/200, Reconstruction Error: 0.0971
# Iteration 121/200, Reconstruction Error: 0.0977
# Iteration 126/200, Reconstruction Error: 0.0984
# Iteration 131/200, Reconstruction Error: 0.0990
# Iteration 136/200, Reconstruction Error: 0.0997
# Iteration 141/200, Reconstruction Error: 0.1003
# Iteration 146/200, Reconstruction Error: 0.1009
# Iteration 151/200, Reconstruction Error: 0.1015
# Iteration 156/200, Reconstruction Error: 0.1022
# Iteration 161/200, Reconstruction Error: 0.1028
# Iteration 166/200, Reconstruction Error: 0.1034
# Iteration 171/200, Reconstruction Error: 0.1040
# Iteration 176/200, Reconstruction Error: 0.1045
# Iteration 181/200, Reconstruction Error: 0.1053
# Iteration 186/200, Reconstruction Error: 0.1059
# Iteration 191/200, Reconstruction Error: 0.1065
# Iteration 196/200, Reconstruction Error: 0.1072
# xのL2ノルムの変化 = 6.030469423157%
# Tensor shape: (64, 3, 7, 7), K1=1242.814771954702, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.1078
# Iteration 6/200, Reconstruction Error: 0.1085
# Iteration 11/200, Reconstruction Error: 0.1092
# Iteration 16/200, Reconstruction Error: 0.1100
# Iteration 21/200, Reconstruction Error: 0.1107
# Iteration 26/200, Reconstruction Error: 0.1115
# Iteration 31/200, Reconstruction Error: 0.1122
# Iteration 36/200, Reconstruction Error: 0.1130
# Iteration 41/200, Reconstruction Error: 0.1136
# Iteration 46/200, Reconstruction Error: 0.1144
# Iteration 51/200, Reconstruction Error: 0.1150
# Iteration 56/200, Reconstruction Error: 0.1157
# Iteration 61/200, Reconstruction Error: 0.1164
# Iteration 66/200, Reconstruction Error: 0.1171
# Iteration 71/200, Reconstruction Error: 0.1178
# Iteration 76/200, Reconstruction Error: 0.1184
# Iteration 81/200, Reconstruction Error: 0.1192
# Iteration 86/200, Reconstruction Error: 0.1198
# Iteration 91/200, Reconstruction Error: 0.1206
# Iteration 96/200, Reconstruction Error: 0.1214
# Iteration 101/200, Reconstruction Error: 0.1221
# Iteration 106/200, Reconstruction Error: 0.1228
# Iteration 111/200, Reconstruction Error: 0.1235
# Iteration 116/200, Reconstruction Error: 0.1242
# Iteration 121/200, Reconstruction Error: 0.1250
# Iteration 126/200, Reconstruction Error: 0.1257
# Iteration 131/200, Reconstruction Error: 0.1263
# Iteration 136/200, Reconstruction Error: 0.1269
# Iteration 141/200, Reconstruction Error: 0.1278
# Iteration 146/200, Reconstruction Error: 0.1285
# Iteration 151/200, Reconstruction Error: 0.1291
# Iteration 156/200, Reconstruction Error: 0.1299
# Iteration 161/200, Reconstruction Error: 0.1306
# Iteration 166/200, Reconstruction Error: 0.1313
# Iteration 171/200, Reconstruction Error: 0.1319
# Iteration 176/200, Reconstruction Error: 0.1329
# Iteration 181/200, Reconstruction Error: 0.1335
# Iteration 186/200, Reconstruction Error: 0.1340
# Iteration 191/200, Reconstruction Error: 0.1349
# Iteration 196/200, Reconstruction Error: 0.1357
# xのL2ノルムの変化 = 6.259464672703172%
# Tensor shape: (64, 3, 7, 7), K1=1192.124012588613, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.1363
# Iteration 6/200, Reconstruction Error: 0.1372
# Iteration 11/200, Reconstruction Error: 0.1379
# Iteration 16/200, Reconstruction Error: 0.1387
# Iteration 21/200, Reconstruction Error: 0.1393
# Iteration 26/200, Reconstruction Error: 0.1403
# Iteration 31/200, Reconstruction Error: 0.1410
# Iteration 36/200, Reconstruction Error: 0.1418
# Iteration 41/200, Reconstruction Error: 0.1426
# Iteration 46/200, Reconstruction Error: 0.1433
# Iteration 51/200, Reconstruction Error: 0.1440
# Iteration 56/200, Reconstruction Error: 0.1447
# Iteration 61/200, Reconstruction Error: 0.1455
# Iteration 66/200, Reconstruction Error: 0.1463
# Iteration 71/200, Reconstruction Error: 0.1470
# Iteration 76/200, Reconstruction Error: 0.1479
# Iteration 81/200, Reconstruction Error: 0.1485
# Iteration 86/200, Reconstruction Error: 0.1494
# Iteration 91/200, Reconstruction Error: 0.1500
# Iteration 96/200, Reconstruction Error: 0.1507
# Iteration 101/200, Reconstruction Error: 0.1515
# Iteration 106/200, Reconstruction Error: 0.1523
# Iteration 111/200, Reconstruction Error: 0.1528
# Iteration 116/200, Reconstruction Error: 0.1535
# Iteration 121/200, Reconstruction Error: 0.1544
# Iteration 126/200, Reconstruction Error: 0.1551
# Iteration 131/200, Reconstruction Error: 0.1559
# Iteration 136/200, Reconstruction Error: 0.1565
# Iteration 141/200, Reconstruction Error: 0.1571
# Iteration 146/200, Reconstruction Error: 0.1579
# Iteration 151/200, Reconstruction Error: 0.1587
# Iteration 156/200, Reconstruction Error: 0.1593
# Iteration 161/200, Reconstruction Error: 0.1601
# Iteration 166/200, Reconstruction Error: 0.1608
# Iteration 171/200, Reconstruction Error: 0.1613
# Iteration 176/200, Reconstruction Error: 0.1621
# Iteration 181/200, Reconstruction Error: 0.1627
# Iteration 186/200, Reconstruction Error: 0.1635
# Iteration 191/200, Reconstruction Error: 0.1643
# Iteration 196/200, Reconstruction Error: 0.1650
# xのL2ノルムの変化 = 6.437187961003057%
# Tensor shape: (64, 3, 7, 7), K1=1145.1568454681092, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.1656
# Iteration 6/200, Reconstruction Error: 0.1664
# Iteration 11/200, Reconstruction Error: 0.1671
# Iteration 16/200, Reconstruction Error: 0.1680
# Iteration 21/200, Reconstruction Error: 0.1688
# Iteration 26/200, Reconstruction Error: 0.1695
# Iteration 31/200, Reconstruction Error: 0.1702
# Iteration 36/200, Reconstruction Error: 0.1710
# Iteration 41/200, Reconstruction Error: 0.1717
# Iteration 46/200, Reconstruction Error: 0.1726
# Iteration 51/200, Reconstruction Error: 0.1733
# Iteration 56/200, Reconstruction Error: 0.1738
# Iteration 61/200, Reconstruction Error: 0.1747
# Iteration 66/200, Reconstruction Error: 0.1753
# Iteration 71/200, Reconstruction Error: 0.1758
# Iteration 76/200, Reconstruction Error: 0.1767
# Iteration 81/200, Reconstruction Error: 0.1776
# Iteration 86/200, Reconstruction Error: 0.1782
# Iteration 91/200, Reconstruction Error: 0.1792
# Iteration 96/200, Reconstruction Error: 0.1796
# Iteration 101/200, Reconstruction Error: 0.1804
# Iteration 106/200, Reconstruction Error: 0.1811
# Iteration 111/200, Reconstruction Error: 0.1819
# Iteration 116/200, Reconstruction Error: 0.1825
# Iteration 121/200, Reconstruction Error: 0.1833
# Iteration 126/200, Reconstruction Error: 0.1840
# Iteration 131/200, Reconstruction Error: 0.1846
# Iteration 136/200, Reconstruction Error: 0.1853
# Iteration 141/200, Reconstruction Error: 0.1862
# Iteration 146/200, Reconstruction Error: 0.1867
# Iteration 151/200, Reconstruction Error: 0.1874
# Iteration 156/200, Reconstruction Error: 0.1882
# Iteration 161/200, Reconstruction Error: 0.1888
# Iteration 166/200, Reconstruction Error: 0.1898
# Iteration 171/200, Reconstruction Error: 0.1903
# Iteration 176/200, Reconstruction Error: 0.1910
# Iteration 181/200, Reconstruction Error: 0.1917
# Iteration 186/200, Reconstruction Error: 0.1923
# Iteration 191/200, Reconstruction Error: 0.1929
# Iteration 196/200, Reconstruction Error: 0.1935
# xのL2ノルムの変化 = 6.509832844553869%
# Tensor shape: (64, 3, 7, 7), K1=1101.388781584655, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.1944
# Iteration 6/200, Reconstruction Error: 0.1952
# Iteration 11/200, Reconstruction Error: 0.1957
# Iteration 16/200, Reconstruction Error: 0.1965
# Iteration 21/200, Reconstruction Error: 0.1972
# Iteration 26/200, Reconstruction Error: 0.1979
# Iteration 31/200, Reconstruction Error: 0.1986
# Iteration 36/200, Reconstruction Error: 0.1995
# Iteration 41/200, Reconstruction Error: 0.2000
# Iteration 46/200, Reconstruction Error: 0.2009
# Iteration 51/200, Reconstruction Error: 0.2016
# Iteration 56/200, Reconstruction Error: 0.2024
# Iteration 61/200, Reconstruction Error: 0.2031
# Iteration 66/200, Reconstruction Error: 0.2038
# Iteration 71/200, Reconstruction Error: 0.2046
# Iteration 76/200, Reconstruction Error: 0.2053
# Iteration 81/200, Reconstruction Error: 0.2061
# Iteration 86/200, Reconstruction Error: 0.2067
# Iteration 91/200, Reconstruction Error: 0.2074
# Iteration 96/200, Reconstruction Error: 0.2080
# Iteration 101/200, Reconstruction Error: 0.2087
# Iteration 106/200, Reconstruction Error: 0.2095
# Iteration 111/200, Reconstruction Error: 0.2103
# Iteration 116/200, Reconstruction Error: 0.2108
# Iteration 121/200, Reconstruction Error: 0.2114
# Iteration 126/200, Reconstruction Error: 0.2122
# Iteration 131/200, Reconstruction Error: 0.2128
# Iteration 136/200, Reconstruction Error: 0.2136
# Iteration 141/200, Reconstruction Error: 0.2144
# Iteration 146/200, Reconstruction Error: 0.2148
# Iteration 151/200, Reconstruction Error: 0.2156
# Iteration 156/200, Reconstruction Error: 0.2163
# Iteration 161/200, Reconstruction Error: 0.2170
# Iteration 166/200, Reconstruction Error: 0.2175
# Iteration 171/200, Reconstruction Error: 0.2181
# Iteration 176/200, Reconstruction Error: 0.2189
# Iteration 181/200, Reconstruction Error: 0.2197
# Iteration 186/200, Reconstruction Error: 0.2203
# Iteration 191/200, Reconstruction Error: 0.2211
# Iteration 196/200, Reconstruction Error: 0.2215
# xのL2ノルムの変化 = 6.646708176177706%
# Tensor shape: (64, 3, 7, 7), K1=1060.4861025692621, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.2222
# Iteration 6/200, Reconstruction Error: 0.2229
# Iteration 11/200, Reconstruction Error: 0.2237
# Iteration 16/200, Reconstruction Error: 0.2244
# Iteration 21/200, Reconstruction Error: 0.2250
# Iteration 26/200, Reconstruction Error: 0.2257
# Iteration 31/200, Reconstruction Error: 0.2263
# Iteration 36/200, Reconstruction Error: 0.2271
# Iteration 41/200, Reconstruction Error: 0.2277
# Iteration 46/200, Reconstruction Error: 0.2285
# Iteration 51/200, Reconstruction Error: 0.2292
# Iteration 56/200, Reconstruction Error: 0.2299
# Iteration 61/200, Reconstruction Error: 0.2304
# Iteration 66/200, Reconstruction Error: 0.2309
# Iteration 71/200, Reconstruction Error: 0.2317
# Iteration 76/200, Reconstruction Error: 0.2325
# Iteration 81/200, Reconstruction Error: 0.2332
# Iteration 86/200, Reconstruction Error: 0.2338
# Iteration 91/200, Reconstruction Error: 0.2347
# Iteration 96/200, Reconstruction Error: 0.2352
# Iteration 101/200, Reconstruction Error: 0.2359
# Iteration 106/200, Reconstruction Error: 0.2367
# Iteration 111/200, Reconstruction Error: 0.2375
# Iteration 116/200, Reconstruction Error: 0.2380
# Iteration 121/200, Reconstruction Error: 0.2389
# Iteration 126/200, Reconstruction Error: 0.2392
# Iteration 131/200, Reconstruction Error: 0.2398
# Iteration 136/200, Reconstruction Error: 0.2405
# Iteration 141/200, Reconstruction Error: 0.2412
# Iteration 146/200, Reconstruction Error: 0.2418
# Iteration 151/200, Reconstruction Error: 0.2425
# Iteration 156/200, Reconstruction Error: 0.2430
# Iteration 161/200, Reconstruction Error: 0.2438
# Iteration 166/200, Reconstruction Error: 0.2441
# Iteration 171/200, Reconstruction Error: 0.2450
# Iteration 176/200, Reconstruction Error: 0.2457
# Iteration 181/200, Reconstruction Error: 0.2462
# Iteration 186/200, Reconstruction Error: 0.2470
# Iteration 191/200, Reconstruction Error: 0.2475
# Iteration 196/200, Reconstruction Error: 0.2482
# xのL2ノルムの変化 = 6.894893116546763%
# Tensor shape: (64, 3, 7, 7), K1=1022.2168693016583, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.2488
# Iteration 6/200, Reconstruction Error: 0.2496
# Iteration 11/200, Reconstruction Error: 0.2501
# Iteration 16/200, Reconstruction Error: 0.2508
# Iteration 21/200, Reconstruction Error: 0.2513
# Iteration 26/200, Reconstruction Error: 0.2520
# Iteration 31/200, Reconstruction Error: 0.2527
# Iteration 36/200, Reconstruction Error: 0.2532
# Iteration 41/200, Reconstruction Error: 0.2541
# Iteration 46/200, Reconstruction Error: 0.2548
# Iteration 51/200, Reconstruction Error: 0.2557
# Iteration 56/200, Reconstruction Error: 0.2559
# Iteration 61/200, Reconstruction Error: 0.2566
# Iteration 66/200, Reconstruction Error: 0.2574
# Iteration 71/200, Reconstruction Error: 0.2580
# Iteration 76/200, Reconstruction Error: 0.2585
# Iteration 81/200, Reconstruction Error: 0.2593
# Iteration 86/200, Reconstruction Error: 0.2597
# Iteration 91/200, Reconstruction Error: 0.2606
# Iteration 96/200, Reconstruction Error: 0.2611
# Iteration 101/200, Reconstruction Error: 0.2617
# Iteration 106/200, Reconstruction Error: 0.2625
# Iteration 111/200, Reconstruction Error: 0.2631
# Iteration 116/200, Reconstruction Error: 0.2637
# Iteration 121/200, Reconstruction Error: 0.2643
# Iteration 126/200, Reconstruction Error: 0.2661
# Iteration 131/200, Reconstruction Error: 0.2666
# Iteration 136/200, Reconstruction Error: 0.2672
# Iteration 141/200, Reconstruction Error: 0.2680
# Iteration 146/200, Reconstruction Error: 0.2688
# Iteration 151/200, Reconstruction Error: 0.2693
# Iteration 156/200, Reconstruction Error: 0.2698
# Iteration 161/200, Reconstruction Error: 0.2706
# Iteration 166/200, Reconstruction Error: 0.2709
# Iteration 171/200, Reconstruction Error: 0.2718
# Iteration 176/200, Reconstruction Error: 0.2723
# Iteration 181/200, Reconstruction Error: 0.2727
# Iteration 186/200, Reconstruction Error: 0.2735
# Iteration 191/200, Reconstruction Error: 0.2741
# Iteration 196/200, Reconstruction Error: 0.2747
# xのL2ノルムの変化 = 7.35559814236661%
# Tensor shape: (64, 3, 7, 7), K1=986.4456276595857, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.2754
# Iteration 6/200, Reconstruction Error: 0.2761
# Iteration 11/200, Reconstruction Error: 0.2771
# Iteration 16/200, Reconstruction Error: 0.2776
# Iteration 21/200, Reconstruction Error: 0.2782
# Iteration 26/200, Reconstruction Error: 0.2787
# Iteration 31/200, Reconstruction Error: 0.2792
# Iteration 36/200, Reconstruction Error: 0.2799
# Iteration 41/200, Reconstruction Error: 0.2806
# Iteration 46/200, Reconstruction Error: 0.2812
# Iteration 51/200, Reconstruction Error: 0.2817
# Iteration 56/200, Reconstruction Error: 0.2827
# Iteration 61/200, Reconstruction Error: 0.2831
# Iteration 66/200, Reconstruction Error: 0.2835
# Iteration 71/200, Reconstruction Error: 0.2844
# Iteration 76/200, Reconstruction Error: 0.2850
# Iteration 81/200, Reconstruction Error: 0.2855
# Iteration 86/200, Reconstruction Error: 0.2861
# Iteration 91/200, Reconstruction Error: 0.2867
# Iteration 96/200, Reconstruction Error: 0.2872
# Iteration 101/200, Reconstruction Error: 0.2878
# Iteration 106/200, Reconstruction Error: 0.2885
# Iteration 111/200, Reconstruction Error: 0.2891
# Iteration 116/200, Reconstruction Error: 0.2897
# Iteration 121/200, Reconstruction Error: 0.2902
# Iteration 126/200, Reconstruction Error: 0.2909
# Iteration 131/200, Reconstruction Error: 0.2916
# Iteration 136/200, Reconstruction Error: 0.2921
# Iteration 141/200, Reconstruction Error: 0.2927
# Iteration 146/200, Reconstruction Error: 0.2934
# Iteration 151/200, Reconstruction Error: 0.2939
# Iteration 156/200, Reconstruction Error: 0.2947
# Iteration 161/200, Reconstruction Error: 0.2951
# Iteration 166/200, Reconstruction Error: 0.2956
# Iteration 171/200, Reconstruction Error: 0.2962
# Iteration 176/200, Reconstruction Error: 0.2970
# Iteration 181/200, Reconstruction Error: 0.2975
# Iteration 186/200, Reconstruction Error: 0.2981
# Iteration 191/200, Reconstruction Error: 0.2989
# Iteration 196/200, Reconstruction Error: 0.2992
# xのL2ノルムの変化 = 7.114144119829138%
# Tensor shape: (64, 3, 7, 7), K1=953.1966139441413, K0=5129 (54.5%)
# Iteration 1/200, Reconstruction Error: 0.3000
# Iteration 6/200, Reconstruction Error: 0.3004
# Iteration 11/200, Reconstruction Error: 0.3010
# Iteration 16/200, Reconstruction Error: 0.3016
# Iteration 21/200, Reconstruction Error: 0.3024
# Iteration 26/200, Reconstruction Error: 0.3028
# Iteration 31/200, Reconstruction Error: 0.3034
# Iteration 36/200, Reconstruction Error: 0.3041
# Iteration 41/200, Reconstruction Error: 0.3046
# Iteration 46/200, Reconstruction Error: 0.3052
# Iteration 51/200, Reconstruction Error: 0.3058
# Iteration 56/200, Reconstruction Error: 0.3064
# Iteration 61/200, Reconstruction Error: 0.3069
# Iteration 66/200, Reconstruction Error: 0.3075
# Iteration 71/200, Reconstruction Error: 0.3080
# Iteration 76/200, Reconstruction Error: 0.3087
# Iteration 81/200, Reconstruction Error: 0.3093
# Iteration 86/200, Reconstruction Error: 0.3099
# Iteration 91/200, Reconstruction Error: 0.3105
# Iteration 96/200, Reconstruction Error: 0.3109
# Iteration 101/200, Reconstruction Error: 0.3114
# Iteration 106/200, Reconstruction Error: 0.3120
# Iteration 111/200, Reconstruction Error: 0.3124
# Iteration 116/200, Reconstruction Error: 0.3131
# Iteration 121/200, Reconstruction Error: 0.3139
# Iteration 126/200, Reconstruction Error: 0.3143
# Iteration 131/200, Reconstruction Error: 0.3149
# Iteration 136/200, Reconstruction Error: 0.3154
# Iteration 141/200, Reconstruction Error: 0.3160
# Iteration 146/200, Reconstruction Error: 0.3167
# Iteration 151/200, Reconstruction Error: 0.3173
# Iteration 156/200, Reconstruction Error: 0.3177
# Iteration 161/200, Reconstruction Error: 0.3183
# Iteration 166/200, Reconstruction Error: 0.3188
# Iteration 171/200, Reconstruction Error: 0.3194
# Iteration 176/200, Reconstruction Error: 0.3196
# Iteration 181/200, Reconstruction Error: 0.3203
# Iteration 186/200, Reconstruction Error: 0.3209
# Iteration 191/200, Reconstruction Error: 0.3215
# Iteration 196/200, Reconstruction Error: 0.3221
# xのL2ノルムの変化 = 7.19589554328883%
# 外のループを規定回数（20回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 9408
# ADMM後の重みテンソルの非ゼロの要素数: 5129 (目標数5129)
# ||Dx||_1 / ||x||_1: 4.2439 (制約は2.013741732952311以下)
#
# --- レイヤー 'layer1.0.conv1' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=3027.1176641582283, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.0000
# Iteration 6/200, Reconstruction Error: 0.2215
# Iteration 11/200, Reconstruction Error: 0.2215
# Iteration 16/200, Reconstruction Error: 0.2215
# Iteration 21/200, Reconstruction Error: 0.2216
# Iteration 26/200, Reconstruction Error: 0.2216
# Iteration 31/200, Reconstruction Error: 0.2216
# Iteration 36/200, Reconstruction Error: 0.2217
# Iteration 41/200, Reconstruction Error: 0.2217
# Iteration 46/200, Reconstruction Error: 0.2218
# Iteration 51/200, Reconstruction Error: 0.2219
# Iteration 56/200, Reconstruction Error: 0.2219
# Iteration 61/200, Reconstruction Error: 0.2220
# Iteration 66/200, Reconstruction Error: 0.2221
# Iteration 71/200, Reconstruction Error: 0.2222
# Iteration 76/200, Reconstruction Error: 0.2223
# Iteration 81/200, Reconstruction Error: 0.2225
# Iteration 86/200, Reconstruction Error: 0.2225
# Iteration 91/200, Reconstruction Error: 0.2226
# Iteration 96/200, Reconstruction Error: 0.2228
# Iteration 101/200, Reconstruction Error: 0.2229
# Iteration 106/200, Reconstruction Error: 0.2231
# Iteration 111/200, Reconstruction Error: 0.2232
# Iteration 116/200, Reconstruction Error: 0.2233
# Iteration 121/200, Reconstruction Error: 0.2235
# Iteration 126/200, Reconstruction Error: 0.2236
# Iteration 131/200, Reconstruction Error: 0.2238
# Iteration 136/200, Reconstruction Error: 0.2240
# Iteration 141/200, Reconstruction Error: 0.2242
# Iteration 146/200, Reconstruction Error: 0.2244
# Iteration 151/200, Reconstruction Error: 0.2246
# Iteration 156/200, Reconstruction Error: 0.2247
# Iteration 161/200, Reconstruction Error: 0.2250
# Iteration 166/200, Reconstruction Error: 0.2251
# Iteration 171/200, Reconstruction Error: 0.2254
# Iteration 176/200, Reconstruction Error: 0.2255
# Iteration 181/200, Reconstruction Error: 0.2258
# Iteration 186/200, Reconstruction Error: 0.2260
# Iteration 191/200, Reconstruction Error: 0.2262
# Iteration 196/200, Reconstruction Error: 0.2264
# Tensor shape: (64, 64, 3, 3), K1=2215.958960000106, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.2267
# Iteration 6/200, Reconstruction Error: 0.2270
# Iteration 11/200, Reconstruction Error: 0.2273
# Iteration 16/200, Reconstruction Error: 0.2277
# Iteration 21/200, Reconstruction Error: 0.2280
# Iteration 26/200, Reconstruction Error: 0.2284
# Iteration 31/200, Reconstruction Error: 0.2287
# Iteration 36/200, Reconstruction Error: 0.2292
# Iteration 41/200, Reconstruction Error: 0.2295
# Iteration 46/200, Reconstruction Error: 0.2299
# Iteration 51/200, Reconstruction Error: 0.2303
# Iteration 56/200, Reconstruction Error: 0.2307
# Iteration 61/200, Reconstruction Error: 0.2311
# Iteration 66/200, Reconstruction Error: 0.2315
# Iteration 71/200, Reconstruction Error: 0.2319
# Iteration 76/200, Reconstruction Error: 0.2322
# Iteration 81/200, Reconstruction Error: 0.2327
# Iteration 86/200, Reconstruction Error: 0.2331
# Iteration 91/200, Reconstruction Error: 0.2335
# Iteration 96/200, Reconstruction Error: 0.2340
# Iteration 101/200, Reconstruction Error: 0.2344
# Iteration 106/200, Reconstruction Error: 0.2350
# Iteration 111/200, Reconstruction Error: 0.2353
# Iteration 116/200, Reconstruction Error: 0.2358
# Iteration 121/200, Reconstruction Error: 0.2363
# Iteration 126/200, Reconstruction Error: 0.2368
# Iteration 131/200, Reconstruction Error: 0.2372
# Iteration 136/200, Reconstruction Error: 0.2377
# Iteration 141/200, Reconstruction Error: 0.2383
# Iteration 146/200, Reconstruction Error: 0.2389
# Iteration 151/200, Reconstruction Error: 0.2394
# Iteration 156/200, Reconstruction Error: 0.2398
# Iteration 161/200, Reconstruction Error: 0.2404
# Iteration 166/200, Reconstruction Error: 0.2410
# Iteration 171/200, Reconstruction Error: 0.2414
# Iteration 176/200, Reconstruction Error: 0.2420
# Iteration 181/200, Reconstruction Error: 0.2426
# Iteration 186/200, Reconstruction Error: 0.2431
# Iteration 191/200, Reconstruction Error: 0.2436
# Iteration 196/200, Reconstruction Error: 0.2443
# xのL2ノルムの変化 = 13.644205597221662%
# Tensor shape: (64, 64, 3, 3), K1=2080.6197105954884, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.2449
# Iteration 6/200, Reconstruction Error: 0.2454
# Iteration 11/200, Reconstruction Error: 0.2460
# Iteration 16/200, Reconstruction Error: 0.2464
# Iteration 21/200, Reconstruction Error: 0.2471
# Iteration 26/200, Reconstruction Error: 0.2476
# Iteration 31/200, Reconstruction Error: 0.2482
# Iteration 36/200, Reconstruction Error: 0.2488
# Iteration 41/200, Reconstruction Error: 0.2492
# Iteration 46/200, Reconstruction Error: 0.2501
# Iteration 51/200, Reconstruction Error: 0.2506
# Iteration 56/200, Reconstruction Error: 0.2514
# Iteration 61/200, Reconstruction Error: 0.2517
# Iteration 66/200, Reconstruction Error: 0.2523
# Iteration 71/200, Reconstruction Error: 0.2529
# Iteration 76/200, Reconstruction Error: 0.2536
# Iteration 81/200, Reconstruction Error: 0.2542
# Iteration 86/200, Reconstruction Error: 0.2547
# Iteration 91/200, Reconstruction Error: 0.2553
# Iteration 96/200, Reconstruction Error: 0.2559
# Iteration 101/200, Reconstruction Error: 0.2565
# Iteration 106/200, Reconstruction Error: 0.2573
# Iteration 111/200, Reconstruction Error: 0.2578
# Iteration 116/200, Reconstruction Error: 0.2586
# Iteration 121/200, Reconstruction Error: 0.2590
# Iteration 126/200, Reconstruction Error: 0.2598
# Iteration 131/200, Reconstruction Error: 0.2603
# Iteration 136/200, Reconstruction Error: 0.2609
# Iteration 141/200, Reconstruction Error: 0.2616
# Iteration 146/200, Reconstruction Error: 0.2622
# Iteration 151/200, Reconstruction Error: 0.2631
# Iteration 156/200, Reconstruction Error: 0.2636
# Iteration 161/200, Reconstruction Error: 0.2642
# Iteration 166/200, Reconstruction Error: 0.2648
# Iteration 171/200, Reconstruction Error: 0.2655
# Iteration 176/200, Reconstruction Error: 0.2663
# Iteration 181/200, Reconstruction Error: 0.2668
# Iteration 186/200, Reconstruction Error: 0.2674
# Iteration 191/200, Reconstruction Error: 0.2681
# Iteration 196/200, Reconstruction Error: 0.2686
# xのL2ノルムの変化 = 14.517321755480141%
# Tensor shape: (64, 64, 3, 3), K1=1960.2607466662785, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.2696
# Iteration 6/200, Reconstruction Error: 0.2703
# Iteration 11/200, Reconstruction Error: 0.2709
# Iteration 16/200, Reconstruction Error: 0.2716
# Iteration 21/200, Reconstruction Error: 0.2724
# Iteration 26/200, Reconstruction Error: 0.2727
# Iteration 31/200, Reconstruction Error: 0.2735
# Iteration 36/200, Reconstruction Error: 0.2745
# Iteration 41/200, Reconstruction Error: 0.2751
# Iteration 46/200, Reconstruction Error: 0.2760
# Iteration 51/200, Reconstruction Error: 0.2768
# Iteration 56/200, Reconstruction Error: 0.2772
# Iteration 61/200, Reconstruction Error: 0.2781
# Iteration 66/200, Reconstruction Error: 0.2788
# Iteration 71/200, Reconstruction Error: 0.2793
# Iteration 76/200, Reconstruction Error: 0.2799
# Iteration 81/200, Reconstruction Error: 0.2808
# Iteration 86/200, Reconstruction Error: 0.2815
# Iteration 91/200, Reconstruction Error: 0.2822
# Iteration 96/200, Reconstruction Error: 0.2829
# Iteration 101/200, Reconstruction Error: 0.2834
# Iteration 106/200, Reconstruction Error: 0.2843
# Iteration 111/200, Reconstruction Error: 0.2851
# Iteration 116/200, Reconstruction Error: 0.2859
# Iteration 121/200, Reconstruction Error: 0.2864
# Iteration 126/200, Reconstruction Error: 0.2871
# Iteration 131/200, Reconstruction Error: 0.2878
# Iteration 136/200, Reconstruction Error: 0.2886
# Iteration 141/200, Reconstruction Error: 0.2890
# Iteration 146/200, Reconstruction Error: 0.2899
# Iteration 151/200, Reconstruction Error: 0.2905
# Iteration 156/200, Reconstruction Error: 0.2910
# Iteration 161/200, Reconstruction Error: 0.2923
# Iteration 166/200, Reconstruction Error: 0.2928
# Iteration 171/200, Reconstruction Error: 0.2934
# Iteration 176/200, Reconstruction Error: 0.2942
# Iteration 181/200, Reconstruction Error: 0.2948
# Iteration 186/200, Reconstruction Error: 0.2956
# Iteration 191/200, Reconstruction Error: 0.2958
# Iteration 196/200, Reconstruction Error: 0.2966
# xのL2ノルムの変化 = 15.578381052414885%
# Tensor shape: (64, 64, 3, 3), K1=1852.947147733444, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.2977
# Iteration 6/200, Reconstruction Error: 0.2986
# Iteration 11/200, Reconstruction Error: 0.2992
# Iteration 16/200, Reconstruction Error: 0.2996
# Iteration 21/200, Reconstruction Error: 0.3005
# Iteration 26/200, Reconstruction Error: 0.3010
# Iteration 31/200, Reconstruction Error: 0.3022
# Iteration 36/200, Reconstruction Error: 0.3026
# Iteration 41/200, Reconstruction Error: 0.3035
# Iteration 46/200, Reconstruction Error: 0.3040
# Iteration 51/200, Reconstruction Error: 0.3047
# Iteration 56/200, Reconstruction Error: 0.3053
# Iteration 61/200, Reconstruction Error: 0.3062
# Iteration 66/200, Reconstruction Error: 0.3071
# Iteration 71/200, Reconstruction Error: 0.3077
# Iteration 76/200, Reconstruction Error: 0.3082
# Iteration 81/200, Reconstruction Error: 0.3092
# Iteration 86/200, Reconstruction Error: 0.3099
# Iteration 91/200, Reconstruction Error: 0.3105
# Iteration 96/200, Reconstruction Error: 0.3109
# Iteration 101/200, Reconstruction Error: 0.3123
# Iteration 106/200, Reconstruction Error: 0.3127
# Iteration 111/200, Reconstruction Error: 0.3133
# Iteration 116/200, Reconstruction Error: 0.3144
# Iteration 121/200, Reconstruction Error: 0.3149
# Iteration 126/200, Reconstruction Error: 0.3156
# Iteration 131/200, Reconstruction Error: 0.3166
# Iteration 136/200, Reconstruction Error: 0.3168
# Iteration 141/200, Reconstruction Error: 0.3174
# Iteration 146/200, Reconstruction Error: 0.3185
# Iteration 151/200, Reconstruction Error: 0.3190
# Iteration 156/200, Reconstruction Error: 0.3198
# Iteration 161/200, Reconstruction Error: 0.3207
# Iteration 166/200, Reconstruction Error: 0.3211
# Iteration 171/200, Reconstruction Error: 0.3219
# Iteration 176/200, Reconstruction Error: 0.3225
# Iteration 181/200, Reconstruction Error: 0.3230
# Iteration 186/200, Reconstruction Error: 0.3238
# Iteration 191/200, Reconstruction Error: 0.3247
# Iteration 196/200, Reconstruction Error: 0.3250
# xのL2ノルムの変化 = 16.791282094403286%
# Tensor shape: (64, 64, 3, 3), K1=1756.8670640426405, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.3262
# Iteration 6/200, Reconstruction Error: 0.3268
# Iteration 11/200, Reconstruction Error: 0.3276
# Iteration 16/200, Reconstruction Error: 0.3282
# Iteration 21/200, Reconstruction Error: 0.3291
# Iteration 26/200, Reconstruction Error: 0.3297
# Iteration 31/200, Reconstruction Error: 0.3302
# Iteration 36/200, Reconstruction Error: 0.3314
# Iteration 41/200, Reconstruction Error: 0.3320
# Iteration 46/200, Reconstruction Error: 0.3324
# Iteration 51/200, Reconstruction Error: 0.3331
# Iteration 56/200, Reconstruction Error: 0.3337
# Iteration 61/200, Reconstruction Error: 0.3344
# Iteration 66/200, Reconstruction Error: 0.3356
# Iteration 71/200, Reconstruction Error: 0.3358
# Iteration 76/200, Reconstruction Error: 0.3364
# Iteration 81/200, Reconstruction Error: 0.3373
# Iteration 86/200, Reconstruction Error: 0.3378
# Iteration 91/200, Reconstruction Error: 0.3385
# Iteration 96/200, Reconstruction Error: 0.3392
# Iteration 101/200, Reconstruction Error: 0.3396
# Iteration 106/200, Reconstruction Error: 0.3406
# Iteration 111/200, Reconstruction Error: 0.3414
# Iteration 116/200, Reconstruction Error: 0.3418
# Iteration 121/200, Reconstruction Error: 0.3424
# Iteration 126/200, Reconstruction Error: 0.3431
# Iteration 131/200, Reconstruction Error: 0.3436
# Iteration 136/200, Reconstruction Error: 0.3448
# Iteration 141/200, Reconstruction Error: 0.3451
# Iteration 146/200, Reconstruction Error: 0.3458
# Iteration 151/200, Reconstruction Error: 0.3466
# Iteration 156/200, Reconstruction Error: 0.3472
# Iteration 161/200, Reconstruction Error: 0.3477
# Iteration 166/200, Reconstruction Error: 0.3485
# Iteration 171/200, Reconstruction Error: 0.3489
# Iteration 176/200, Reconstruction Error: 0.3500
# Iteration 181/200, Reconstruction Error: 0.3505
# Iteration 186/200, Reconstruction Error: 0.3513
# Iteration 191/200, Reconstruction Error: 0.3514
# Iteration 196/200, Reconstruction Error: 0.3524
# xのL2ノルムの変化 = 17.139232312001447%
# Tensor shape: (64, 64, 3, 3), K1=1670.2315260317675, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.3532
# Iteration 6/200, Reconstruction Error: 0.3540
# Iteration 11/200, Reconstruction Error: 0.3545
# Iteration 16/200, Reconstruction Error: 0.3552
# Iteration 21/200, Reconstruction Error: 0.3560
# Iteration 26/200, Reconstruction Error: 0.3567
# Iteration 31/200, Reconstruction Error: 0.3573
# Iteration 36/200, Reconstruction Error: 0.3581
# Iteration 41/200, Reconstruction Error: 0.3585
# Iteration 46/200, Reconstruction Error: 0.3592
# Iteration 51/200, Reconstruction Error: 0.3602
# Iteration 56/200, Reconstruction Error: 0.3605
# Iteration 61/200, Reconstruction Error: 0.3616
# Iteration 66/200, Reconstruction Error: 0.3619
# Iteration 71/200, Reconstruction Error: 0.3626
# Iteration 76/200, Reconstruction Error: 0.3633
# Iteration 81/200, Reconstruction Error: 0.3639
# Iteration 86/200, Reconstruction Error: 0.3644
# Iteration 91/200, Reconstruction Error: 0.3654
# Iteration 96/200, Reconstruction Error: 0.3662
# Iteration 101/200, Reconstruction Error: 0.3667
# Iteration 106/200, Reconstruction Error: 0.3672
# Iteration 111/200, Reconstruction Error: 0.3678
# Iteration 116/200, Reconstruction Error: 0.3690
# Iteration 121/200, Reconstruction Error: 0.3693
# Iteration 126/200, Reconstruction Error: 0.3699
# Iteration 131/200, Reconstruction Error: 0.3703
# Iteration 136/200, Reconstruction Error: 0.3713
# Iteration 141/200, Reconstruction Error: 0.3719
# Iteration 146/200, Reconstruction Error: 0.3723
# Iteration 151/200, Reconstruction Error: 0.3729
# Iteration 156/200, Reconstruction Error: 0.3732
# Iteration 161/200, Reconstruction Error: 0.3735
# Iteration 166/200, Reconstruction Error: 0.3747
# Iteration 171/200, Reconstruction Error: 0.3753
# Iteration 176/200, Reconstruction Error: 0.3759
# Iteration 181/200, Reconstruction Error: 0.3764
# Iteration 186/200, Reconstruction Error: 0.3773
# Iteration 191/200, Reconstruction Error: 0.3778
# Iteration 196/200, Reconstruction Error: 0.3784
# xのL2ノルムの変化 = 17.83637220241553%
# Tensor shape: (64, 64, 3, 3), K1=1591.6246216548398, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.3792
# Iteration 6/200, Reconstruction Error: 0.3802
# Iteration 11/200, Reconstruction Error: 0.3806
# Iteration 16/200, Reconstruction Error: 0.3812
# Iteration 21/200, Reconstruction Error: 0.3814
# Iteration 26/200, Reconstruction Error: 0.3824
# Iteration 31/200, Reconstruction Error: 0.3829
# Iteration 36/200, Reconstruction Error: 0.3835
# Iteration 41/200, Reconstruction Error: 0.3840
# Iteration 46/200, Reconstruction Error: 0.3850
# Iteration 51/200, Reconstruction Error: 0.3852
# Iteration 56/200, Reconstruction Error: 0.3862
# Iteration 61/200, Reconstruction Error: 0.3861
# Iteration 66/200, Reconstruction Error: 0.3878
# Iteration 71/200, Reconstruction Error: 0.3879
# Iteration 76/200, Reconstruction Error: 0.3887
# Iteration 81/200, Reconstruction Error: 0.3890
# Iteration 86/200, Reconstruction Error: 0.3902
# Iteration 91/200, Reconstruction Error: 0.3909
# Iteration 96/200, Reconstruction Error: 0.3916
# Iteration 101/200, Reconstruction Error: 0.3921
# Iteration 106/200, Reconstruction Error: 0.3925
# Iteration 111/200, Reconstruction Error: 0.3928
# Iteration 116/200, Reconstruction Error: 0.3941
# Iteration 121/200, Reconstruction Error: 0.3944
# Iteration 126/200, Reconstruction Error: 0.3950
# Iteration 131/200, Reconstruction Error: 0.3954
# Iteration 136/200, Reconstruction Error: 0.3960
# Iteration 141/200, Reconstruction Error: 0.3970
# Iteration 146/200, Reconstruction Error: 0.3970
# Iteration 151/200, Reconstruction Error: 0.3976
# Iteration 156/200, Reconstruction Error: 0.3981
# Iteration 161/200, Reconstruction Error: 0.3989
# Iteration 166/200, Reconstruction Error: 0.3996
# Iteration 171/200, Reconstruction Error: 0.4000
# Iteration 176/200, Reconstruction Error: 0.4006
# Iteration 181/200, Reconstruction Error: 0.4015
# Iteration 186/200, Reconstruction Error: 0.4014
# Iteration 191/200, Reconstruction Error: 0.4022
# Iteration 196/200, Reconstruction Error: 0.4028
# xのL2ノルムの変化 = 18.35667780996846%
# Tensor shape: (64, 64, 3, 3), K1=1520.0124716349146, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.4038
# Iteration 6/200, Reconstruction Error: 0.4045
# Iteration 11/200, Reconstruction Error: 0.4052
# Iteration 16/200, Reconstruction Error: 0.4058
# Iteration 21/200, Reconstruction Error: 0.4065
# Iteration 26/200, Reconstruction Error: 0.4068
# Iteration 31/200, Reconstruction Error: 0.4078
# Iteration 36/200, Reconstruction Error: 0.4080
# Iteration 41/200, Reconstruction Error: 0.4083
# Iteration 46/200, Reconstruction Error: 0.4094
# Iteration 51/200, Reconstruction Error: 0.4102
# Iteration 56/200, Reconstruction Error: 0.4105
# Iteration 61/200, Reconstruction Error: 0.4108
# Iteration 66/200, Reconstruction Error: 0.4119
# Iteration 71/200, Reconstruction Error: 0.4119
# Iteration 76/200, Reconstruction Error: 0.4129
# Iteration 81/200, Reconstruction Error: 0.4133
# Iteration 86/200, Reconstruction Error: 0.4140
# Iteration 91/200, Reconstruction Error: 0.4145
# Iteration 96/200, Reconstruction Error: 0.4148
# Iteration 101/200, Reconstruction Error: 0.4154
# Iteration 106/200, Reconstruction Error: 0.4158
# Iteration 111/200, Reconstruction Error: 0.4166
# Iteration 116/200, Reconstruction Error: 0.4171
# Iteration 121/200, Reconstruction Error: 0.4179
# Iteration 126/200, Reconstruction Error: 0.4181
# Iteration 131/200, Reconstruction Error: 0.4187
# Iteration 136/200, Reconstruction Error: 0.4197
# Iteration 141/200, Reconstruction Error: 0.4205
# Iteration 146/200, Reconstruction Error: 0.4206
# Iteration 151/200, Reconstruction Error: 0.4209
# Iteration 156/200, Reconstruction Error: 0.4216
# Iteration 161/200, Reconstruction Error: 0.4224
# Iteration 166/200, Reconstruction Error: 0.4226
# Iteration 171/200, Reconstruction Error: 0.4231
# Iteration 176/200, Reconstruction Error: 0.4241
# Iteration 181/200, Reconstruction Error: 0.4241
# Iteration 186/200, Reconstruction Error: 0.4253
# Iteration 191/200, Reconstruction Error: 0.4251
# Iteration 196/200, Reconstruction Error: 0.4259
# xのL2ノルムの変化 = 18.588875452965333%
# Tensor shape: (64, 64, 3, 3), K1=1454.5932102185222, K0=12715 (34.5%)
# Iteration 1/200, Reconstruction Error: 0.4264
# Iteration 6/200, Reconstruction Error: 0.4273
# Iteration 11/200, Reconstruction Error: 0.4279
# Iteration 16/200, Reconstruction Error: 0.4284
# Iteration 21/200, Reconstruction Error: 0.4286
# Iteration 26/200, Reconstruction Error: 0.4296
# Iteration 31/200, Reconstruction Error: 0.4298
# Iteration 36/200, Reconstruction Error: 0.4300
# Iteration 41/200, Reconstruction Error: 0.4309
# Iteration 46/200, Reconstruction Error: 0.4314
# Iteration 51/200, Reconstruction Error: 0.4321
# Iteration 56/200, Reconstruction Error: 0.4325
# Iteration 61/200, Reconstruction Error: 0.4331
# Iteration 66/200, Reconstruction Error: 0.4336
# Iteration 71/200, Reconstruction Error: 0.4346
# Iteration 76/200, Reconstruction Error: 0.4349
# Iteration 81/200, Reconstruction Error: 0.4354
# Iteration 86/200, Reconstruction Error: 0.4358
# Iteration 91/200, Reconstruction Error: 0.4361
# Iteration 96/200, Reconstruction Error: 0.4367
# Iteration 101/200, Reconstruction Error: 0.4376
# Iteration 106/200, Reconstruction Error: 0.4377
# Iteration 111/200, Reconstruction Error: 0.4382
# Iteration 116/200, Reconstruction Error: 0.4392
# Iteration 121/200, Reconstruction Error: 0.4397
# Iteration 126/200, Reconstruction Error: 0.4399
# Iteration 131/200, Reconstruction Error: 0.4401
# Iteration 136/200, Reconstruction Error: 0.4408
# Iteration 141/200, Reconstruction Error: 0.4415
# Iteration 146/200, Reconstruction Error: 0.4417
# Iteration 151/200, Reconstruction Error: 0.4425
# Iteration 156/200, Reconstruction Error: 0.4433
# Iteration 161/200, Reconstruction Error: 0.4436
# Iteration 166/200, Reconstruction Error: 0.4438
# Iteration 171/200, Reconstruction Error: 0.4444
# Iteration 176/200, Reconstruction Error: 0.4448
# Iteration 181/200, Reconstruction Error: 0.4455
# Iteration 186/200, Reconstruction Error: 0.4463
# Iteration 191/200, Reconstruction Error: 0.4467
# Iteration 196/200, Reconstruction Error: 0.4470
# xのL2ノルムの変化 = 18.894734982805154%
# 外のループを規定回数（20回）回しました
#
# 結果:
# 元の重みテンソルの非ゼロの要素数: 36864
# ADMM後の重みテンソルの非ゼロの要素数: 12715 (目標数12715)
# ||Dx||_1 / ||x||_1: 5.5225 (制約は2.5937328516165374以下)
#
# --- レイヤー 'layer1.0.conv2' の処理を開始 ---
# Tensor shape: (64, 64, 3, 3), K1=2962.936093791804, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.0000
# Iteration 6/200, Reconstruction Error: 0.2857
# Iteration 11/200, Reconstruction Error: 0.2857
# Iteration 16/200, Reconstruction Error: 0.2857
# Iteration 21/200, Reconstruction Error: 0.2857
# Iteration 26/200, Reconstruction Error: 0.2857
# Iteration 31/200, Reconstruction Error: 0.2858
# Iteration 36/200, Reconstruction Error: 0.2858
# Iteration 41/200, Reconstruction Error: 0.2859
# Iteration 46/200, Reconstruction Error: 0.2859
# Iteration 51/200, Reconstruction Error: 0.2860
# Iteration 56/200, Reconstruction Error: 0.2860
# Iteration 61/200, Reconstruction Error: 0.2861
# Iteration 66/200, Reconstruction Error: 0.2862
# Iteration 71/200, Reconstruction Error: 0.2862
# Iteration 76/200, Reconstruction Error: 0.2863
# Iteration 81/200, Reconstruction Error: 0.2864
# Iteration 86/200, Reconstruction Error: 0.2865
# Iteration 91/200, Reconstruction Error: 0.2866
# Iteration 96/200, Reconstruction Error: 0.2867
# Iteration 101/200, Reconstruction Error: 0.2868
# Iteration 106/200, Reconstruction Error: 0.2869
# Iteration 111/200, Reconstruction Error: 0.2870
# Iteration 116/200, Reconstruction Error: 0.2872
# Iteration 121/200, Reconstruction Error: 0.2873
# Iteration 126/200, Reconstruction Error: 0.2874
# Iteration 131/200, Reconstruction Error: 0.2875
# Iteration 136/200, Reconstruction Error: 0.2877
# Iteration 141/200, Reconstruction Error: 0.2878
# Iteration 146/200, Reconstruction Error: 0.2880
# Iteration 151/200, Reconstruction Error: 0.2881
# Iteration 156/200, Reconstruction Error: 0.2883
# Iteration 161/200, Reconstruction Error: 0.2885
# Iteration 166/200, Reconstruction Error: 0.2886
# Iteration 171/200, Reconstruction Error: 0.2888
# Iteration 176/200, Reconstruction Error: 0.2890
# Iteration 181/200, Reconstruction Error: 0.2891
# Iteration 186/200, Reconstruction Error: 0.2893
# Iteration 191/200, Reconstruction Error: 0.2895
# Iteration 196/200, Reconstruction Error: 0.2897
# Tensor shape: (64, 64, 3, 3), K1=2067.9708757003714, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.2899
# Iteration 6/200, Reconstruction Error: 0.2902
# Iteration 11/200, Reconstruction Error: 0.2904
# Iteration 16/200, Reconstruction Error: 0.2907
# Iteration 21/200, Reconstruction Error: 0.2910
# Iteration 26/200, Reconstruction Error: 0.2913
# Iteration 31/200, Reconstruction Error: 0.2917
# Iteration 36/200, Reconstruction Error: 0.2920
# Iteration 41/200, Reconstruction Error: 0.2924
# Iteration 46/200, Reconstruction Error: 0.2926
# Iteration 51/200, Reconstruction Error: 0.2930
# Iteration 56/200, Reconstruction Error: 0.2934
# Iteration 61/200, Reconstruction Error: 0.2938
# Iteration 66/200, Reconstruction Error: 0.2942
# Iteration 71/200, Reconstruction Error: 0.2945
# Iteration 76/200, Reconstruction Error: 0.2949
# Iteration 81/200, Reconstruction Error: 0.2953
# Iteration 86/200, Reconstruction Error: 0.2957
# Iteration 91/200, Reconstruction Error: 0.2961
# Iteration 96/200, Reconstruction Error: 0.2964
# Iteration 101/200, Reconstruction Error: 0.2969
# Iteration 106/200, Reconstruction Error: 0.2973
# Iteration 111/200, Reconstruction Error: 0.2977
# Iteration 116/200, Reconstruction Error: 0.2983
# Iteration 121/200, Reconstruction Error: 0.2987
# Iteration 126/200, Reconstruction Error: 0.2990
# Iteration 131/200, Reconstruction Error: 0.2995
# Iteration 136/200, Reconstruction Error: 0.3000
# Iteration 141/200, Reconstruction Error: 0.3004
# Iteration 146/200, Reconstruction Error: 0.3009
# Iteration 151/200, Reconstruction Error: 0.3013
# Iteration 156/200, Reconstruction Error: 0.3019
# Iteration 161/200, Reconstruction Error: 0.3023
# Iteration 166/200, Reconstruction Error: 0.3028
# Iteration 171/200, Reconstruction Error: 0.3034
# Iteration 176/200, Reconstruction Error: 0.3039
# Iteration 181/200, Reconstruction Error: 0.3043
# Iteration 186/200, Reconstruction Error: 0.3047
# Iteration 191/200, Reconstruction Error: 0.3053
# Iteration 196/200, Reconstruction Error: 0.3058
# xのL2ノルムの変化 = 16.6879096971377%
# Tensor shape: (64, 64, 3, 3), K1=1945.968709807698, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.3064
# Iteration 6/200, Reconstruction Error: 0.3070
# Iteration 11/200, Reconstruction Error: 0.3075
# Iteration 16/200, Reconstruction Error: 0.3080
# Iteration 21/200, Reconstruction Error: 0.3084
# Iteration 26/200, Reconstruction Error: 0.3090
# Iteration 31/200, Reconstruction Error: 0.3095
# Iteration 36/200, Reconstruction Error: 0.3101
# Iteration 41/200, Reconstruction Error: 0.3106
# Iteration 46/200, Reconstruction Error: 0.3111
# Iteration 51/200, Reconstruction Error: 0.3116
# Iteration 56/200, Reconstruction Error: 0.3121
# Iteration 61/200, Reconstruction Error: 0.3130
# Iteration 66/200, Reconstruction Error: 0.3135
# Iteration 71/200, Reconstruction Error: 0.3139
# Iteration 76/200, Reconstruction Error: 0.3147
# Iteration 81/200, Reconstruction Error: 0.3152
# Iteration 86/200, Reconstruction Error: 0.3158
# Iteration 91/200, Reconstruction Error: 0.3163
# Iteration 96/200, Reconstruction Error: 0.3169
# Iteration 101/200, Reconstruction Error: 0.3175
# Iteration 106/200, Reconstruction Error: 0.3181
# Iteration 111/200, Reconstruction Error: 0.3188
# Iteration 116/200, Reconstruction Error: 0.3194
# Iteration 121/200, Reconstruction Error: 0.3199
# Iteration 126/200, Reconstruction Error: 0.3204
# Iteration 131/200, Reconstruction Error: 0.3211
# Iteration 136/200, Reconstruction Error: 0.3215
# Iteration 141/200, Reconstruction Error: 0.3224
# Iteration 146/200, Reconstruction Error: 0.3229
# Iteration 151/200, Reconstruction Error: 0.3234
# Iteration 156/200, Reconstruction Error: 0.3240
# Iteration 161/200, Reconstruction Error: 0.3247
# Iteration 166/200, Reconstruction Error: 0.3252
# Iteration 171/200, Reconstruction Error: 0.3259
# Iteration 176/200, Reconstruction Error: 0.3266
# Iteration 181/200, Reconstruction Error: 0.3271
# Iteration 186/200, Reconstruction Error: 0.3276
# Iteration 191/200, Reconstruction Error: 0.3283
# Iteration 196/200, Reconstruction Error: 0.3289
# xのL2ノルムの変化 = 18.695914540692048%
# Tensor shape: (64, 64, 3, 3), K1=1838.7688989595251, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.3296
# Iteration 6/200, Reconstruction Error: 0.3305
# Iteration 11/200, Reconstruction Error: 0.3310
# Iteration 16/200, Reconstruction Error: 0.3316
# Iteration 21/200, Reconstruction Error: 0.3324
# Iteration 26/200, Reconstruction Error: 0.3331
# Iteration 31/200, Reconstruction Error: 0.3337
# Iteration 36/200, Reconstruction Error: 0.3344
# Iteration 41/200, Reconstruction Error: 0.3349
# Iteration 46/200, Reconstruction Error: 0.3356
# Iteration 51/200, Reconstruction Error: 0.3362
# Iteration 56/200, Reconstruction Error: 0.3367
# Iteration 61/200, Reconstruction Error: 0.3375
# Iteration 66/200, Reconstruction Error: 0.3384
# Iteration 71/200, Reconstruction Error: 0.3388
# Iteration 76/200, Reconstruction Error: 0.3393
# Iteration 81/200, Reconstruction Error: 0.3402
# Iteration 86/200, Reconstruction Error: 0.3408
# Iteration 91/200, Reconstruction Error: 0.3414
# Iteration 96/200, Reconstruction Error: 0.3421
# Iteration 101/200, Reconstruction Error: 0.3427
# Iteration 106/200, Reconstruction Error: 0.3431
# Iteration 111/200, Reconstruction Error: 0.3439
# Iteration 116/200, Reconstruction Error: 0.3445
# Iteration 121/200, Reconstruction Error: 0.3453
# Iteration 126/200, Reconstruction Error: 0.3459
# Iteration 131/200, Reconstruction Error: 0.3464
# Iteration 136/200, Reconstruction Error: 0.3472
# Iteration 141/200, Reconstruction Error: 0.3475
# Iteration 146/200, Reconstruction Error: 0.3481
# Iteration 151/200, Reconstruction Error: 0.3491
# Iteration 156/200, Reconstruction Error: 0.3495
# Iteration 161/200, Reconstruction Error: 0.3503
# Iteration 166/200, Reconstruction Error: 0.3507
# Iteration 171/200, Reconstruction Error: 0.3516
# Iteration 176/200, Reconstruction Error: 0.3522
# Iteration 181/200, Reconstruction Error: 0.3528
# Iteration 186/200, Reconstruction Error: 0.3535
# Iteration 191/200, Reconstruction Error: 0.3539
# Iteration 196/200, Reconstruction Error: 0.3546
# xのL2ノルムの変化 = 19.963361653249116%
# Tensor shape: (64, 64, 3, 3), K1=1744.0692921638256, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.3554
# Iteration 6/200, Reconstruction Error: 0.3560
# Iteration 11/200, Reconstruction Error: 0.3565
# Iteration 16/200, Reconstruction Error: 0.3573
# Iteration 21/200, Reconstruction Error: 0.3579
# Iteration 26/200, Reconstruction Error: 0.3588
# Iteration 31/200, Reconstruction Error: 0.3593
# Iteration 36/200, Reconstruction Error: 0.3602
# Iteration 41/200, Reconstruction Error: 0.3608
# Iteration 46/200, Reconstruction Error: 0.3617
# Iteration 51/200, Reconstruction Error: 0.3623
# Iteration 56/200, Reconstruction Error: 0.3630
# Iteration 61/200, Reconstruction Error: 0.3635
# Iteration 66/200, Reconstruction Error: 0.3641
# Iteration 71/200, Reconstruction Error: 0.3651
# Iteration 76/200, Reconstruction Error: 0.3651
# Iteration 81/200, Reconstruction Error: 0.3661
# Iteration 86/200, Reconstruction Error: 0.3669
# Iteration 91/200, Reconstruction Error: 0.3672
# Iteration 96/200, Reconstruction Error: 0.3681
# Iteration 101/200, Reconstruction Error: 0.3686
# Iteration 106/200, Reconstruction Error: 0.3694
# Iteration 111/200, Reconstruction Error: 0.3696
# Iteration 116/200, Reconstruction Error: 0.3703
# Iteration 121/200, Reconstruction Error: 0.3714
# Iteration 126/200, Reconstruction Error: 0.3717
# Iteration 131/200, Reconstruction Error: 0.3726
# Iteration 136/200, Reconstruction Error: 0.3734
# Iteration 141/200, Reconstruction Error: 0.3737
# Iteration 146/200, Reconstruction Error: 0.3742
# Iteration 151/200, Reconstruction Error: 0.3748
# Iteration 156/200, Reconstruction Error: 0.3756
# Iteration 161/200, Reconstruction Error: 0.3768
# Iteration 166/200, Reconstruction Error: 0.3769
# Iteration 171/200, Reconstruction Error: 0.3775
# Iteration 176/200, Reconstruction Error: 0.3782
# Iteration 181/200, Reconstruction Error: 0.3790
# Iteration 186/200, Reconstruction Error: 0.3795
# Iteration 191/200, Reconstruction Error: 0.3802
# Iteration 196/200, Reconstruction Error: 0.3808
# xのL2ノルムの変化 = 21.7085732500996%
# Tensor shape: (64, 64, 3, 3), K1=1659.4687537318866, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.3819
# Iteration 6/200, Reconstruction Error: 0.3824
# Iteration 11/200, Reconstruction Error: 0.3829
# Iteration 16/200, Reconstruction Error: 0.3837
# Iteration 21/200, Reconstruction Error: 0.3848
# Iteration 26/200, Reconstruction Error: 0.3851
# Iteration 31/200, Reconstruction Error: 0.3859
# Iteration 36/200, Reconstruction Error: 0.3861
# Iteration 41/200, Reconstruction Error: 0.3868
# Iteration 46/200, Reconstruction Error: 0.3876
# Iteration 51/200, Reconstruction Error: 0.3886
# Iteration 56/200, Reconstruction Error: 0.3892
# Iteration 61/200, Reconstruction Error: 0.3901
# Iteration 66/200, Reconstruction Error: 0.3907
# Iteration 71/200, Reconstruction Error: 0.3909
# Iteration 76/200, Reconstruction Error: 0.3917
# Iteration 81/200, Reconstruction Error: 0.3923
# Iteration 86/200, Reconstruction Error: 0.3929
# Iteration 91/200, Reconstruction Error: 0.3936
# Iteration 96/200, Reconstruction Error: 0.3940
# Iteration 101/200, Reconstruction Error: 0.3946
# Iteration 106/200, Reconstruction Error: 0.3952
# Iteration 111/200, Reconstruction Error: 0.3962
# Iteration 116/200, Reconstruction Error: 0.3963
# Iteration 121/200, Reconstruction Error: 0.3974
# Iteration 126/200, Reconstruction Error: 0.3981
# Iteration 131/200, Reconstruction Error: 0.3989
# Iteration 136/200, Reconstruction Error: 0.3988
# Iteration 141/200, Reconstruction Error: 0.4000
# Iteration 146/200, Reconstruction Error: 0.4009
# Iteration 151/200, Reconstruction Error: 0.4014
# Iteration 156/200, Reconstruction Error: 0.4018
# Iteration 161/200, Reconstruction Error: 0.4023
# Iteration 166/200, Reconstruction Error: 0.4024
# Iteration 171/200, Reconstruction Error: 0.4036
# Iteration 176/200, Reconstruction Error: 0.4046
# Iteration 181/200, Reconstruction Error: 0.4053
# Iteration 186/200, Reconstruction Error: 0.4053
# Iteration 191/200, Reconstruction Error: 0.4061
# Iteration 196/200, Reconstruction Error: 0.4067
# xのL2ノルムの変化 = 23.032623996372877%
# Tensor shape: (64, 64, 3, 3), K1=1583.5966873684438, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.4068
# Iteration 6/200, Reconstruction Error: 0.4077
# Iteration 11/200, Reconstruction Error: 0.4085
# Iteration 16/200, Reconstruction Error: 0.4094
# Iteration 21/200, Reconstruction Error: 0.4098
# Iteration 26/200, Reconstruction Error: 0.4107
# Iteration 31/200, Reconstruction Error: 0.4105
# Iteration 36/200, Reconstruction Error: 0.4118
# Iteration 41/200, Reconstruction Error: 0.4126
# Iteration 46/200, Reconstruction Error: 0.4127
# Iteration 51/200, Reconstruction Error: 0.4134
# Iteration 56/200, Reconstruction Error: 0.4140
# Iteration 61/200, Reconstruction Error: 0.4150
# Iteration 66/200, Reconstruction Error: 0.4155
# Iteration 71/200, Reconstruction Error: 0.4162
# Iteration 76/200, Reconstruction Error: 0.4168
# Iteration 81/200, Reconstruction Error: 0.4173
# Iteration 86/200, Reconstruction Error: 0.4175
# Iteration 91/200, Reconstruction Error: 0.4185
# Iteration 96/200, Reconstruction Error: 0.4189
# Iteration 101/200, Reconstruction Error: 0.4198
# Iteration 106/200, Reconstruction Error: 0.4204
# Iteration 111/200, Reconstruction Error: 0.4209
# Iteration 116/200, Reconstruction Error: 0.4212
# Iteration 121/200, Reconstruction Error: 0.4222
# Iteration 126/200, Reconstruction Error: 0.4224
# Iteration 131/200, Reconstruction Error: 0.4228
# Iteration 136/200, Reconstruction Error: 0.4239
# Iteration 141/200, Reconstruction Error: 0.4245
# Iteration 146/200, Reconstruction Error: 0.4252
# Iteration 151/200, Reconstruction Error: 0.4258
# Iteration 156/200, Reconstruction Error: 0.4263
# Iteration 161/200, Reconstruction Error: 0.4268
# Iteration 166/200, Reconstruction Error: 0.4269
# Iteration 171/200, Reconstruction Error: 0.4277
# Iteration 176/200, Reconstruction Error: 0.4287
# Iteration 181/200, Reconstruction Error: 0.4288
# Iteration 186/200, Reconstruction Error: 0.4298
# Iteration 191/200, Reconstruction Error: 0.4305
# Iteration 196/200, Reconstruction Error: 0.4307
# xのL2ノルムの変化 = 23.60163494080872%
# Tensor shape: (64, 64, 3, 3), K1=1514.9771533451317, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.4308
# Iteration 6/200, Reconstruction Error: 0.4322
# Iteration 11/200, Reconstruction Error: 0.4322
# Iteration 16/200, Reconstruction Error: 0.4330
# Iteration 21/200, Reconstruction Error: 0.4338
# Iteration 26/200, Reconstruction Error: 0.4340
# Iteration 31/200, Reconstruction Error: 0.4347
# Iteration 36/200, Reconstruction Error: 0.4351
# Iteration 41/200, Reconstruction Error: 0.4353
# Iteration 46/200, Reconstruction Error: 0.4363
# Iteration 51/200, Reconstruction Error: 0.4373
# Iteration 56/200, Reconstruction Error: 0.4381
# Iteration 61/200, Reconstruction Error: 0.4382
# Iteration 66/200, Reconstruction Error: 0.4388
# Iteration 71/200, Reconstruction Error: 0.4391
# Iteration 76/200, Reconstruction Error: 0.4399
# Iteration 81/200, Reconstruction Error: 0.4403
# Iteration 86/200, Reconstruction Error: 0.4412
# Iteration 91/200, Reconstruction Error: 0.4418
# Iteration 96/200, Reconstruction Error: 0.4424
# Iteration 101/200, Reconstruction Error: 0.4433
# Iteration 106/200, Reconstruction Error: 0.4432
# Iteration 111/200, Reconstruction Error: 0.4436
# Iteration 116/200, Reconstruction Error: 0.4449
# Iteration 121/200, Reconstruction Error: 0.4449
# Iteration 126/200, Reconstruction Error: 0.4455
# Iteration 131/200, Reconstruction Error: 0.4461
# Iteration 136/200, Reconstruction Error: 0.4469
# Iteration 141/200, Reconstruction Error: 0.4476
# Iteration 146/200, Reconstruction Error: 0.4482
# Iteration 151/200, Reconstruction Error: 0.4481
# Iteration 156/200, Reconstruction Error: 0.4488
# Iteration 161/200, Reconstruction Error: 0.4498
# Iteration 166/200, Reconstruction Error: 0.4501
# Iteration 171/200, Reconstruction Error: 0.4504
# Iteration 176/200, Reconstruction Error: 0.4515
# Iteration 181/200, Reconstruction Error: 0.4522
# Iteration 186/200, Reconstruction Error: 0.4520
# Iteration 191/200, Reconstruction Error: 0.4526
# Iteration 196/200, Reconstruction Error: 0.4531
# xのL2ノルムの変化 = 24.806899585701235%
# Tensor shape: (64, 64, 3, 3), K1=1452.4713431537218, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.4538
# Iteration 6/200, Reconstruction Error: 0.4544
# Iteration 11/200, Reconstruction Error: 0.4546
# Iteration 16/200, Reconstruction Error: 0.4554
# Iteration 21/200, Reconstruction Error: 0.4565
# Iteration 26/200, Reconstruction Error: 0.4568
# Iteration 31/200, Reconstruction Error: 0.4571
# Iteration 36/200, Reconstruction Error: 0.4574
# Iteration 41/200, Reconstruction Error: 0.4585
# Iteration 46/200, Reconstruction Error: 0.4588
# Iteration 51/200, Reconstruction Error: 0.4593
# Iteration 56/200, Reconstruction Error: 0.4595
# Iteration 61/200, Reconstruction Error: 0.4604
# Iteration 66/200, Reconstruction Error: 0.4612
# Iteration 71/200, Reconstruction Error: 0.4617
# Iteration 76/200, Reconstruction Error: 0.4618
# Iteration 81/200, Reconstruction Error: 0.4622
# Iteration 86/200, Reconstruction Error: 0.4634
# Iteration 91/200, Reconstruction Error: 0.4639
# Iteration 96/200, Reconstruction Error: 0.4642
# Iteration 101/200, Reconstruction Error: 0.4647
# Iteration 106/200, Reconstruction Error: 0.4649
# Iteration 111/200, Reconstruction Error: 0.4659
# Iteration 116/200, Reconstruction Error: 0.4666
# Iteration 121/200, Reconstruction Error: 0.4665
# Iteration 126/200, Reconstruction Error: 0.4674
# Iteration 131/200, Reconstruction Error: 0.4682
# Iteration 136/200, Reconstruction Error: 0.4683
# Iteration 141/200, Reconstruction Error: 0.4685
# Iteration 146/200, Reconstruction Error: 0.4696
# Iteration 151/200, Reconstruction Error: 0.4701
# Iteration 156/200, Reconstruction Error: 0.4701
# Iteration 161/200, Reconstruction Error: 0.4707
# Iteration 166/200, Reconstruction Error: 0.4712
# Iteration 171/200, Reconstruction Error: 0.4721
# Iteration 176/200, Reconstruction Error: 0.4725
# Iteration 181/200, Reconstruction Error: 0.4736
# Iteration 186/200, Reconstruction Error: 0.4735
# Iteration 191/200, Reconstruction Error: 0.4738
# Iteration 196/200, Reconstruction Error: 0.4746
# xのL2ノルムの変化 = 25.41898008324555%
# Tensor shape: (64, 64, 3, 3), K1=1395.2650366082582, K0=13906 (37.7%)
# Iteration 1/200, Reconstruction Error: 0.4751
# Iteration 6/200, Reconstruction Error: 0.4754
# Iteration 11/200, Reconstruction Error: 0.4761
# Iteration 16/200, Reconstruction Error: 0.4766
# Iteration 21/200, Reconstruction Error: 0.4772
# Iteration 26/200, Reconstruction Error: 0.4780
# Iteration 31/200, Reconstruction Error: 0.4788
# Iteration 36/200, Reconstruction Error: 0.4786
# Iteration 41/200, Reconstruction Error: 0.4789
# Iteration 46/200, Reconstruction Error: 0.4796
# Iteration 51/200, Reconstruction Error: 0.4803
# Iteration 56/200, Reconstruction Error: 0.4808
# Iteration 61/200, Reconstruction Error: 0.4815
# Iteration 66/200, Reconstruction Error: 0.4820
# Iteration 71/200, Reconstruction Error: 0.4827
# Iteration 76/200, Reconstruction Error: 0.4832
# Iteration 81/200, Reconstruction Error: 0.4841
# Iteration 86/200, Reconstruction Error: 0.4842
# Iteration 91/200, Reconstruction Error: 0.4841
# Iteration 96/200, Reconstruction Error: 0.4852
# Iteration 101/200, Reconstruction Error: 0.4861
# Iteration 106/200, Reconstruction Error: 0.4864
# Iteration 111/200, Reconstruction Error: 0.4861
# Iteration 116/200, Reconstruction Error: 0.4868
# Iteration 121/200, Reconstruction Error: 0.4876
# Iteration 126/200, Reconstruction Error: 0.4878
# Iteration 131/200, Reconstruction Error: 0.4886
# Iteration 136/200, Reconstruction Error: 0.4892
# Iteration 141/200, Reconstruction Error: 0.4897
# Iteration 146/200, Reconstruction Error: 0.4896
# Iteration 151/200, Reconstruction Error: 0.4901

# %%
zero_percentage_list = []

for i in range(10):
    # 更新後の重みの値を見る
    threshold = 10**-i

    print(f"閾値 {threshold} を使って、永続的なプルーニングマスクを適用します。")

    # 2. マスクを適用したいパラメータをリストアップ
    #    ここでは、全ての畳み込み層の'weight'を対象にします。
    parameters_to_prune = [
        (module, "weight")
        for module in model.modules()
        if isinstance(module, torch.nn.Conv2d)
    ]

    # 3. 各レイヤーに対して、現在の重みを基にカスタムマスクを作成し、適用する
    for module, name in parameters_to_prune:
        # 現在の重みを取得
        weights = getattr(module, name).detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        mask = (torch.abs(weights) > threshold).float().to(weights.device)
        
        # カスタムマスクを適用
        prune.CustomFromMask.apply(module, name, mask=mask)

    with torch.no_grad():
        all_conv_params = 0
        all_conv_zeros = 0
        for module, name in parameters_to_prune:
            weight_after_pruning = module.weight
            num_zeros = (weight_after_pruning == 0).sum().item()
            total_params = weight_after_pruning.numel()
            sparsity = 100. * num_zeros / total_params

            # 全体で何％枝刈りされたか考える
            all_conv_params += total_params
            all_conv_zeros += num_zeros

            print(f"{name}の重みのゼロの数: {num_zeros} / {total_params} ({sparsity:.4f}%)")

        all_conv_sparsity = 100. * all_conv_zeros / all_conv_params
        print(f"全畳み込み層の0率：{all_conv_sparsity:.4f}%")
        zero_percentage_list.append(all_conv_sparsity)

        for module, name in parameters_to_prune:
            # 1. 元の重み('weight_orig')を退避
            original_weights = module.weight_orig.clone()

            # 2. prune.removeでフックとマスクを削除
            prune.remove(module, 'weight')

            # 3. 退避した元の重みで上書き
            module.weight.data.copy_(original_weights)

plt.plot(zero_percentage_list)
plt.xticks(range(10))
plt.yticks(np.arange(40, 101, 5))
plt.grid()
plt.xlabel('(1e-x)')
plt.ylabel('zero_percent')
plt.show()

# 0マスクをつける閾値は1e-4か1e-5くらいがよさそう
# Out:
# 閾値 1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9408 / 9408 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 36864 / 36864 (100.0000%)
# weightの重みのゼロの数: 73728 / 73728 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 8192 / 8192 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 147456 / 147456 (100.0000%)
# weightの重みのゼロの数: 294912 / 294912 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 32768 / 32768 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 589824 / 589824 (100.0000%)
# weightの重みのゼロの数: 1179648 / 1179648 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 131072 / 131072 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# weightの重みのゼロの数: 2359296 / 2359296 (100.0000%)
# 全畳み込み層の0率：100.0000%
# 閾値 0.1 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9406 / 9408 (99.9787%)
# weightの重みのゼロの数: 36829 / 36864 (99.9051%)
# weightの重みのゼロの数: 36681 / 36864 (99.5036%)
# weightの重みのゼロの数: 36711 / 36864 (99.5850%)
# weightの重みのゼロの数: 36708 / 36864 (99.5768%)
# weightの重みのゼロの数: 73571 / 73728 (99.7871%)
# weightの重みのゼロの数: 147124 / 147456 (99.7748%)
# weightの重みのゼロの数: 7824 / 8192 (95.5078%)
# weightの重みのゼロの数: 147214 / 147456 (99.8359%)
# weightの重みのゼロの数: 147341 / 147456 (99.9220%)
# weightの重みのゼロの数: 294055 / 294912 (99.7094%)
# weightの重みのゼロの数: 589115 / 589824 (99.8798%)
# weightの重みのゼロの数: 32577 / 32768 (99.4171%)
# weightの重みのゼロの数: 588472 / 589824 (99.7708%)
# weightの重みのゼロの数: 589071 / 589824 (99.8723%)
# weightの重みのゼロの数: 1178785 / 1179648 (99.9268%)
# weightの重みのゼロの数: 2358565 / 2359296 (99.9690%)
# weightの重みのゼロの数: 129544 / 131072 (98.8342%)
# weightの重みのゼロの数: 2358926 / 2359296 (99.9843%)
# weightの重みのゼロの数: 2358991 / 2359296 (99.9871%)
# 全畳み込み層の0率：99.9158%
# 閾値 0.01 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9396 / 9408 (99.8724%)
# weightの重みのゼロの数: 36740 / 36864 (99.6636%)
# weightの重みのゼロの数: 31160 / 36864 (84.5269%)
# weightの重みのゼロの数: 35774 / 36864 (97.0432%)
# weightの重みのゼロの数: 33166 / 36864 (89.9685%)
# weightの重みのゼロの数: 70856 / 73728 (96.1046%)
# weightの重みのゼロの数: 139729 / 147456 (94.7598%)
# weightの重みのゼロの数: 4826 / 8192 (58.9111%)
# weightの重みのゼロの数: 142881 / 147456 (96.8974%)
# weightの重みのゼロの数: 138414 / 147456 (93.8680%)
# weightの重みのゼロの数: 256730 / 294912 (87.0531%)
# weightの重みのゼロの数: 538853 / 589824 (91.3583%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：92.1579%
# 閾値 0.001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 9396 / 9408 (99.8724%)
# weightの重みのゼロの数: 36614 / 36864 (99.3218%)
# weightの重みのゼロの数: 23416 / 36864 (63.5200%)
# weightの重みのゼロの数: 25245 / 36864 (68.4814%)
# weightの重みのゼロの数: 24199 / 36864 (65.6440%)
# weightの重みのゼロの数: 54675 / 73728 (74.1577%)
# weightの重みのゼロの数: 117512 / 147456 (79.6929%)
# weightの重みのゼロの数: 4357 / 8192 (53.1860%)
# weightの重みのゼロの数: 125010 / 147456 (84.7778%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.4914%
# 閾値 0.0001 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 6561 / 9408 (69.7385%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 23022 / 36864 (62.4512%)
# weightの重みのゼロの数: 22202 / 36864 (60.2268%)
# weightの重みのゼロの数: 22933 / 36864 (62.2097%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231114 / 294912 (78.3671%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0222%
# 閾値 1e-05 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22958 / 36864 (62.2776%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22865 / 36864 (62.0253%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231112 / 294912 (78.3664%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24140 / 32768 (73.6694%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：90.0000%
# 閾値 1e-06 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 22949 / 36864 (62.2531%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 22858 / 36864 (62.0063%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231057 / 294912 (78.3478%)
# weightの重みのゼロの数: 489628 / 589824 (83.0126%)
# weightの重みのゼロの数: 24063 / 32768 (73.4344%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：89.9987%
# 閾値 1e-07 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 10610 / 36864 (28.7815%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 20102 / 36864 (54.5302%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 231057 / 294912 (78.3478%)
# weightの重みのゼロの数: 446792 / 589824 (75.7501%)
# weightの重みのゼロの数: 21382 / 32768 (65.2527%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：89.4559%
# 閾値 1e-08 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 10374 / 36864 (28.1413%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 11283 / 36864 (30.6071%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 230949 / 294912 (78.3112%)
# weightの重みのゼロの数: 196792 / 589824 (33.3645%)
# weightの重みのゼロの数: 8937 / 32768 (27.2736%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：87.0237%
# 閾値 1e-09 を使って、永続的なプルーニングマスクを適用します。
# weightの重みのゼロの数: 4279 / 9408 (45.4826%)
# weightの重みのゼロの数: 24149 / 36864 (65.5084%)
# weightの重みのゼロの数: 2360 / 36864 (6.4019%)
# weightの重みのゼロの数: 22140 / 36864 (60.0586%)
# weightの重みのゼロの数: 5487 / 36864 (14.8844%)
# weightの重みのゼロの数: 48436 / 73728 (65.6955%)
# weightの重みのゼロの数: 108909 / 147456 (73.8586%)
# weightの重みのゼロの数: 4352 / 8192 (53.1250%)
# weightの重みのゼロの数: 107465 / 147456 (72.8794%)
# weightの重みのゼロの数: 111269 / 147456 (75.4591%)
# weightの重みのゼロの数: 230949 / 294912 (78.3112%)
# weightの重みのゼロの数: 60767 / 589824 (10.3026%)
# weightの重みのゼロの数: 7009 / 32768 (21.3898%)
# weightの重みのゼロの数: 509072 / 589824 (86.3091%)
# weightの重みのゼロの数: 520476 / 589824 (88.2426%)
# weightの重みのゼロの数: 1050433 / 1179648 (89.0463%)
# weightの重みのゼロの数: 2189418 / 2359296 (92.7996%)
# weightの重みのゼロの数: 95241 / 131072 (72.6631%)
# weightの重みのゼロの数: 2161988 / 2359296 (91.6370%)
# weightの重みのゼロの数: 2301894 / 2359296 (97.5670%)
# 全畳み込み層の0率：85.6646%

# %%
# maskをつくる
threshold = 1e-4   #1e-4が基準

masks = {}

for name, module in model.named_modules():
    if isinstance(module, torch.nn.Conv2d):
        # 現在の重みを取得
        weights = module.weight.detach()
        
        # 閾値に基づいてマスクを作成 (絶対値が閾値より大きい要素が1、それ以外は0)
        masks[name] = (torch.abs(weights) > threshold).float().to(weights.device)

# %%
# カスタムマスクを適用
# ブロックスパースアルゴリズム前の密モデルの重みに対してマスクをかける
pt_model_path = "dense.pt"
model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 10)  # CIFAR-10 にあわせて出力層変更
model.load_state_dict(torch.load(pt_model_path))

for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])

# %%
# ADMM後のモデルにマスクをかける
'''
for name, module in model.named_modules(): 
    if name in masks:
        prune.CustomFromMask.apply(module, "weight", mask=masks[name])
'''
# Out:
# '\nfor name, module in model.named_modules(): \n    if name in masks:\n        prune.CustomFromMask.apply(module, "weight", mask=masks[name])\n'

# %%
# ゼロ比率を表示
all_conv_params = 0
all_conv_zeros = 0

for name, module in model.named_modules():
  if isinstance(module, torch.nn.Conv2d):
    print(f"{name} Zero-Ratio: {100.0 * float(torch.sum(module.weight == 0)) / float(module.weight.nelement()):.4f}%")
    weight_after_pruning = module.weight
    num_zeros = (weight_after_pruning == 0).sum().item()
    total_params = weight_after_pruning.numel()
    all_conv_params += total_params
    all_conv_zeros += num_zeros

sparsity = 100. * all_conv_zeros / all_conv_params if all_conv_params > 0 else 0
print(f"全畳み込み層の0率：{sparsity:.4f}%")
# Out:
# conv1 Zero-Ratio: 45.4826%
# layer1.0.conv1 Zero-Ratio: 65.5084%
# layer1.0.conv2 Zero-Ratio: 62.2776%
# layer1.1.conv1 Zero-Ratio: 60.0586%
# layer1.1.conv2 Zero-Ratio: 62.0253%
# layer2.0.conv1 Zero-Ratio: 65.6955%
# layer2.0.conv2 Zero-Ratio: 73.8586%
# layer2.0.downsample.0 Zero-Ratio: 53.1250%
# layer2.1.conv1 Zero-Ratio: 72.8794%
# layer2.1.conv2 Zero-Ratio: 75.4591%
# layer3.0.conv1 Zero-Ratio: 78.3671%
# layer3.0.conv2 Zero-Ratio: 83.0126%
# layer3.0.downsample.0 Zero-Ratio: 73.6694%
# layer3.1.conv1 Zero-Ratio: 86.3091%
# layer3.1.conv2 Zero-Ratio: 88.2426%
# layer4.0.conv1 Zero-Ratio: 89.0463%
# layer4.0.conv2 Zero-Ratio: 92.7996%
# layer4.0.downsample.0 Zero-Ratio: 72.6631%
# layer4.1.conv1 Zero-Ratio: 91.6370%
# layer4.1.conv2 Zero-Ratio: 97.5670%
# 全畳み込み層の0率：90.0000%

# %%
# 再訓練
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)   #lr = 0.001で損失0.02とか
num_epochs = 15
epoch_loss_list = []
# CosineAnnealingLRを定義
# T_max: 学習率が半周期で最小値になるまでのエポック数。通常、総エポック数を指定。
# eta_min: 最小学習率。
scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=0)

for epoch in range(num_epochs):
  model.train()
  model = model.to(device)
  total_loss = 0.0
  num_train = 0
  for inputs, labels in trainloader:
    inputs, labels = inputs.to(device), labels.to(device)   # データ代入

    # 重み更新のための手順
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # 損失を記録
    total_loss += loss.item()*labels.size(0)
    num_train+=labels.size(0)

  # 出力と記録
  epoch_loss_list.append(total_loss/num_train)
  current_lr = optimizer.param_groups[0]['lr']
  print(f'Epoch[{epoch+1}/{num_epochs}], Loss: {epoch_loss_list[epoch]:.4f}, LR: {current_lr:.8f}')


  # 次のエポックへの準備
  if epoch >= 1:
    if np.abs(epoch_loss_list[epoch]-epoch_loss_list[epoch-1]) < 0.001:
      break
  scheduler.step()
# Out:
# Epoch[1/15], Loss: 0.3555, LR: 0.00100000
# Epoch[2/15], Loss: 0.1224, LR: 0.00098907
# Epoch[3/15], Loss: 0.0577, LR: 0.00095677
# Epoch[4/15], Loss: 0.0297, LR: 0.00090451
# Epoch[5/15], Loss: 0.0148, LR: 0.00083457
# Epoch[6/15], Loss: 0.0075, LR: 0.00075000
# Epoch[7/15], Loss: 0.0021, LR: 0.00065451
# Epoch[8/15], Loss: 0.0007, LR: 0.00055226
# Epoch[9/15], Loss: 0.0004, LR: 0.00044774

# %%
# 損失グラフ作成
plt.plot(epoch_loss_list)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
# 永続化（マスクと重みを掛ける）
for module in model.modules():
  if isinstance(module, torch.nn.Conv2d):
    prune.remove(module, "weight")

# %%
# onnxファイルとptファイルの作成
model = model.to('cpu')
model_to_onnx(model, "MM_ADMM_blocksparse_trained.onnx")
torch.save(model.state_dict(), "MM_ADMM_blocksparse_trained.pt")
